# %%
x = 2

# %%
se = 2

# %%
# %config Completer.use_jedi = False

# %%
for _ in range(100): 
    for _ in range(1000): 
        print("ehl")
# Out:
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ehl
# ...

# %%
x = 2

# %%
# how
