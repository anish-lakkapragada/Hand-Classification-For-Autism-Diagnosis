# %% [markdown]
# # The first step is preprocessing. We use the [SSBD Dataset](https://rolandgoecke.net/research/datasets/ssbd/) in order to get the data for hand flapping and spinning.
#
# ## The dataset does contain 75 URLs (although we'll ignore all headbanging videos) to youtube videos. All the data is nicely stored in XML files that I will read to get the youtube videos and also the time stamps of when the behavior (hand flapping or spinning) occurs. Then I will use pytube to download the youtube videos to .mp4 and moviepy to cut the .mp4 videos into the areas of interest. Finally, because some of those areas of interest clips are more than a few seconds long (which is all you need to detect spinning or headbanging) I will take those areas that are > 8 seconds and split them into many clips (that way we have more data.) Also in sections of the video where no behavior is used I will take them as videos as control data.

# %%
# first change the directory over to ssbd release
import os 
import xml.etree.ElementTree as ET

# %%
# next step would be to get the hand flapping and spinning data 

tree = ET.parse("ssbd-release/Annotations/v_ArmFlapping_07.xml")
root = tree.getroot()
for child in root:
    # for each child in the root 
    if child.tag == "url":
        print(child.text)
    if child.tag == "behaviours":
        for behavior in child: # go through each reported behavior 
            for tag in behavior: # tag is just the attribute of the behavior 
                if tag.tag == "time":
                    print(tag.text)
                if tag.tag == "intensity":
                    print(tag.text)
                if tag.tag == "category":
                    print(tag.text)
# Out:
# http://www.youtube.com/watch?v=T9rbit_oiJA
# 0004:0010
# armflapping
# high
# 0015:0020
# armflapping
# high

# %%
def convert_to_second(time : str) -> int:
    # this will take in a time like "0125" or 1:25 and make it 85 (60 + 25)
    overall_seconds = 0 
    for i, time_char in enumerate(reversed(time)):
        if i == 0:
            overall_seconds += int(time_char)
        if i == 1:
            overall_seconds += int(time_char) * 10
        if i == 2:
            overall_seconds += int(time_char) * 60 
        if i == 3:
            overall_seconds += int(time_char) * 600 
    return overall_seconds 

assert convert_to_second('2345') == 23 * 60 + 45  

def consecutive(data, stepsize=1):
    '''groups up elements in an array that are continous with each other (useful to create sections where none 
    of the behaviors are shown.)'''
    return np.split(data, np.where(np.diff(data) != stepsize)[0]+1)

# %%
from collections import defaultdict
import math 
import numpy as np

NUM_SECONDS_TO_RECOGNIZE = 8 # hypothesis: takes this many seconds seconds to recognize handflapping + spinning 

URLS_TO_DOWNLOAD = set() # contains all youtube videos to download 
links_to_times = {} # data will be stored here like {link : {'category' : [(start, end)], 'another cat' : [(start, end)]}


for i, file_name in enumerate(os.listdir('ssbd-release/Annotations/')):
    # parse this file 
    tree = ET.parse('ssbd-release/Annotations/' + file_name)
    root = tree.getroot() 
    
    # everything we need to store
    URL = ""
    
    for child in root:
        
        if child.tag == "url":
            URL = child.text # store URL
            URLS_TO_DOWNLOAD.add(URL)
            links_to_times[URL] = defaultdict(list) 
        
        if child.tag == "duration":
            duration = int(child.text[:-1])
            all_times = list(range(duration))
        
        if child.tag == "behaviours": # this child has the list of behaviors 
            for reported_behavior in child: 
                for info in reported_behavior:
                    # gather the start time, end time, and category for this youtube link 
                    if info.tag == "time":
                        # the time will be start:end 
                        times = str(info.text) # contains the string 
                        if times.count(":"): 
                            divider_index = times.index(":")
                        elif times.count("-"):
                            divider_index = times.index("-")
                        else:
                            break # invalid then 
                        actual_start_time, actual_end_time = convert_to_second(times[:divider_index]), convert_to_second(times[divider_index + 1:])
                        START_TIMES, END_TIMES = [], []
                        times = np.array(range(actual_start_time, actual_end_time +1))
                        for time in times:
                            try:
                                all_times.remove(time)
                            except Exception as e:
                                pass 
                        split_times = np.array_split(times, math.ceil(times.shape[0] / NUM_SECONDS_TO_RECOGNIZE))
                        for time in split_times:
                            START_TIMES.append(time[0])
                            END_TIMES.append(time[-1])
                    if info.tag == "category":
                        # this is the label 
                        LABEL = info.text 
                
                # create an entry for this reported behavior 
                for START_TIME, END_TIME in zip(START_TIMES, END_TIMES):
                    links_to_times[URL][LABEL].append((START_TIME, END_TIME))
                    
            idle_times = consecutive(np.array(all_times))
            num_contributed = 0 # each video can only give 4 control clips (because otherwise it takes WAY too long)
            for control_times in idle_times:
                if num_contributed >= 4: 
                    break 
                # times maybe > NUM_SECONDS_TO_RECOGNIZE so split if that is the case 
                if len(control_times) <= NUM_SECONDS_TO_RECOGNIZE:
                    START_TIME, END_TIME = control_times[0], control_times[-1]
                    links_to_times[URL]['control'].append((START_TIME, END_TIME))
                    num_contributed += 1
                else:
                    # needs to be split 
                    control_times_split = np.array_split(control_times, math.ceil(len(control_times) / NUM_SECONDS_TO_RECOGNIZE))
                    for control_time in control_times_split:  
                        START_TIME, END_TIME = control_time[0], control_time[-1]
                        links_to_times[URL]['control'].append((START_TIME, END_TIME))
                        num_contributed += 1
                        if num_contributed >= 4: 
                            break

# %%
links_to_times
# Out:
# {'http://www.youtube.com/watch?v=Pqd9Vu-juPI': defaultdict(list,
#              {'spinning': [(10, 15)],
#               'control': [(0, 4), (5, 9), (16, 23), (24, 31)]}),
#  'http://www.youtube.com/watch?v=yMgx2lVjf5I': defaultdict(list,
#              {'headbanging': [(1, 7), (18, 25), (36, 43), (44, 50)],
#               'control': [(0, 0), (8, 12), (13, 17), (26, 30)]}),
#  'http://www.youtube.com/watch?v=WRGUUOZ5_wA': defaultdict(list,
#              {'armflapping': [(60, 67), (60, 67)],
#               'control': [(0, 7), (8, 15), (16, 23), (24, 31)]}),
#  'http://www.youtube.com/watch?v=8vFUIFEfRpA': defaultdict(list,
#              {'armflapping': [(2, 8), (9, 14)],
#               'control': [(0, 1), (15, 21), (22, 28), (29, 34)]}),
#  'http://www.youtube.com/watch?v=SOc13pnf-Dc': defaultdict(list,
#              {'armflapping': [(65, 71),
#                (72, 78),
#                (79, 85),
#                (132, 136),
#                (137, 140)],
#               'control': [(0, 7), (8, 15), (16, 22), (23, 29)]}),
#  'http://www.youtube.com/watch?v=iDuAugAykcc': defaultdict(list,
#              {'armflapping': [(18, 22),
#                (23, 27),
#                (33, 37),
#                (50, 57),
#                (68, 73),
#                (74, 79),
#                (80, 85)],
#               'control': [(0, 5), (6, 11), (12, 17), (28, 32)]}),
#  'http://www.youtube.com/watch?v=BUAFdqrw4fA': defaultdict(list,
#              {'headbanging': [(8, 13),
#                (14, 18),
#                (20, 26),
#                (27, 32),
#                (33, 38),
#                (39, 44),
#                (54, 61),
#                (62, 69),
#                (70, 76),
#                (77, 83)],
#               'control': [(0, 7), (19, 19), (45, 49), (50, 53)]}),
#  'http://www.youtube.com/watch?v=WcsZ9eMQ5Zs': defaultdict(list,
#              {'headbanging': [(2, 6), (7, 10)],
#               'control': [(0, 1), (11, 13)]}),
#  'http://www.youtube.com/watch?v=w96PxUcoo58': defaultdict(list,
#              {'headbanging': [(5, 10)], 'control': [(0, 4), (11, 13)]}),
#  'http://www.youtube.com/watch?v=ehlLfMossUY': defaultdict(list,
#              {'armflapping': [(27, 30), (40, 43), (100, 102)],
#               'control': [(0, 6), (7, 13), (14, 20), (21, 26)]}),
#  'http://www.youtube.com/watch?v=mnBWOI4LuKw': defaultdict(list,
#              {'armflapping': [(3, 9),
#                (10, 16),
#                (17, 23),
#                (24, 30),
#                (74, 81),
#                (82, 88),
#                (89, 95),
#                (96, 102),
#                (103, 109),
#                (110, 116),
#                (117, 123),
#                (124, 130),
#                (134, 141),
#                (142, 148),
#                (149, 155)],
#               'control': [(0, 2), (31, 38), (39, 45), (46, 52)]}),
#  'http://www.youtube.com/watch?v=3Oh_Lmehb6c': defaultdict(list,
#              {'armflapping': [(19, 22), (40, 45), (46, 51)],
#               'control': [(0, 6), (7, 12), (13, 18), (23, 28)]}),
#  'http://www.youtube.com/watch?v=T9rbit_oiJA': defaultdict(list,
#              {'armflapping': [(4, 10), (15, 20)],
#               'control': [(0, 3), (11, 14), (21, 27), (28, 33)]}),
#  'http://www.youtube.com/watch?v=6sR-8llWl_s': defaultdict(list,
#              {'headbanging': [(9, 14), (15, 20), (21, 26)],
#               'control': [(0, 4), (5, 8), (27, 33), (34, 40)]}),
#  'http://www.youtube.com/watch?v=Z2kfvB4lv7A': defaultdict(list,
#              {'armflapping': [(22, 27)],
#               'control': [(0, 7), (8, 14), (15, 21), (28, 34)]}),
#  'http://www.youtube.com/watch?v=vtVnrV_jog0': defaultdict(list,
#              {'armflapping': [(2, 8), (9, 14), (19, 23), (36, 39)],
#               'control': [(0, 1), (15, 18), (24, 29), (30, 35)]}),
#  'http://www.youtube.com/watch?v=5sgfS0SSh8o': defaultdict(list,
#              {'armflapping': [(32, 39), (40, 46)], 'control': [(0, 4)]}),
#  'http://www.youtube.com/watch?v=hKf-IwHM6TI': defaultdict(list,
#              {'armflapping': [(11, 16), (19, 23), (29, 33)],
#               'control': [(0, 5), (6, 10), (17, 18), (24, 28)]}),
#  'http://www.youtube.com/watch?v=zuoD4tEtYyk': defaultdict(list,
#              {'headbanging': [(1, 7), (8, 14), (15, 20)],
#               'control': [(0, 0), (21, 21)]}),
#  'http://www.youtube.com/watch?v=I38WtUMuQwM': defaultdict(list,
#              {'headbanging': [(30, 35), (36, 40)],
#               'armflapping': [(124, 130),
#                (131, 137),
#                (138, 144),
#                (145, 150),
#                (176, 181),
#                (182, 187),
#                (206, 211)],
#               'control': [(0, 7), (8, 15), (16, 22), (23, 29)]}),
#  'http://www.youtube.com/watch?v=pz1nIbRWb2M': defaultdict(list,
#              {'armflapping': [(3, 7)],
#               'control': [(0, 2), (8, 14), (15, 21), (22, 28)]}),
#  'http://www.youtube.com/watch?v=I7fdv1q9-m8': defaultdict(list,
#              {'armflapping': [(18, 24)],
#               'headbanging': [(27, 32)],
#               'control': [(0, 5), (6, 11), (12, 17), (25, 26)]}),
#  'http://www.youtube.com/watch?v=nGoMpqcYcOg': defaultdict(list,
#              {'armflapping': [(17, 23), (32, 37)],
#               'control': [(0, 5), (6, 11), (12, 16), (24, 31)]}),
#  'http://www.youtube.com/watch?v=TVMWW9SejgI': defaultdict(list,
#              {'headbanging': [(1, 8), (9, 15)],
#               'control': [(0, 0), (16, 20), (21, 25)]}),
#  'http://www.youtube.com/watch?v=hX3sIO2wc1s': defaultdict(list,
#              {'headbanging': [(3, 10)], 'control': [(0, 2), (11, 15)]}),
#  'http://www.youtube.com/watch?v=VxK45NHvHTg': defaultdict(list,
#              {'spinning': [(25, 28)],
#               'control': [(0, 6), (7, 12), (13, 18), (19, 24)]}),
#  'http://www.youtube.com/watch?v=AXghcX_Bjac': defaultdict(list,
#              {'spinning': [(56, 63)],
#               'control': [(0, 7), (8, 15), (16, 23), (24, 31)]}),
#  'http://www.youtube.com/watch?v=scM9g0LExJA': defaultdict(list,
#              {'spinning': [(1, 8),
#                (9, 16),
#                (17, 24),
#                (25, 32),
#                (33, 40),
#                (41, 47),
#                (60, 67),
#                (68, 74),
#                (75, 81),
#                (82, 88),
#                (105, 112),
#                (113, 120),
#                (121, 128),
#                (140, 147),
#                (163, 170),
#                (171, 178),
#                (179, 186),
#                (187, 194),
#                (195, 202),
#                (203, 210),
#                (211, 218),
#                (219, 226),
#                (227, 234),
#                (235, 242),
#                (243, 250),
#                (251, 258),
#                (259, 266),
#                (267, 274),
#                (275, 281),
#                (282, 288),
#                (289, 295)],
#               'control': [(0, 0)]}),
#  'http://www.youtube.com/watch?v=-rC-ab0nzxY': defaultdict(list,
#              {'spinning': [(26, 31), (32, 37), (38, 43)],
#               'control': [(0, 6), (7, 13), (14, 19), (20, 25)]}),
#  'http://www.youtube.com/watch?v=yiEo7Kg1ngY': defaultdict(list,
#              {'spinning': [(1, 8),
#                (9, 16),
#                (17, 24),
#                (25, 32),
#                (33, 40),
#                (41, 48),
#                (49, 56),
#                (57, 64),
#                (65, 72),
#                (73, 80),
#                (81, 88),
#                (89, 96),
#                (97, 104),
#                (105, 112),
#                (113, 120),
#                (121, 127),
#                (128, 134),
#                (135, 141),
#                (142, 148),
#                (149, 155)],
#               'control': [(0, 0), (156, 157)]}),
#  'http://www.youtube.com/watch?v=8R1MfXoI3mo': defaultdict(list,
#              {'spinning': [(2, 7),
#                (15, 22),
#                (23, 30),
#                (31, 38),
#                (39, 45),
#                (46, 52),
#                (53, 59),
#                (60, 66),
#                (67, 73),
#                (74, 80)],
#               'control': [(0, 1), (8, 14)]}),
#  'http://www.youtube.com/watch?v=5MS6VZwZDi0': defaultdict(list,
#              {'spinning': [(2, 9),
#                (10, 17),
#                (18, 24),
#                (25, 31),
#                (32, 38),
#                (39, 45),
#                (46, 52),
#                (53, 59)],
#               'control': [(0, 1), (60, 66), (67, 73), (74, 80)]}),
#  'http://www.youtube.com/watch?v=TH5mlAhdw00': defaultdict(list,
#              {'spinning': [(2, 9)],
#               'control': [(0, 1), (10, 17), (18, 25), (26, 33)]}),
#  'http://www.youtube.com/watch?v=kFuxwAufWvQ': defaultdict(list,
#              {'spinning': [(2, 9),
#                (10, 17),
#                (18, 25),
#                (26, 33),
#                (34, 40),
#                (41, 47)],
#               'control': [(0, 1), (48, 55), (56, 63), (64, 71)]}),
#  'http://www.youtube.com/watch?v=oukupxRUA84': defaultdict(list,
#              {'spinning': [(4, 8),
#                (9, 12),
#                (28, 34),
#                (35, 41),
#                (42, 47),
#                (58, 64)],
#               'control': [(0, 3), (13, 20), (21, 27), (48, 52)]}),
#  'http://www.youtube.com/watch?v=Gt-WMpTP7IE': defaultdict(list,
#              {'spinning': [(1, 8),
#                (9, 16),
#                (17, 24),
#                (25, 32),
#                (33, 40),
#                (41, 48),
#                (49, 56),
#                (57, 63),
#                (64, 70)],
#               'control': [(0, 0), (71, 78), (79, 85)]}),
#  'http://www.youtube.com/watch?v=uWgI1w2fQhs': defaultdict(list,
#              {'spinning': [(3, 9), (10, 16), (17, 22), (23, 28)],
#               'control': [(0, 2), (29, 35), (36, 42)]}),
#  'http://www.youtube.com/watch?v=VAMZwnfAHyY': defaultdict(list,
#              {'spinning': [(3, 8), (9, 14), (15, 20)],
#               'control': [(0, 2), (21, 27), (28, 33)]}),
#  'http://www.youtube.com/watch?v=arn5UCMLlBo': defaultdict(list,
#              {'spinning': [(2, 8), (9, 15)], 'control': [(0, 1), (16, 18)]}),
#  'http://www.youtube.com/watch?v=5BVFjqo0FUY': defaultdict(list,
#              {'spinning': [(1, 8),
#                (9, 16),
#                (17, 24),
#                (36, 43),
#                (44, 51),
#                (52, 59),
#                (60, 67),
#                (68, 75),
#                (76, 82),
#                (83, 89),
#                (90, 96),
#                (97, 103),
#                (104, 110),
#                (111, 117),
#                (125, 131),
#                (132, 138),
#                (139, 145),
#                (146, 152),
#                (153, 159),
#                (160, 165),
#                (180, 186),
#                (187, 193),
#                (194, 199)],
#               'control': [(0, 0), (25, 30), (31, 35), (118, 124)]}),
#  'http://www.youtube.com/watch?v=2AS14wxMB-A': defaultdict(list,
#              {'spinning': [(6, 12), (13, 18)],
#               'control': [(0, 5), (19, 24), (25, 29)]}),
#  'http://www.youtube.com/watch?v=cxqsde-6V-c': defaultdict(list,
#              {'spinning': [(1, 7), (8, 14), (15, 20)],
#               'control': [(0, 0), (21, 27), (28, 33), (34, 39)]}),
#  'http://www.youtube.com/watch?v=ZHJr17Q4384': defaultdict(list,
#              {'spinning': [(2, 9),
#                (10, 17),
#                (18, 25),
#                (26, 33),
#                (34, 41),
#                (42, 49),
#                (50, 57),
#                (58, 65),
#                (66, 73),
#                (74, 81),
#                (82, 89),
#                (90, 96),
#                (97, 103),
#                (104, 110)],
#               'control': [(0, 1), (111, 114)]}),
#  'http://www.youtube.com/watch?v=NDcUGYlTy_4': defaultdict(list,
#              {'spinning': [(6, 12), (75, 81), (82, 88), (89, 95)],
#               'control': [(0, 5), (13, 20), (21, 28), (29, 36)]}),
#  'http://www.youtube.com/watch?v=sAgAvYT3D8s': defaultdict(list,
#              {'spinning': [(10, 15), (16, 20)],
#               'control': [(0, 4), (5, 9), (21, 28), (29, 36)]}),
#  'http://www.youtube.com/watch?v=wu5fgT-LkHs': defaultdict(list,
#              {'spinning': [(2, 8),
#                (9, 14),
#                (15, 20),
#                (30, 36),
#                (37, 43),
#                (44, 50),
#                (51, 57),
#                (58, 63)],
#               'control': [(0, 1), (21, 25), (26, 29), (64, 71)]}),
#  'http://www.youtube.com/watch?v=uNpUNkjNreg': defaultdict(list,
#              {'spinning': [(68, 75), (76, 83)],
#               'control': [(0, 7), (8, 15), (16, 23), (24, 31)]}),
#  'http://www.youtube.com/watch?v=gKED6S0eGYA': defaultdict(list,
#              {'spinning': [(1, 5), (6, 10)],
#               'control': [(0, 0), (11, 18), (19, 25)]}),
#  'http://www.youtube.com/watch?v=pgj_LKf6jL4': defaultdict(list,
#              {'spinning': [(51, 58)],
#               'control': [(0, 7), (8, 15), (16, 22), (23, 29)]}),
#  'http://www.youtube.com/watch?v=yCaymsrcNwA': defaultdict(list,
#              {'headbanging': [(1, 4)],
#               'control': [(0, 0), (5, 11), (12, 18), (19, 24)]}),
#  'http://www.youtube.com/watch?v=9zOrUA7Kn4o': defaultdict(list,
#              {'headbanging': [(1, 8), (9, 16), (17, 23)],
#               'control': [(0, 0), (24, 31), (32, 38), (39, 45)]}),
#  'http://www.youtube.com/watch?v=AGmXuSY4gx0': defaultdict(list,
#              {'armflapping': [(8, 15)],
#               'control': [(0, 7), (16, 22), (23, 28), (29, 34)]}),
#  'http://www.youtube.com/watch?v=JM8BHjJTSFM': defaultdict(list,
#              {'armflapping': [(3, 7), (40, 45), (46, 50)],
#               'control': [(0, 2), (8, 15), (16, 23), (24, 31)]}),
#  'http://www.youtube.com/watch?v=1vRklwIBC28': defaultdict(list,
#              {'headbanging': [(60, 66),
#                (67, 73),
#                (74, 80),
#                (81, 87),
#                (88, 94),
#                (100, 106),
#                (107, 113),
#                (114, 120)],
#               'armflapping': [(175, 182), (183, 190), (205, 212), (213, 219)],
#               'control': [(0, 7), (8, 15), (16, 23), (24, 31)]}),
#  'http://www.youtube.com/watch?v=I2rfPPinMHk': defaultdict(list,
#              {'armflapping': [(4, 8)],
#               'control': [(0, 3), (9, 15), (16, 22)]}),
#  'http://www.youtube.com/watch?v=0Vk9itex_ds': defaultdict(list,
#              {'headbanging': [(4, 10), (11, 17), (18, 24), (25, 30)],
#               'control': [(0, 3), (31, 32)]}),
#  'http://www.youtube.com/watch?v=Lw-MsQ2k6ZQ': defaultdict(list,
#              {'headbanging': [(10, 17)],
#               'control': [(0, 4), (5, 9), (18, 25), (26, 32)]}),
#  'http://www.youtube.com/watch?v=a5BuwkqtIa0': defaultdict(list,
#              {'headbanging': [(4, 9), (36, 40), (41, 44)],
#               'control': [(0, 3), (10, 16), (17, 23), (24, 29)]}),
#  'http://www.youtube.com/watch?v=k9MJ4pDQQ74': defaultdict(list,
#              {'headbanging': [(6, 10), (11, 14)], 'control': [(0, 5)]}),
#  'http://www.youtube.com/watch?v=8SrUO-NdSZU': defaultdict(list,
#              {'headbanging': [(2, 9),
#                (10, 16),
#                (17, 23),
#                (24, 30),
#                (31, 37),
#                (38, 44),
#                (45, 51),
#                (52, 58)],
#               'control': [(0, 1), (59, 66), (67, 73), (74, 80)]}),
#  'http://www.youtube.com/watch?v=B9hYEIjsHDA': defaultdict(list,
#              {'headbanging': [(2, 8), (9, 14), (15, 20)],
#               'control': [(0, 1), (21, 25), (26, 29)]}),
#  'http://www.youtube.com/watch?v=nwLp0k1xa0o': defaultdict(list,
#              {'headbanging': [(55, 59), (60, 64)],
#               'control': [(0, 7), (8, 15), (16, 23), (24, 31)]}),
#  'http://www.youtube.com/watch?v=UxpQpWzhOx0': defaultdict(list,
#              {'armflapping': [(2, 6),
#                (41, 48),
#                (49, 55),
#                (60, 67),
#                (68, 75),
#                (76, 82),
#                (83, 89),
#                (94, 98),
#                (99, 102),
#                (110, 114),
#                (115, 118)],
#               'control': [(0, 1), (7, 13), (14, 20), (21, 27)]}),
#  'http://www.youtube.com/watch?v=xeKKMkVgNPU': defaultdict(list,
#              {'armflapping': [(3, 9), (60, 65), (66, 70)],
#               'spinning': [(49, 53), (54, 57)],
#               'control': [(0, 2), (10, 17), (18, 25), (26, 33)]}),
#  'http://www.youtube.com/watch?v=WLtorzPESbc': defaultdict(list,
#              {'headbanging': [(10, 14), (15, 19)],
#               'control': [(0, 4), (5, 9), (20, 22)]}),
#  'http://www.youtube.com/watch?v=5WTHMIJ_61I': defaultdict(list,
#              {'headbanging': [(2, 7), (8, 12)],
#               'control': [(0, 1), (13, 20), (21, 28), (29, 36)]}),
#  'http://www.youtube.com/watch?v=pzPhXbGEpSo': defaultdict(list,
#              {'headbanging': [(16, 23), (24, 30), (34, 39)],
#               'control': [(0, 7), (8, 15), (31, 33), (40, 46)]}),
#  'http://www.youtube.com/watch?v=aNaC46cUOJo': defaultdict(list,
#              {'headbanging': [(16, 22)],
#               'control': [(0, 7), (8, 15), (23, 30), (31, 38)]}),
#  'http://www.youtube.com/watch?v=C_O8vyrSt0Q': defaultdict(list,
#              {'armflapping': [(5, 10),
#                (11, 15),
#                (30, 37),
#                (38, 44),
#                (55, 62),
#                (63, 70),
#                (85, 92),
#                (93, 100),
#                (125, 132),
#                (133, 139)],
#               'control': [(0, 4), (16, 22), (23, 29), (45, 49)]}),
#  'http://www.youtube.com/watch?v=AQ-jO6O5gow': defaultdict(list,
#              {'armflapping': [(7, 11), (12, 16)],
#               'control': [(0, 6), (17, 22)]}),
#  'http://www.youtube.com/watch?v=MOt-6FAEP_g': defaultdict(list,
#              {'armflapping': [(94, 98)],
#               'control': [(0, 7), (8, 15), (16, 23), (24, 31)]}),
#  'http://www.youtube.com/watch?v=5Ps9iE8mPqY': defaultdict(list,
#              {'armflapping': [(18, 21),
#                (47, 51),
#                (70, 77),
#                (90, 96),
#                (97, 102),
#                (103, 108),
#                (122, 128),
#                (129, 134),
#                (195, 200),
#                (218, 223)],
#               'control': [(0, 5), (6, 11), (12, 17), (22, 28)]}),
#  'http://www.youtube.com/watch?v=Pa-pdBF4FFA': defaultdict(list,
#              {'headbanging': [(36, 39)],
#               'control': [(0, 7), (8, 14), (15, 21), (22, 28)]}),
#  'http://www.youtube.com/watch?v=Lex0gIMd73g': defaultdict(list,
#              {'headbanging': [(3, 10), (11, 17)],
#               'control': [(0, 2), (18, 19)]})}

# %%
# pickle this just incase 
import pickle 
with open("links_to_times.pkl", 'wb') as f:
    pickle.dump(links_to_times, f)

# %%
# RARELY RUN THIS - DELETES ALL VIDEOS IN ALL BEHAVIOR_DATA DIRS
for behavior in os.listdir("behavior_data"): 
    if behavior == ".DS_Store": continue 
    for file in os.listdir("behavior_data/" + behavior): 
        os.remove("behavior_data/" + behavior + "/" + file)

# %%
import cv2
import numpy as np
from moviepy.video.io.VideoFileClip import VideoFileClip
import pytube
FPS = 30 
i = 0 
for vid, (url, category_times) in enumerate((links_to_times.items())): 
    print(f"staring the {vid+1}th file")
    # download the video 
    print(url)
    try: 
        print("This is url: ", url)
        y = pytube.YouTube(url)
        video = y.streams.get_highest_resolution()
        video.download()
    except Exception as e:
        print(f"annoying url: {url}")
        print(e)
        continue 
        
    for category, times in category_times.items(): 
        folder_path = "behavior_data/" + category + "/"
        
        for start_time, end_time in times:
            try:
                input_file = y.streams.get_highest_resolution().default_filename
                output_file = folder_path + f"{i}.mp4"
                print(os.listdir(folder_path))
                if f"{i}.mp4" not in os.listdir(folder_path):
                    print("adding file")
                    with VideoFileClip(input_file) as video:
                        new = video.subclip(start_time, end_time)
                        new.write_videofile(output_file, audio_codec='aac')
                        i += 1 
            except Exception as e:
                print(f"failed on {i}")
                i += 1 
    os.remove(y.streams.get_highest_resolution().default_filename)
# Out:
# staring the 1th file
# http://www.youtube.com/watch?v=Pqd9Vu-juPI
# This is url:  http://www.youtube.com/watch?v=Pqd9Vu-juPI
# chunk:   0%|          | 0/111 [00:00<?, ?it/s, now=None]
# []
# adding file
# Moviepy - Building video behavior_data/spinning/0.mp4.
# MoviePy - Writing audio in 0TEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video behavior_data/spinning/0.mp4
# chunk:   0%|          | 0/89 [00:00<?, ?it/s, now=None]
# Moviepy - Done !
# Moviepy - video ready behavior_data/spinning/0.mp4
# []
# adding file
# Moviepy - Building video behavior_data/control/1.mp4.
# MoviePy - Writing audio in 1TEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video behavior_data/control/1.mp4
# chunk:   0%|          | 0/89 [00:00<?, ?it/s, now=None]
# Moviepy - Done !
# Moviepy - video ready behavior_data/control/1.mp4
# ['1.mp4']
# adding file
# Moviepy - Building video behavior_data/control/2.mp4.
# MoviePy - Writing audio in 2TEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video behavior_data/control/2.mp4
#
# Moviepy - Done !
# Moviepy - video ready behavior_data/control/2.mp4
# chunk:   0%|          | 0/155 [00:00<?, ?it/s, now=None]
# ['1.mp4', '2.mp4']
# adding file
# Moviepy - Building video behavior_data/control/3.mp4.
# MoviePy - Writing audio in 3TEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video behavior_data/control/3.mp4
# chunk:   0%|          | 0/155 [00:00<?, ?it/s, now=None]
# Moviepy - Done !
# Moviepy - video ready behavior_data/control/3.mp4
# ['1.mp4', '2.mp4', '3.mp4']
# adding file
# Moviepy - Building video behavior_data/control/4.mp4.
# MoviePy - Writing audio in 4TEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video behavior_data/control/4.mp4
#
# Moviepy - Done !
# Moviepy - video ready behavior_data/control/4.mp4
# staring the 2th file
# http://www.youtube.com/watch?v=yMgx2lVjf5I
# This is url:  http://www.youtube.com/watch?v=yMgx2lVjf5I
# chunk:   0%|          | 0/133 [00:00<?, ?it/s, now=None]
# []
# adding file
# Moviepy - Building video behavior_data/headbanging/5.mp4.
# MoviePy - Writing audio in 5TEMP_MPY_wvf_snd.mp4
# t:  36%|███▌      | 65/180 [00:00<00:00, 643.30it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video behavior_data/headbanging/5.mp4
# chunk:   0%|          | 0/155 [00:00<?, ?it/s, now=None]
# Moviepy - Done !
# Moviepy - video ready behavior_data/headbanging/5.mp4
# ['5.mp4']
# adding file
# Moviepy - Building video behavior_data/headbanging/6.mp4.
# MoviePy - Writing audio in 6TEMP_MPY_wvf_snd.mp4
# t:  32%|███▏      | 67/210 [00:00<00:00, 668.10it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video behavior_data/headbanging/6.mp4
# chunk:   0%|          | 0/155 [00:00<?, ?it/s, now=None]
# Moviepy - Done !
# Moviepy - video ready behavior_data/headbanging/6.mp4
# ['6.mp4', '5.mp4']
# adding file
# Moviepy - Building video behavior_data/headbanging/7.mp4.
# MoviePy - Writing audio in 7TEMP_MPY_wvf_snd.mp4
# t:  31%|███       | 65/210 [00:00<00:00, 648.23it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video behavior_data/headbanging/7.mp4
# chunk:   0%|          | 0/133 [00:00<?, ?it/s, now=None]
# Moviepy - Done !
# Moviepy - video ready behavior_data/headbanging/7.mp4
# ['7.mp4', '6.mp4', '5.mp4']
# adding file
# Moviepy - Building video behavior_data/headbanging/8.mp4.
# MoviePy - Writing audio in 8TEMP_MPY_wvf_snd.mp4
# t:  40%|████      | 72/180 [00:00<00:00, 690.29it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video behavior_data/headbanging/8.mp4
# chunk:   0%|          | 0/1 [00:00<?, ?it/s, now=None]
# Moviepy - Done !
# Moviepy - video ready behavior_data/headbanging/8.mp4
# ['4.mp4', '1.mp4', '2.mp4', '3.mp4']
# adding file
# Moviepy - Building video behavior_data/control/9.mp4.
# MoviePy - Writing audio in 9TEMP_MPY_wvf_snd.mp4
# failed on 9
# ['4.mp4', '1.mp4', '2.mp4', '3.mp4']
# adding file
# chunk: 100%|██████████| 1/1 [00:00<00:00,  5.83it/s, now=None]
# chunk:   0%|          | 0/89 [00:00<?, ?it/s, now=None]
# chunk: 100%|██████████| 1/1 [00:00<00:00,  3.39it/s, now=None]
# t:   0%|          | 0/120 [00:00<?, ?it/s, now=None]
# Moviepy - Building video behavior_data/control/10.mp4.
# MoviePy - Writing audio in 10TEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video behavior_data/control/10.mp4
# t:  57%|█████▋    | 68/120 [00:00<00:00, 677.97it/s, now=None]
# chunk: 100%|██████████| 1/1 [00:00<00:00,  1.31it/s, now=None]
# chunk:   0%|          | 0/89 [00:00<?, ?it/s, now=None]
# Moviepy - Done !
# Moviepy - video ready behavior_data/control/10.mp4
# ['4.mp4', '1.mp4', '2.mp4', '3.mp4', '10.mp4']
# adding file
# Moviepy - Building video behavior_data/control/11.mp4.
# MoviePy - Writing audio in 11TEMP_MPY_wvf_snd.mp4
# chunk: 100%|██████████| 1/1 [00:00<00:00,  1.20it/s, now=None]
# t:   0%|          | 0/120 [00:00<?, ?it/s, now=None]
# t:  60%|██████    | 72/120 [00:00<00:00, 698.07it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video behavior_data/control/11.mp4
# chunk: 100%|██████████| 1/1 [00:01<00:00,  1.28s/it, now=None]
# chunk:   0%|          | 0/89 [00:00<?, ?it/s, now=None]
# Moviepy - Done !
# Moviepy - video ready behavior_data/control/11.mp4
# ['4.mp4', '1.mp4', '2.mp4', '3.mp4', '11.mp4', '10.mp4']
# adding file
# Moviepy - Building video behavior_data/control/12.mp4.
# MoviePy - Writing audio in 12TEMP_MPY_wvf_snd.mp4
# chunk: 100%|██████████| 1/1 [00:01<00:00,  1.36s/it, now=None]
# t:   0%|          | 0/120 [00:00<?, ?it/s, now=None]
# t:  59%|█████▉    | 71/120 [00:00<00:00, 703.54it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video behavior_data/control/12.mp4
# chunk: 100%|██████████| 1/1 [00:01<00:00,  1.65s/it, now=None]
# Moviepy - Done !
# Moviepy - video ready behavior_data/control/12.mp4
# staring the 3th file
# http://www.youtube.com/watch?v=WRGUUOZ5_wA
# This is url:  http://www.youtube.com/watch?v=WRGUUOZ5_wA
# chunk: 100%|██████████| 1/1 [02:19<00:00, 139.84s/it, now=None]
# []
# adding file
# Moviepy - Building video behavior_data/armflapping/13.mp4.
# MoviePy - Writing audio in 13TEMP_MPY_wvf_snd.mp4
# chunk:   0%|          | 0/155 [00:00<?, ?it/s, now=None]
# chunk:  88%|████████▊ | 136/155 [00:00<00:00, 1356.06it/s, now=None]
# chunk: 100%|██████████| 1/1 [02:19<00:00, 139.97s/it, now=None]
# t:   0%|          | 0/168 [00:00<?, ?it/s, now=None]
# t:  18%|█▊        | 30/168 [00:00<00:00, 292.34it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video behavior_data/armflapping/13.mp4
# t:  36%|███▌      | 60/168 [00:00<00:00, 217.00it/s, now=None]
# t:  49%|████▉     | 83/168 [00:00<00:00, 188.26it/s, now=None]
# t:  61%|██████▏   | 103/168 [00:00<00:00, 180.21it/s, now=None]
# t:  73%|███████▎  | 122/168 [00:00<00:00, 171.31it/s, now=None]
# t:  83%|████████▎ | 140/168 [00:00<00:00, 161.07it/s, now=None]
# t:  93%|█████████▎| 157/168 [00:00<00:00, 152.29it/s, now=None]
# chunk: 100%|██████████| 1/1 [02:21<00:00, 141.37s/it, now=None]
# Moviepy - Done !
# Moviepy - video ready behavior_data/armflapping/13.mp4
# ['13.mp4']
# adding file
# chunk: 100%|██████████| 1/1 [02:21<00:00, 141.81s/it, now=None]
# chunk:   0%|          | 0/155 [00:00<?, ?it/s, now=None]
# chunk:  72%|███████▏  | 112/155 [00:00<00:00, 1116.55it/s, now=None]
# chunk: 100%|██████████| 1/1 [02:21<00:00, 141.95s/it, now=None]
# t:   0%|          | 0/168 [00:00<?, ?it/s, now=None]
# Moviepy - Building video behavior_data/armflapping/14.mp4.
# MoviePy - Writing audio in 14TEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video behavior_data/armflapping/14.mp4
# t:  18%|█▊        | 30/168 [00:00<00:00, 288.08it/s, now=None]
# t:  35%|███▌      | 59/168 [00:00<00:00, 233.03it/s, now=None]
# t:  49%|████▉     | 83/168 [00:00<00:00, 209.81it/s, now=None]
# t:  62%|██████▎   | 105/168 [00:00<00:00, 203.84it/s, now=None]
# t:  75%|███████▌  | 126/168 [00:00<00:00, 187.34it/s, now=None]
# t:  86%|████████▋ | 145/168 [00:00<00:00, 170.06it/s, now=None]
# t:  97%|█████████▋| 163/168 [00:00<00:00, 163.05it/s, now=None]
# chunk: 100%|██████████| 1/1 [02:23<00:00, 143.31s/it, now=None]
# Moviepy - Done !
# Moviepy - video ready behavior_data/armflapping/14.mp4
# ['4.mp4', '1.mp4', '2.mp4', '3.mp4', '11.mp4', '10.mp4', '12.mp4']
# adding file
# chunk: 100%|██████████| 1/1 [02:23<00:00, 143.62s/it, now=None]
# chunk:   0%|          | 0/155 [00:00<?, ?it/s, now=None]
# chunk: 100%|██████████| 1/1 [02:23<00:00, 143.72s/it, now=None]
# t:   0%|          | 0/168 [00:00<?, ?it/s, now=None]
# Moviepy - Building video behavior_data/control/15.mp4.
# MoviePy - Writing audio in 15TEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video behavior_data/control/15.mp4
# t:  17%|█▋        | 28/168 [00:00<00:00, 274.58it/s, now=None]
# t:  33%|███▎      | 56/168 [00:00<00:00, 246.08it/s, now=None]
# t:  48%|████▊     | 81/168 [00:00<00:00, 177.90it/s, now=None]
# t:  60%|██████    | 101/168 [00:00<00:00, 175.36it/s, now=None]
# t:  71%|███████▏  | 120/168 [00:00<00:00, 177.52it/s, now=None]
# t:  83%|████████▎ | 139/168 [00:00<00:00, 180.06it/s, now=None]
# t:  94%|█████████▍| 158/168 [00:00<00:00, 180.87it/s, now=None]
# chunk: 100%|██████████| 1/1 [02:24<00:00, 144.89s/it, now=None]
# Moviepy - Done !
# Moviepy - video ready behavior_data/control/15.mp4
# ['4.mp4', '1.mp4', '2.mp4', '3.mp4', '15.mp4', '11.mp4', '10.mp4', '12.mp4']
# adding file
# chunk: 100%|██████████| 1/1 [02:25<00:00, 145.30s/it, now=None]
# chunk:   0%|          | 0/155 [00:00<?, ?it/s, now=None]
# chunk: 100%|██████████| 1/1 [02:25<00:00, 145.41s/it, now=None]
# t:   0%|          | 0/168 [00:00<?, ?it/s, now=None]
# Moviepy - Building video behavior_data/control/16.mp4.
# MoviePy - Writing audio in 16TEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video behavior_data/control/16.mp4
# t:  17%|█▋        | 28/168 [00:00<00:00, 278.31it/s, now=None]
# t:  33%|███▎      | 56/168 [00:00<00:00, 252.90it/s, now=None]
# t:  49%|████▉     | 82/168 [00:00<00:00, 213.28it/s, now=None]
# t:  62%|██████▏   | 104/168 [00:00<00:00, 215.10it/s, now=None]
# t:  76%|███████▌  | 128/168 [00:00<00:00, 222.41it/s, now=None]
# t:  90%|████████▉ | 151/168 [00:00<00:00, 208.70it/s, now=None]
# chunk: 100%|██████████| 1/1 [02:26<00:00, 146.40s/it, now=None]
# Moviepy - Done !
# Moviepy - video ready behavior_data/control/16.mp4
# ['4.mp4', '1.mp4', '2.mp4', '3.mp4', '16.mp4', '15.mp4', '11.mp4', '10.mp4', '12.mp4']
# adding file
# chunk: 100%|██████████| 1/1 [02:26<00:00, 146.83s/it, now=None]
# chunk:   0%|          | 0/155 [00:00<?, ?it/s, now=None]
# chunk: 100%|██████████| 1/1 [02:26<00:00, 146.93s/it, now=None]
# t:   0%|          | 0/168 [00:00<?, ?it/s, now=None]
# Moviepy - Building video behavior_data/control/17.mp4.
# MoviePy - Writing audio in 17TEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video behavior_data/control/17.mp4
# t:  17%|█▋        | 28/168 [00:00<00:00, 279.29it/s, now=None]
# t:  33%|███▎      | 56/168 [00:00<00:00, 259.45it/s, now=None]
# t:  49%|████▉     | 83/168 [00:00<00:00, 189.81it/s, now=None]
# t:  62%|██████▏   | 104/168 [00:00<00:00, 162.24it/s, now=None]
# t:  73%|███████▎  | 122/168 [00:00<00:00, 147.37it/s, now=None]
# t:  86%|████████▌ | 144/168 [00:00<00:00, 164.50it/s, now=None]
# t:  96%|█████████▋| 162/168 [00:00<00:00, 156.77it/s, now=None]
# chunk: 100%|██████████| 1/1 [02:28<00:00, 148.30s/it, now=None]
# Moviepy - Done !
# Moviepy - video ready behavior_data/control/17.mp4
# ['4.mp4', '1.mp4', '2.mp4', '3.mp4', '17.mp4', '16.mp4', '15.mp4', '11.mp4', '10.mp4', '12.mp4']
# adding file
# chunk: 100%|██████████| 1/1 [02:28<00:00, 148.74s/it, now=None]
# chunk:   0%|          | 0/155 [00:00<?, ?it/s, now=None]
# chunk: 100%|██████████| 1/1 [02:28<00:00, 148.84s/it, now=None]
# t:   0%|          | 0/168 [00:00<?, ?it/s, now=None]
# Moviepy - Building video behavior_data/control/18.mp4.
# MoviePy - Writing audio in 18TEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video behavior_data/control/18.mp4
# t:  15%|█▌        | 26/168 [00:00<00:00, 259.92it/s, now=None]
# t:  31%|███       | 52/168 [00:00<00:00, 249.59it/s, now=None]
# t:  46%|████▌     | 77/168 [00:00<00:00, 191.32it/s, now=None]
# t:  58%|█████▊    | 98/168 [00:00<00:00, 173.76it/s, now=None]
# t:  70%|██████▉   | 117/168 [00:00<00:00, 152.39it/s, now=None]
# t:  79%|███████▉  | 133/168 [00:00<00:00, 150.59it/s, now=None]
# t:  90%|█████████ | 152/168 [00:00<00:00, 160.17it/s, now=None]
# chunk: 100%|██████████| 1/1 [02:30<00:00, 150.13s/it, now=None]
# Moviepy - Done !
# Moviepy - video ready behavior_data/control/18.mp4
# staring the 4th file
# http://www.youtube.com/watch?v=8vFUIFEfRpA
# This is url:  http://www.youtube.com/watch?v=8vFUIFEfRpA
# ['14.mp4', '13.mp4']
# adding file
# chunk: 100%|██████████| 1/1 [03:52<00:00, 232.91s/it, now=None]
# chunk:   0%|          | 0/133 [00:00<?, ?it/s, now=None]
# chunk: 100%|██████████| 1/1 [03:52<00:00, 232.99s/it, now=None]
# t:   0%|          | 0/90 [00:00<?, ?it/s, now=None]
# t:  30%|███       | 27/90 [00:00<00:00, 263.17it/s, now=None]
# Moviepy - Building video behavior_data/armflapping/19.mp4.
# MoviePy - Writing audio in 19TEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video behavior_data/armflapping/19.mp4
# t:  60%|██████    | 54/90 [00:00<00:00, 246.69it/s, now=None]
# t:  88%|████████▊ | 79/90 [00:00<00:00, 150.71it/s, now=None]
# chunk: 100%|██████████| 1/1 [03:54<00:00, 234.24s/it, now=None]A
# Moviepy - Done !
# Moviepy - video ready behavior_data/armflapping/19.mp4
# ['19.mp4', '14.mp4', '13.mp4']
# adding file
# chunk: 100%|██████████| 1/1 [03:54<00:00, 234.68s/it, now=None]
# chunk:   0%|          | 0/111 [00:00<?, ?it/s, now=None]
# chunk: 100%|██████████| 1/1 [03:54<00:00, 234.77s/it, now=None]
# t:   0%|          | 0/75 [00:00<?, ?it/s, now=None]
# t:  37%|███▋      | 28/75 [00:00<00:00, 277.59it/s, now=None]
# Moviepy - Building video behavior_data/armflapping/20.mp4.
# MoviePy - Writing audio in 20TEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video behavior_data/armflapping/20.mp4
# t:  75%|███████▍  | 56/75 [00:00<00:00, 247.86it/s, now=None]
# chunk: 100%|██████████| 1/1 [03:55<00:00, 235.86s/it, now=None]A
# Moviepy - Done !
# Moviepy - video ready behavior_data/armflapping/20.mp4
# ['4.mp4', '1.mp4', '2.mp4', '3.mp4', '18.mp4', '17.mp4', '16.mp4', '15.mp4', '11.mp4', '10.mp4', '12.mp4']
# adding file
# chunk: 100%|██████████| 1/1 [03:56<00:00, 236.22s/it, now=None]
# chunk:   0%|          | 0/23 [00:00<?, ?it/s, now=None]
# chunk: 100%|██████████| 1/1 [03:56<00:00, 236.26s/it, now=None]
# t:   0%|          | 0/15 [00:00<?, ?it/s, now=None]
# Moviepy - Building video behavior_data/control/21.mp4.
# MoviePy - Writing audio in 21TEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video behavior_data/control/21.mp4
# chunk: 100%|██████████| 1/1 [03:56<00:00, 236.54s/it, now=None]
# Moviepy - Done !
# Moviepy - video ready behavior_data/control/21.mp4
# ['4.mp4', '1.mp4', '2.mp4', '3.mp4', '21.mp4', '18.mp4', '17.mp4', '16.mp4', '15.mp4', '11.mp4', '10.mp4', '12.mp4']
# adding file
# chunk: 100%|██████████| 1/1 [03:57<00:00, 237.01s/it, now=None]
# chunk:   0%|          | 0/133 [00:00<?, ?it/s, now=None]
# chunk: 100%|██████████| 1/1 [03:57<00:00, 237.10s/it, now=None]
# t:   0%|          | 0/90 [00:00<?, ?it/s, now=None]
# t:  31%|███       | 28/90 [00:00<00:00, 276.54it/s, now=None]
# Moviepy - Building video behavior_data/control/22.mp4.
# MoviePy - Writing audio in 22TEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video behavior_data/control/22.mp4
# t:  62%|██████▏   | 56/90 [00:00<00:00, 255.14it/s, now=None]
# t:  91%|█████████ | 82/90 [00:00<00:00, 137.11it/s, now=None]
# chunk: 100%|██████████| 1/1 [03:58<00:00, 238.38s/it, now=None]A
# Moviepy - Done !
# Moviepy - video ready behavior_data/control/22.mp4
# ['4.mp4', '1.mp4', '2.mp4', '3.mp4', '22.mp4', '21.mp4', '18.mp4', '17.mp4', '16.mp4', '15.mp4', '11.mp4', '10.mp4', '12.mp4']
# adding file
# chunk: 100%|██████████| 1/1 [03:58<00:00, 238.85s/it, now=None]
# chunk:   0%|          | 0/133 [00:00<?, ?it/s, now=None]
# chunk: 100%|██████████| 1/1 [03:58<00:00, 238.96s/it, now=None]
# t:   0%|          | 0/90 [00:00<?, ?it/s, now=None]
# Moviepy - Building video behavior_data/control/23.mp4.
# MoviePy - Writing audio in 23TEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video behavior_data/control/23.mp4
# t:  32%|███▏      | 29/90 [00:00<00:00, 289.14it/s, now=None]
# t:  64%|██████▍   | 58/90 [00:00<00:00, 191.26it/s, now=None]
# t:  89%|████████▉ | 80/90 [00:00<00:00, 168.10it/s, now=None]
# chunk: 100%|██████████| 1/1 [04:00<00:00, 240.15s/it, now=None]A
# Moviepy - Done !
# Moviepy - video ready behavior_data/control/23.mp4
# ['4.mp4', '1.mp4', '2.mp4', '3.mp4', '22.mp4', '23.mp4', '21.mp4', '18.mp4', '17.mp4', '16.mp4', '15.mp4', '11.mp4', '10.mp4', '12.mp4']
# adding file
# chunk: 100%|██████████| 1/1 [04:00<00:00, 240.62s/it, now=None]
# chunk:   0%|          | 0/111 [00:00<?, ?it/s, now=None]
# chunk: 100%|██████████| 1/1 [04:00<00:00, 240.71s/it, now=None]
# t:   0%|          | 0/75 [00:00<?, ?it/s, now=None]
# Moviepy - Building video behavior_data/control/24.mp4.
# MoviePy - Writing audio in 24TEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video behavior_data/control/24.mp4
# t:  39%|███▊      | 29/75 [00:00<00:00, 286.60it/s, now=None]
# t:  77%|███████▋  | 58/75 [00:00<00:00, 198.66it/s, now=None]
# chunk: 100%|██████████| 1/1 [04:01<00:00, 241.74s/it, now=None]A
# Moviepy - Done !
# Moviepy - video ready behavior_data/control/24.mp4
# staring the 5th file
# http://www.youtube.com/watch?v=SOc13pnf-Dc
# This is url:  http://www.youtube.com/watch?v=SOc13pnf-Dc
# ['20.mp4', '19.mp4', '14.mp4', '13.mp4']
# adding file
# chunk: 100%|██████████| 1/1 [13:45<00:00, 825.96s/it, now=None]
# chunk:   0%|          | 0/133 [00:00<?, ?it/s, now=None]
# chunk: 100%|██████████| 1/1 [13:46<00:00, 826.08s/it, now=None]
# t:   0%|          | 0/180 [00:00<?, ?it/s, now=None]
# Moviepy - Building video behavior_data/armflapping/25.mp4.
# MoviePy - Writing audio in 25TEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video behavior_data/armflapping/25.mp4
# t:  17%|█▋        | 30/180 [00:00<00:00, 293.04it/s, now=None]
# t:  33%|███▎      | 60/180 [00:00<00:00, 195.33it/s, now=None]
# t:  46%|████▌     | 82/180 [00:00<00:00, 163.72it/s, now=None]
# t:  56%|█████▌    | 100/180 [00:00<00:00, 140.42it/s, now=None]
# t:  64%|██████▍   | 115/180 [00:00<00:00, 140.03it/s, now=None]
# t:  76%|███████▌  | 137/180 [00:00<00:00, 160.06it/s, now=None]
# t:  87%|████████▋ | 156/180 [00:00<00:00, 164.81it/s, now=None]
# t:  97%|█████████▋| 174/180 [00:01<00:00, 161.66it/s, now=None]
# chunk: 100%|██████████| 1/1 [13:47<00:00, 827.55s/it, now=None]
# Moviepy - Done !
# Moviepy - video ready behavior_data/armflapping/25.mp4
# ['20.mp4', '25.mp4', '19.mp4', '14.mp4', '13.mp4']
# adding file
# chunk: 100%|██████████| 1/1 [13:48<00:00, 828.16s/it, now=None]
# chunk:   0%|          | 0/133 [00:00<?, ?it/s, now=None]
# chunk:  92%|█████████▏| 122/133 [00:00<00:00, 1217.58it/s, now=None]
# chunk: 100%|██████████| 1/1 [13:48<00:00, 828.28s/it, now=None]
# t:   0%|          | 0/180 [00:00<?, ?it/s, now=None]
# Moviepy - Building video behavior_data/armflapping/26.mp4.
# MoviePy - Writing audio in 26TEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video behavior_data/armflapping/26.mp4
# t:  16%|█▌        | 28/180 [00:00<00:00, 279.99it/s, now=None]
# t:  31%|███       | 56/180 [00:00<00:00, 265.32it/s, now=None]
# t:  46%|████▌     | 83/180 [00:00<00:00, 186.33it/s, now=None]
# t:  58%|█████▊    | 104/180 [00:00<00:00, 178.45it/s, now=None]
# t:  69%|██████▉   | 124/180 [00:00<00:00, 169.00it/s, now=None]
# t:  79%|███████▉  | 142/180 [00:00<00:00, 160.43it/s, now=None]
# t:  88%|████████▊ | 159/180 [00:00<00:00, 152.46it/s, now=None]
# t:  98%|█████████▊| 176/180 [00:01<00:00, 156.15it/s, now=None]
# chunk: 100%|██████████| 1/1 [13:49<00:00, 829.69s/it, now=None]
# Moviepy - Done !
# Moviepy - video ready behavior_data/armflapping/26.mp4
# ['20.mp4', '25.mp4', '19.mp4', '26.mp4', '14.mp4', '13.mp4']
# adding file
# chunk: 100%|██████████| 1/1 [13:50<00:00, 830.30s/it, now=None]
# chunk:   0%|          | 0/133 [00:00<?, ?it/s, now=None]
# chunk:  93%|█████████▎| 124/133 [00:00<00:00, 1234.28it/s, now=None]
# chunk: 100%|██████████| 1/1 [13:50<00:00, 830.43s/it, now=None]
# t:   0%|          | 0/180 [00:00<?, ?it/s, now=None]
# Moviepy - Building video behavior_data/armflapping/27.mp4.
# MoviePy - Writing audio in 27TEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video behavior_data/armflapping/27.mp4
# t:  16%|█▌        | 29/180 [00:00<00:00, 281.43it/s, now=None]
# t:  32%|███▏      | 58/180 [00:00<00:00, 200.03it/s, now=None]
# t:  44%|████▍     | 80/180 [00:00<00:00, 187.83it/s, now=None]
# t:  56%|█████▌    | 100/180 [00:00<00:00, 172.21it/s, now=None]
# t:  66%|██████▌   | 118/180 [00:00<00:00, 171.18it/s, now=None]
# t:  76%|███████▌  | 136/180 [00:00<00:00, 155.29it/s, now=None]
# t:  84%|████████▍ | 152/180 [00:00<00:00, 151.26it/s, now=None]
# t:  94%|█████████▍| 169/180 [00:01<00:00, 154.98it/s, now=None]
# chunk: 100%|██████████| 1/1 [13:51<00:00, 831.90s/it, now=None]
# Moviepy - Done !
# Moviepy - video ready behavior_data/armflapping/27.mp4
# ['20.mp4', '25.mp4', '19.mp4', '27.mp4', '26.mp4', '14.mp4', '13.mp4']
# adding file
# chunk: 100%|██████████| 1/1 [13:52<00:00, 832.53s/it, now=None]
# chunk:   0%|          | 0/89 [00:00<?, ?it/s, now=None]
# chunk: 100%|██████████| 1/1 [13:52<00:00, 832.63s/it, now=None]
# t:   0%|          | 0/120 [00:00<?, ?it/s, now=None]
# Moviepy - Building video behavior_data/armflapping/28.mp4.
# MoviePy - Writing audio in 28TEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video behavior_data/armflapping/28.mp4
# t:  22%|██▎       | 27/120 [00:00<00:00, 269.08it/s, now=None]
# t:  45%|████▌     | 54/120 [00:00<00:00, 250.48it/s, now=None]
# t:  67%|██████▋   | 80/120 [00:00<00:00, 165.71it/s, now=None]
# t:  82%|████████▎ | 99/120 [00:00<00:00, 153.29it/s, now=None]
# t:  97%|█████████▋| 116/120 [00:00<00:00, 145.88it/s, now=None]
# chunk: 100%|██████████| 1/1 [13:53<00:00, 833.81s/it, now=None]
# Moviepy - Done !
# Moviepy - video ready behavior_data/armflapping/28.mp4
# ['20.mp4', '25.mp4', '19.mp4', '27.mp4', '26.mp4', '14.mp4', '28.mp4', '13.mp4']
# adding file
# chunk: 100%|██████████| 1/1 [13:54<00:00, 834.44s/it, now=None]
# chunk:   0%|          | 0/67 [00:00<?, ?it/s, now=None]
# chunk: 100%|██████████| 1/1 [13:54<00:00, 834.54s/it, now=None]
# t:   0%|          | 0/90 [00:00<?, ?it/s, now=None]
# Moviepy - Building video behavior_data/armflapping/29.mp4.
# MoviePy - Writing audio in 29TEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video behavior_data/armflapping/29.mp4
# t:  31%|███       | 28/90 [00:00<00:00, 277.36it/s, now=None]
# t:  62%|██████▏   | 56/90 [00:00<00:00, 250.98it/s, now=None]
# t:  91%|█████████ | 82/90 [00:00<00:00, 165.85it/s, now=None]
# chunk: 100%|██████████| 1/1 [13:55<00:00, 835.54s/it, now=None]A
# Moviepy - Done !
# Moviepy - video ready behavior_data/armflapping/29.mp4
# chunk: 100%|██████████| 1/1 [13:56<00:00, 836.05s/it, now=None]
# chunk:   0%|          | 0/155 [00:00<?, ?it/s, now=None]
# ['4.mp4', '1.mp4', '2.mp4', '3.mp4', '22.mp4', '23.mp4', '21.mp4', '18.mp4', '24.mp4', '17.mp4', '16.mp4', '15.mp4', '11.mp4', '10.mp4', '12.mp4']
# adding file
# Moviepy - Building video behavior_data/control/30.mp4.
# MoviePy - Writing audio in 30TEMP_MPY_wvf_snd.mp4
# chunk: 100%|██████████| 1/1 [13:56<00:00, 836.14s/it, now=None]
# t:   0%|          | 0/210 [00:00<?, ?it/s, now=None]
# t:  13%|█▎        | 27/210 [00:00<00:00, 269.88it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video behavior_data/control/30.mp4
# t:  26%|██▌       | 54/210 [00:00<00:00, 248.56it/s, now=None]
# t:  38%|███▊      | 79/210 [00:00<00:00, 162.66it/s, now=None]
# t:  47%|████▋     | 98/210 [00:00<00:00, 142.73it/s, now=None]
# t:  54%|█████▍    | 114/210 [00:00<00:00, 141.73it/s, now=None]
# t:  62%|██████▏   | 130/210 [00:00<00:00, 134.09it/s, now=None]
# t:  69%|██████▊   | 144/210 [00:00<00:00, 129.07it/s, now=None]
# t:  76%|███████▌  | 159/210 [00:01<00:00, 133.66it/s, now=None]
# t:  82%|████████▏ | 173/210 [00:01<00:00, 129.16it/s, now=None]
# t:  89%|████████▉ | 187/210 [00:01<00:00, 131.16it/s, now=None]
# t:  97%|█████████▋| 203/210 [00:01<00:00, 139.07it/s, now=None]
# chunk: 100%|██████████| 1/1 [13:58<00:00, 838.06s/it, now=None]
# Moviepy - Done !
# Moviepy - video ready behavior_data/control/30.mp4
# ['4.mp4', '1.mp4', '2.mp4', '3.mp4', '22.mp4', '23.mp4', '21.mp4', '18.mp4', '24.mp4', '30.mp4', '17.mp4', '16.mp4', '15.mp4', '11.mp4', '10.mp4', '12.mp4']
# adding file
# chunk: 100%|██████████| 1/1 [13:58<00:00, 838.69s/it, now=None]
# chunk:   0%|          | 0/155 [00:00<?, ?it/s, now=None]
# chunk: 100%|██████████| 1/1 [13:58<00:00, 838.78s/it, now=None]
# t:   0%|          | 0/210 [00:00<?, ?it/s, now=None]
# Moviepy - Building video behavior_data/control/31.mp4.
# MoviePy - Writing audio in 31TEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video behavior_data/control/31.mp4
# t:  14%|█▍        | 30/210 [00:00<00:00, 294.91it/s, now=None]
# t:  29%|██▊       | 60/210 [00:00<00:00, 192.27it/s, now=None]
# t:  39%|███▉      | 82/210 [00:00<00:00, 168.45it/s, now=None]
# t:  48%|████▊     | 100/210 [00:00<00:00, 145.31it/s, now=None]
# t:  57%|█████▋    | 119/210 [00:00<00:00, 154.87it/s, now=None]
# t:  65%|██████▍   | 136/210 [00:00<00:00, 143.02it/s, now=None]
# t:  72%|███████▏  | 151/210 [00:01<00:00, 130.36it/s, now=None]
# t:  80%|███████▉  | 167/210 [00:01<00:00, 136.21it/s, now=None]
# t:  87%|████████▋ | 182/210 [00:01<00:00, 132.07it/s, now=None]
# t:  93%|█████████▎| 196/210 [00:01<00:00, 132.08it/s, now=None]
# chunk: 100%|██████████| 1/1 [14:00<00:00, 840.70s/it, now=None]
# Moviepy - Done !
# Moviepy - video ready behavior_data/control/31.mp4
# ['4.mp4', '1.mp4', '2.mp4', '3.mp4', '22.mp4', '23.mp4', '21.mp4', '18.mp4', '24.mp4', '30.mp4', '31.mp4', '17.mp4', '16.mp4', '15.mp4', '11.mp4', '10.mp4', '12.mp4']
# adding file
# chunk: 100%|██████████| 1/1 [14:01<00:00, 841.32s/it, now=None]
# chunk:   0%|          | 0/133 [00:00<?, ?it/s, now=None]
# chunk: 100%|██████████| 1/1 [14:01<00:00, 841.41s/it, now=None]
# t:   0%|          | 0/180 [00:00<?, ?it/s, now=None]
# Moviepy - Building video behavior_data/control/32.mp4.
# MoviePy - Writing audio in 32TEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video behavior_data/control/32.mp4
# t:  16%|█▌        | 29/180 [00:00<00:00, 280.23it/s, now=None]
# t:  32%|███▏      | 58/180 [00:00<00:00, 189.18it/s, now=None]
# t:  44%|████▍     | 79/180 [00:00<00:00, 171.95it/s, now=None]
# t:  54%|█████▍    | 98/180 [00:00<00:00, 158.47it/s, now=None]
# t:  64%|██████▍   | 115/180 [00:00<00:00, 146.22it/s, now=None]
# t:  72%|███████▏  | 130/180 [00:00<00:00, 142.21it/s, now=None]
# t:  81%|████████  | 145/180 [00:00<00:00, 142.54it/s, now=None]
# t:  89%|████████▉ | 160/180 [00:01<00:00, 133.29it/s, now=None]
# t:  97%|█████████▋| 174/180 [00:01<00:00, 130.10it/s, now=None]
# chunk: 100%|██████████| 1/1 [14:03<00:00, 843.12s/it, now=None]
# Moviepy - Done !
# Moviepy - video ready behavior_data/control/32.mp4
# ['4.mp4', '1.mp4', '2.mp4', '3.mp4', '22.mp4', '23.mp4', '21.mp4', '18.mp4', '24.mp4', '30.mp4', '31.mp4', '32.mp4', '17.mp4', '16.mp4', '15.mp4', '11.mp4', '10.mp4', '12.mp4']
# adding file
# chunk: 100%|██████████| 1/1 [14:03<00:00, 843.81s/it, now=None]
# chunk:   0%|          | 0/133 [00:00<?, ?it/s, now=None]
# chunk: 100%|██████████| 1/1 [14:03<00:00, 843.92s/it, now=None]
# t:   0%|          | 0/180 [00:00<?, ?it/s, now=None]
# Moviepy - Building video behavior_data/control/33.mp4.
# MoviePy - Writing audio in 33TEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video behavior_data/control/33.mp4
# t:  16%|█▌        | 29/180 [00:00<00:00, 287.24it/s, now=None]
# t:  32%|███▏      | 58/180 [00:00<00:00, 189.72it/s, now=None]
# t:  44%|████▍     | 79/180 [00:00<00:00, 170.50it/s, now=None]
# t:  54%|█████▍    | 98/180 [00:00<00:00, 156.97it/s, now=None]
# t:  64%|██████▍   | 115/180 [00:00<00:00, 147.47it/s, now=None]
# t:  73%|███████▎  | 131/180 [00:00<00:00, 142.18it/s, now=None]
# t:  81%|████████  | 146/180 [00:00<00:00, 138.27it/s, now=None]
# t:  89%|████████▉ | 161/180 [00:01<00:00, 137.56it/s, now=None]
# t:  97%|█████████▋| 175/180 [00:01<00:00, 136.37it/s, now=None]
# chunk: 100%|██████████| 1/1 [14:05<00:00, 845.55s/it, now=None]
# Moviepy - Done !
# Moviepy - video ready behavior_data/control/33.mp4
# staring the 6th file
# http://www.youtube.com/watch?v=iDuAugAykcc
# This is url:  http://www.youtube.com/watch?v=iDuAugAykcc
# chunk: 100%|██████████| 1/1 [15:05<00:00, 905.92s/it, now=None]
# chunk:   0%|          | 0/89 [00:00<?, ?it/s, now=None]
# ['20.mp4', '25.mp4', '19.mp4', '27.mp4', '26.mp4', '14.mp4', '28.mp4', '29.mp4', '13.mp4']
# adding file
# Moviepy - Building video behavior_data/armflapping/34.mp4.
# MoviePy - Writing audio in 34TEMP_MPY_wvf_snd.mp4
# chunk: 100%|██████████| 1/1 [15:05<00:00, 905.99s/it, now=None]
# t:   0%|          | 0/96 [00:00<?, ?it/s, now=None]
# chunk: 100%|██████████| 1/1 [15:06<00:00, 906.17s/it, now=None]
# MoviePy - Done.
# Moviepy - Writing video behavior_data/armflapping/34.mp4
#
# Moviepy - Done !
# Moviepy - video ready behavior_data/armflapping/34.mp4
# chunk: 100%|██████████| 1/1 [15:06<00:00, 906.35s/it, now=None]
# chunk:   0%|          | 0/89 [00:00<?, ?it/s, now=None]
# ['34.mp4', '20.mp4', '25.mp4', '19.mp4', '27.mp4', '26.mp4', '14.mp4', '28.mp4', '29.mp4', '13.mp4']
# adding file
# Moviepy - Building video behavior_data/armflapping/35.mp4.
# MoviePy - Writing audio in 35TEMP_MPY_wvf_snd.mp4
# chunk: 100%|██████████| 1/1 [15:06<00:00, 906.43s/it, now=None]
# t:   0%|          | 0/96 [00:00<?, ?it/s, now=None]
# t: 100%|██████████| 96/96 [00:00<00:00, 918.23it/s, now=None]
# chunk: 100%|██████████| 1/1 [15:06<00:00, 906.62s/it, now=None]A
# MoviePy - Done.
# Moviepy - Writing video behavior_data/armflapping/35.mp4
#
# Moviepy - Done !
# Moviepy - video ready behavior_data/armflapping/35.mp4
# chunk: 100%|██████████| 1/1 [15:06<00:00, 906.80s/it, now=None]
# chunk:   0%|          | 0/89 [00:00<?, ?it/s, now=None]
# ['35.mp4', '34.mp4', '20.mp4', '25.mp4', '19.mp4', '27.mp4', '26.mp4', '14.mp4', '28.mp4', '29.mp4', '13.mp4']
# adding file
# Moviepy - Building video behavior_data/armflapping/36.mp4.
# MoviePy - Writing audio in 36TEMP_MPY_wvf_snd.mp4
# chunk: 100%|██████████| 1/1 [15:06<00:00, 906.89s/it, now=None]
# t:   0%|          | 0/96 [00:00<?, ?it/s, now=None]
# chunk: 100%|██████████| 1/1 [15:07<00:00, 907.07s/it, now=None]
# MoviePy - Done.
# Moviepy - Writing video behavior_data/armflapping/36.mp4
#
# Moviepy - Done !
# Moviepy - video ready behavior_data/armflapping/36.mp4
# chunk: 100%|██████████| 1/1 [15:07<00:00, 907.23s/it, now=None]
# chunk:   0%|          | 0/155 [00:00<?, ?it/s, now=None]
# ['36.mp4', '35.mp4', '34.mp4', '20.mp4', '25.mp4', '19.mp4', '27.mp4', '26.mp4', '14.mp4', '28.mp4', '29.mp4', '13.mp4']
# adding file
# Moviepy - Building video behavior_data/armflapping/37.mp4.
# MoviePy - Writing audio in 37TEMP_MPY_wvf_snd.mp4
# chunk:  95%|█████████▍| 147/155 [00:00<00:00, 1459.74it/s, now=None]
# chunk: 100%|██████████| 1/1 [15:07<00:00, 907.36s/it, now=None]
# t:   0%|          | 0/168 [00:00<?, ?it/s, now=None]
# t:  66%|██████▌   | 111/168 [00:00<00:00, 1069.06it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video behavior_data/armflapping/37.mp4
# chunk: 100%|██████████| 1/1 [15:07<00:00, 907.78s/it, now=None]
# chunk:   0%|          | 0/111 [00:00<?, ?it/s, now=None]
# Moviepy - Done !
# Moviepy - video ready behavior_data/armflapping/37.mp4
# ['36.mp4', '37.mp4', '35.mp4', '34.mp4', '20.mp4', '25.mp4', '19.mp4', '27.mp4', '26.mp4', '14.mp4', '28.mp4', '29.mp4', '13.mp4']
# adding file
# Moviepy - Building video behavior_data/armflapping/38.mp4.
# MoviePy - Writing audio in 38TEMP_MPY_wvf_snd.mp4
# chunk: 100%|██████████| 1/1 [15:07<00:00, 907.88s/it, now=None]
# t:   0%|          | 0/120 [00:00<?, ?it/s, now=None]
# t:  91%|█████████ | 109/120 [00:00<00:00, 1089.89it/s, now=None]
# chunk: 100%|██████████| 1/1 [15:08<00:00, 908.06s/it, now=None]
# MoviePy - Done.
# Moviepy - Writing video behavior_data/armflapping/38.mp4
#
# Moviepy - Done !
# Moviepy - video ready behavior_data/armflapping/38.mp4
# chunk: 100%|██████████| 1/1 [15:08<00:00, 908.25s/it, now=None]
# chunk:   0%|          | 0/111 [00:00<?, ?it/s, now=None]
# ['36.mp4', '37.mp4', '35.mp4', '34.mp4', '20.mp4', '25.mp4', '19.mp4', '27.mp4', '26.mp4', '14.mp4', '28.mp4', '29.mp4', '38.mp4', '13.mp4']
# adding file
# Moviepy - Building video behavior_data/armflapping/39.mp4.
# MoviePy - Writing audio in 39TEMP_MPY_wvf_snd.mp4
# chunk: 100%|██████████| 1/1 [15:08<00:00, 908.35s/it, now=None]
# t:   0%|          | 0/120 [00:00<?, ?it/s, now=None]
# t:  94%|█████████▍| 113/120 [00:00<00:00, 1101.29it/s, now=None]
# chunk: 100%|██████████| 1/1 [15:08<00:00, 908.54s/it, now=None]
# MoviePy - Done.
# Moviepy - Writing video behavior_data/armflapping/39.mp4
#
# Moviepy - Done !
# Moviepy - video ready behavior_data/armflapping/39.mp4
# chunk: 100%|██████████| 1/1 [15:08<00:00, 908.73s/it, now=None]
# chunk:   0%|          | 0/111 [00:00<?, ?it/s, now=None]
# ['36.mp4', '37.mp4', '35.mp4', '34.mp4', '20.mp4', '25.mp4', '19.mp4', '27.mp4', '26.mp4', '14.mp4', '28.mp4', '29.mp4', '39.mp4', '38.mp4', '13.mp4']
# adding file
# Moviepy - Building video behavior_data/armflapping/40.mp4.
# MoviePy - Writing audio in 40TEMP_MPY_wvf_snd.mp4
# chunk: 100%|██████████| 1/1 [15:08<00:00, 908.83s/it, now=None]
# t:   0%|          | 0/120 [00:00<?, ?it/s, now=None]
# t:  91%|█████████ | 109/120 [00:00<00:00, 1089.12it/s, now=None]
# chunk: 100%|██████████| 1/1 [15:09<00:00, 909.02s/it, now=None]
# MoviePy - Done.
# Moviepy - Writing video behavior_data/armflapping/40.mp4
#
# Moviepy - Done !
# Moviepy - video ready behavior_data/armflapping/40.mp4
# chunk: 100%|██████████| 1/1 [15:09<00:00, 909.17s/it, now=None]
# chunk:   0%|          | 0/111 [00:00<?, ?it/s, now=None]
# chunk: 100%|██████████| 1/1 [15:09<00:00, 909.25s/it, now=None]
# t:   0%|          | 0/120 [00:00<?, ?it/s, now=None]
# ['4.mp4', '1.mp4', '2.mp4', '3.mp4', '22.mp4', '23.mp4', '21.mp4', '18.mp4', '24.mp4', '30.mp4', '31.mp4', '33.mp4', '32.mp4', '17.mp4', '16.mp4', '15.mp4', '11.mp4', '10.mp4', '12.mp4']
# adding file
# Moviepy - Building video behavior_data/control/41.mp4.
# MoviePy - Writing audio in 41TEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video behavior_data/control/41.mp4
# t:  91%|█████████ | 109/120 [00:00<00:00, 1078.04it/s, now=None]
# chunk: 100%|██████████| 1/1 [15:09<00:00, 909.63s/it, now=None]
# chunk:   0%|          | 0/111 [00:00<?, ?it/s, now=None]
# Moviepy - Done !
# Moviepy - video ready behavior_data/control/41.mp4
# ['41.mp4', '4.mp4', '1.mp4', '2.mp4', '3.mp4', '22.mp4', '23.mp4', '21.mp4', '18.mp4', '24.mp4', '30.mp4', '31.mp4', '33.mp4', '32.mp4', '17.mp4', '16.mp4', '15.mp4', '11.mp4', '10.mp4', '12.mp4']
# adding file
# Moviepy - Building video behavior_data/control/42.mp4.
# MoviePy - Writing audio in 42TEMP_MPY_wvf_snd.mp4
# chunk: 100%|██████████| 1/1 [15:09<00:00, 909.71s/it, now=None]
# t:   0%|          | 0/120 [00:00<?, ?it/s, now=None]
# t:  89%|████████▉ | 107/120 [00:00<00:00, 1041.46it/s, now=None]
# chunk: 100%|██████████| 1/1 [15:09<00:00, 909.90s/it, now=None]
# MoviePy - Done.
# Moviepy - Writing video behavior_data/control/42.mp4
#
# Moviepy - Done !
# Moviepy - video ready behavior_data/control/42.mp4
# chunk: 100%|██████████| 1/1 [15:10<00:00, 910.08s/it, now=None]
# chunk:   0%|          | 0/111 [00:00<?, ?it/s, now=None]
# ['41.mp4', '42.mp4', '4.mp4', '1.mp4', '2.mp4', '3.mp4', '22.mp4', '23.mp4', '21.mp4', '18.mp4', '24.mp4', '30.mp4', '31.mp4', '33.mp4', '32.mp4', '17.mp4', '16.mp4', '15.mp4', '11.mp4', '10.mp4', '12.mp4']
# adding file
# Moviepy - Building video behavior_data/control/43.mp4.
# MoviePy - Writing audio in 43TEMP_MPY_wvf_snd.mp4
# chunk: 100%|██████████| 1/1 [15:10<00:00, 910.16s/it, now=None]
# t:   0%|          | 0/120 [00:00<?, ?it/s, now=None]
# t:  86%|████████▌ | 103/120 [00:00<00:00, 1027.49it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video behavior_data/control/43.mp4
# chunk: 100%|██████████| 1/1 [15:10<00:00, 910.55s/it, now=None]
# chunk:   0%|          | 0/89 [00:00<?, ?it/s, now=None]
# Moviepy - Done !
# Moviepy - video ready behavior_data/control/43.mp4
# ['41.mp4', '42.mp4', '4.mp4', '43.mp4', '1.mp4', '2.mp4', '3.mp4', '22.mp4', '23.mp4', '21.mp4', '18.mp4', '24.mp4', '30.mp4', '31.mp4', '33.mp4', '32.mp4', '17.mp4', '16.mp4', '15.mp4', '11.mp4', '10.mp4', '12.mp4']
# adding file
# Moviepy - Building video behavior_data/control/44.mp4.
# MoviePy - Writing audio in 44TEMP_MPY_wvf_snd.mp4
# chunk: 100%|██████████| 1/1 [15:10<00:00, 910.63s/it, now=None]
# t:   0%|          | 0/96 [00:00<?, ?it/s, now=None]
# chunk: 100%|██████████| 1/1 [15:10<00:00, 910.81s/it, now=None]
# MoviePy - Done.
# Moviepy - Writing video behavior_data/control/44.mp4
#
# Moviepy - Done !
# Moviepy - video ready behavior_data/control/44.mp4
# staring the 7th file
# http://www.youtube.com/watch?v=BUAFdqrw4fA
# This is url:  http://www.youtube.com/watch?v=BUAFdqrw4fA
# ['7.mp4', '6.mp4', '5.mp4', '8.mp4']
# adding file
# chunk: 100%|██████████| 1/1 [21:13<00:00, 1273.81s/it, now=None]
# chunk:   0%|          | 0/111 [00:00<?, ?it/s, now=None]
# chunk: 100%|██████████| 1/1 [21:13<00:00, 1273.89s/it, now=None]
# t:   0%|          | 0/150 [00:00<?, ?it/s, now=None]
# t:  20%|██        | 30/150 [00:00<00:00, 288.47it/s, now=None]
# Moviepy - Building video behavior_data/headbanging/45.mp4.
# MoviePy - Writing audio in 45TEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video behavior_data/headbanging/45.mp4
# t:  39%|███▉      | 59/150 [00:00<00:00, 184.81it/s, now=None]
# t:  53%|█████▎    | 80/150 [00:00<00:00, 163.91it/s, now=None]
# t:  65%|██████▌   | 98/150 [00:00<00:00, 159.16it/s, now=None]
# t:  77%|███████▋  | 115/150 [00:00<00:00, 148.75it/s, now=None]
# t:  87%|████████▋ | 131/150 [00:00<00:00, 146.96it/s, now=None]
# t:  97%|█████████▋| 146/150 [00:00<00:00, 144.90it/s, now=None]
# chunk: 100%|██████████| 1/1 [21:15<00:00, 1275.31s/it, now=None][A
# Moviepy - Done !
# Moviepy - video ready behavior_data/headbanging/45.mp4
# ['7.mp4', '6.mp4', '5.mp4', '45.mp4', '8.mp4']
# adding file
# chunk: 100%|██████████| 1/1 [21:15<00:00, 1275.64s/it, now=None]
# chunk:   0%|          | 0/89 [00:00<?, ?it/s, now=None]
# chunk: 100%|██████████| 1/1 [21:15<00:00, 1275.72s/it, now=None]
# t:   0%|          | 0/120 [00:00<?, ?it/s, now=None]
# t:  20%|██        | 24/120 [00:00<00:00, 237.34it/s, now=None]
# Moviepy - Building video behavior_data/headbanging/46.mp4.
# MoviePy - Writing audio in 46TEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video behavior_data/headbanging/46.mp4
# t:  40%|████      | 48/120 [00:00<00:00, 225.82it/s, now=None]
# t:  59%|█████▉    | 71/120 [00:00<00:00, 145.48it/s, now=None]
# t:  73%|███████▎  | 88/120 [00:00<00:00, 133.05it/s, now=None]
# t:  86%|████████▌ | 103/120 [00:00<00:00, 117.75it/s, now=None]
# t:  97%|█████████▋| 116/120 [00:00<00:00, 116.33it/s, now=None]
# chunk: 100%|██████████| 1/1 [21:17<00:00, 1277.22s/it, now=None][A
# Moviepy - Done !
# Moviepy - video ready behavior_data/headbanging/46.mp4
# ['7.mp4', '6.mp4', '5.mp4', '46.mp4', '45.mp4', '8.mp4']
# adding file
# chunk: 100%|██████████| 1/1 [21:17<00:00, 1277.63s/it, now=None]
# chunk:   0%|          | 0/133 [00:00<?, ?it/s, now=None]
# chunk:  78%|███████▊  | 104/133 [00:00<00:00, 1038.41it/s, now=None]
# chunk: 100%|██████████| 1/1 [21:17<00:00, 1277.77s/it, now=None]
# t:   0%|          | 0/180 [00:00<?, ?it/s, now=None]
# Moviepy - Building video behavior_data/headbanging/47.mp4.
# MoviePy - Writing audio in 47TEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video behavior_data/headbanging/47.mp4
# t:  11%|█         | 20/180 [00:00<00:00, 194.74it/s, now=None]
# t:  22%|██▏       | 40/180 [00:00<00:00, 195.40it/s, now=None]
# t:  33%|███▎      | 60/180 [00:00<00:00, 127.30it/s, now=None]
# t:  42%|████▏     | 75/180 [00:00<00:00, 121.00it/s, now=None]
# t:  49%|████▉     | 89/180 [00:00<00:00, 117.27it/s, now=None]
# t:  57%|█████▋    | 102/180 [00:00<00:00, 111.61it/s, now=None]
# t:  63%|██████▎   | 114/180 [00:00<00:00, 104.71it/s, now=None]
# t:  69%|██████▉   | 125/180 [00:01<00:00, 99.68it/s, now=None]
# t:  76%|███████▌  | 136/180 [00:01<00:00, 94.00it/s, now=None]
# t:  81%|████████  | 146/180 [00:01<00:00, 95.31it/s, now=None]
# t:  87%|████████▋ | 156/180 [00:01<00:00, 93.23it/s, now=None]
# t:  92%|█████████▏| 166/180 [00:01<00:00, 89.91it/s, now=None]
# t:  98%|█████████▊| 176/180 [00:01<00:00, 89.54it/s, now=None]
# chunk: 100%|██████████| 1/1 [21:20<00:00, 1280.10s/it, now=None]A
# Moviepy - Done !
# Moviepy - video ready behavior_data/headbanging/47.mp4
# ['7.mp4', '6.mp4', '5.mp4', '47.mp4', '46.mp4', '45.mp4', '8.mp4']
# adding file
# chunk: 100%|██████████| 1/1 [21:20<00:00, 1280.51s/it, now=None]
# chunk:   0%|          | 0/111 [00:00<?, ?it/s, now=None]
# chunk:  86%|████████▋ | 96/111 [00:00<00:00, 958.68it/s, now=None]
# chunk: 100%|██████████| 1/1 [21:20<00:00, 1280.64s/it, now=None]
# t:   0%|          | 0/150 [00:00<?, ?it/s, now=None]
# Moviepy - Building video behavior_data/headbanging/48.mp4.
# MoviePy - Writing audio in 48TEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video behavior_data/headbanging/48.mp4
# t:  14%|█▍        | 21/150 [00:00<00:00, 202.01it/s, now=None]
# t:  28%|██▊       | 42/150 [00:00<00:00, 197.01it/s, now=None]
# t:  41%|████▏     | 62/150 [00:00<00:00, 136.60it/s, now=None]
# t:  52%|█████▏    | 78/150 [00:00<00:00, 127.04it/s, now=None]
# t:  61%|██████▏   | 92/150 [00:00<00:00, 129.11it/s, now=None]
# t:  71%|███████   | 106/150 [00:00<00:00, 121.70it/s, now=None]
# t:  79%|███████▉  | 119/150 [00:00<00:00, 116.27it/s, now=None]
# t:  87%|████████▋ | 131/150 [00:01<00:00, 115.51it/s, now=None]
# t:  95%|█████████▌| 143/150 [00:01<00:00, 116.51it/s, now=None]
# chunk: 100%|██████████| 1/1 [21:22<00:00, 1282.39s/it, now=None][A
# Moviepy - Done !
# Moviepy - video ready behavior_data/headbanging/48.mp4
# ['7.mp4', '6.mp4', '5.mp4', '47.mp4', '46.mp4', '45.mp4', '48.mp4', '8.mp4']
# adding file
# chunk: 100%|██████████| 1/1 [21:22<00:00, 1282.74s/it, now=None]
# chunk:   0%|          | 0/111 [00:00<?, ?it/s, now=None]
# chunk:  93%|█████████▎| 103/111 [00:00<00:00, 980.54it/s, now=None]
# chunk: 100%|██████████| 1/1 [21:22<00:00, 1282.86s/it, now=None]
# t:   0%|          | 0/150 [00:00<?, ?it/s, now=None]
# Moviepy - Building video behavior_data/headbanging/49.mp4.
# MoviePy - Writing audio in 49TEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video behavior_data/headbanging/49.mp4
# t:  15%|█▌        | 23/150 [00:00<00:00, 225.36it/s, now=None]
# t:  31%|███▏      | 47/150 [00:00<00:00, 230.58it/s, now=None]
# t:  47%|████▋     | 71/150 [00:00<00:00, 160.59it/s, now=None]
# t:  59%|█████▉    | 89/150 [00:00<00:00, 150.08it/s, now=None]
# t:  71%|███████   | 106/150 [00:00<00:00, 138.95it/s, now=None]
# t:  81%|████████  | 121/150 [00:00<00:00, 134.12it/s, now=None]
# t:  90%|█████████ | 135/150 [00:00<00:00, 134.64it/s, now=None]
# t:  99%|█████████▉| 149/150 [00:01<00:00, 128.87it/s, now=None]
# chunk: 100%|██████████| 1/1 [21:24<00:00, 1284.43s/it, now=None][A
# Moviepy - Done !
# Moviepy - video ready behavior_data/headbanging/49.mp4
# ['7.mp4', '6.mp4', '5.mp4', '47.mp4', '46.mp4', '45.mp4', '48.mp4', '49.mp4', '8.mp4']
# adding file
# chunk: 100%|██████████| 1/1 [21:24<00:00, 1284.77s/it, now=None]
# chunk:   0%|          | 0/111 [00:00<?, ?it/s, now=None]
# chunk:  96%|█████████▋| 107/111 [00:00<00:00, 1068.52it/s, now=None]
# chunk: 100%|██████████| 1/1 [21:24<00:00, 1284.89s/it, now=None]
# t:   0%|          | 0/150 [00:00<?, ?it/s, now=None]
# Moviepy - Building video behavior_data/headbanging/50.mp4.
# MoviePy - Writing audio in 50TEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video behavior_data/headbanging/50.mp4
# t:  16%|█▌        | 24/150 [00:00<00:00, 236.30it/s, now=None]
# t:  32%|███▏      | 48/150 [00:00<00:00, 233.84it/s, now=None]
# t:  48%|████▊     | 72/150 [00:00<00:00, 158.62it/s, now=None]
# t:  60%|██████    | 90/150 [00:00<00:00, 144.28it/s, now=None]
# t:  71%|███████▏  | 107/150 [00:00<00:00, 150.34it/s, now=None]
# t:  83%|████████▎ | 124/150 [00:00<00:00, 133.94it/s, now=None]
# t:  93%|█████████▎| 139/150 [00:00<00:00, 135.20it/s, now=None]
# chunk: 100%|██████████| 1/1 [21:26<00:00, 1286.39s/it, now=None][A
# Moviepy - Done !
# Moviepy - video ready behavior_data/headbanging/50.mp4
# ['7.mp4', '6.mp4', '5.mp4', '47.mp4', '46.mp4', '50.mp4', '45.mp4', '48.mp4', '49.mp4', '8.mp4']
# adding file
# chunk: 100%|██████████| 1/1 [21:26<00:00, 1286.71s/it, now=None]
# chunk:   0%|          | 0/155 [00:00<?, ?it/s, now=None]
# chunk:  66%|██████▋   | 103/155 [00:00<00:00, 1020.06it/s, now=None]
# chunk: 100%|██████████| 1/1 [21:26<00:00, 1286.86s/it, now=None]
# t:   0%|          | 0/210 [00:00<?, ?it/s, now=None]
# Moviepy - Building video behavior_data/headbanging/51.mp4.
# MoviePy - Writing audio in 51TEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video behavior_data/headbanging/51.mp4
# t:  11%|█         | 23/210 [00:00<00:00, 228.81it/s, now=None]
# t:  22%|██▏       | 47/210 [00:00<00:00, 233.29it/s, now=None]
# t:  34%|███▍      | 71/210 [00:00<00:00, 160.56it/s, now=None]
# t:  43%|████▎     | 90/210 [00:00<00:00, 149.20it/s, now=None]
# t:  51%|█████     | 107/210 [00:00<00:00, 145.83it/s, now=None]
# t:  59%|█████▊    | 123/210 [00:00<00:00, 142.69it/s, now=None]
# t:  66%|██████▌   | 138/210 [00:00<00:00, 134.34it/s, now=None]
# t:  74%|███████▍  | 155/210 [00:01<00:00, 142.74it/s, now=None]
# t:  81%|████████  | 170/210 [00:01<00:00, 140.74it/s, now=None]
# t:  88%|████████▊ | 185/210 [00:01<00:00, 136.93it/s, now=None]
# t:  95%|█████████▍| 199/210 [00:01<00:00, 136.11it/s, now=None]
# chunk: 100%|██████████| 1/1 [21:28<00:00, 1288.80s/it, now=None][A
# Moviepy - Done !
# Moviepy - video ready behavior_data/headbanging/51.mp4
# ['7.mp4', '6.mp4', '5.mp4', '47.mp4', '46.mp4', '50.mp4', '45.mp4', '51.mp4', '48.mp4', '49.mp4', '8.mp4']
# adding file
# chunk: 100%|██████████| 1/1 [21:29<00:00, 1289.14s/it, now=None]
# chunk:   0%|          | 0/155 [00:00<?, ?it/s, now=None]
# chunk:  67%|██████▋   | 104/155 [00:00<00:00, 1037.89it/s, now=None]
# chunk: 100%|██████████| 1/1 [21:29<00:00, 1289.29s/it, now=None]
# t:   0%|          | 0/210 [00:00<?, ?it/s, now=None]
# Moviepy - Building video behavior_data/headbanging/52.mp4.
# MoviePy - Writing audio in 52TEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video behavior_data/headbanging/52.mp4
# t:  12%|█▏        | 25/210 [00:00<00:00, 247.47it/s, now=None]
# t:  24%|██▍       | 50/210 [00:00<00:00, 228.41it/s, now=None]
# t:  35%|███▍      | 73/210 [00:00<00:00, 155.03it/s, now=None]
# t:  43%|████▎     | 91/210 [00:00<00:00, 149.18it/s, now=None]
# t:  51%|█████▏    | 108/210 [00:00<00:00, 141.96it/s, now=None]
# t:  59%|█████▊    | 123/210 [00:00<00:00, 138.44it/s, now=None]
# t:  66%|██████▌   | 138/210 [00:00<00:00, 139.39it/s, now=None]
# t:  73%|███████▎  | 153/210 [00:01<00:00, 132.88it/s, now=None]
# t:  80%|███████▉  | 167/210 [00:01<00:00, 132.58it/s, now=None]
# t:  86%|████████▌ | 181/210 [00:01<00:00, 133.18it/s, now=None]
# t:  93%|█████████▎| 195/210 [00:01<00:00, 132.82it/s, now=None]
# t: 100%|██████████| 210/210 [00:01<00:00, 135.32it/s, now=None]
# chunk: 100%|██████████| 1/1 [21:31<00:00, 1291.26s/it, now=None][A
# Moviepy - Done !
# Moviepy - video ready behavior_data/headbanging/52.mp4
# ['7.mp4', '6.mp4', '5.mp4', '47.mp4', '52.mp4', '46.mp4', '50.mp4', '45.mp4', '51.mp4', '48.mp4', '49.mp4', '8.mp4']
# adding file
# chunk: 100%|██████████| 1/1 [21:31<00:00, 1291.62s/it, now=None]
# chunk:   0%|          | 0/133 [00:00<?, ?it/s, now=None]
# chunk:  65%|██████▌   | 87/133 [00:00<00:00, 868.16it/s, now=None]
# chunk: 100%|██████████| 1/1 [21:31<00:00, 1291.77s/it, now=None]
# t:   0%|          | 0/180 [00:00<?, ?it/s, now=None]
# Moviepy - Building video behavior_data/headbanging/53.mp4.
# MoviePy - Writing audio in 53TEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video behavior_data/headbanging/53.mp4
# t:  12%|█▏        | 22/180 [00:00<00:00, 215.09it/s, now=None]
# t:  24%|██▍       | 44/180 [00:00<00:00, 215.23it/s, now=None]
# t:  37%|███▋      | 66/180 [00:00<00:00, 151.52it/s, now=None]
# t:  46%|████▌     | 83/180 [00:00<00:00, 142.24it/s, now=None]
# t:  55%|█████▌    | 99/180 [00:00<00:00, 145.50it/s, now=None]
# t:  64%|██████▍   | 115/180 [00:00<00:00, 134.59it/s, now=None]
# t:  72%|███████▏  | 129/180 [00:00<00:00, 133.77it/s, now=None]
# t:  79%|███████▉  | 143/180 [00:00<00:00, 130.78it/s, now=None]
# t:  88%|████████▊ | 158/180 [00:01<00:00, 136.06it/s, now=None]
# t:  96%|█████████▌| 172/180 [00:01<00:00, 134.85it/s, now=None]
# chunk: 100%|██████████| 1/1 [21:33<00:00, 1293.53s/it, now=None][A
# Moviepy - Done !
# Moviepy - video ready behavior_data/headbanging/53.mp4
# ['7.mp4', '6.mp4', '5.mp4', '47.mp4', '53.mp4', '52.mp4', '46.mp4', '50.mp4', '45.mp4', '51.mp4', '48.mp4', '49.mp4', '8.mp4']
# adding file
# ...
# adding file
# Moviepy - Building video behavior_data/control/508.mp4.
# MoviePy - Writing audio in 508TEMP_MPY_wvf_snd.mp4
# chunk: 100%|██████████| 1/1 [1:28:12<00:00, 5292.45s/it, now=None]
# t:   0%|          | 0/120 [00:00<?, ?it/s, now=None]
# t:  84%|████████▍ | 101/120 [00:00<00:00, 1006.98it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video behavior_data/control/508.mp4
# chunk: 100%|██████████| 1/1 [1:28:12<00:00, 5292.82s/it, now=None]
# chunk:   0%|          | 0/111 [00:00<?, ?it/s, now=None]
# Moviepy - Done !
# Moviepy - video ready behavior_data/control/508.mp4
# ['154.mp4', '140.mp4', '55.mp4', '41.mp4', '395.mp4', '68.mp4', '141.mp4', '169.mp4', '237.mp4', '42.mp4', '4.mp4', '427.mp4', '355.mp4', '433.mp4', '396.mp4', '354.mp4', '432.mp4', '340.mp4', '57.mp4', '43.mp4', '142.mp4', '94.mp4', '146.mp4', '152.mp4', '84.mp4', '1.mp4', '344.mp4', '422.mp4', '350.mp4', '387.mp4', '345.mp4', '423.mp4', '91.mp4', '85.mp4', '153.mp4', '147.mp4', '151.mp4', '145.mp4', '93.mp4', '87.mp4', '2.mp4', '44.mp4', '353.mp4', '435.mp4', '421.mp4', '347.mp4', '390.mp4', '408.mp4', '420.mp4', '434.mp4', '3.mp4', '86.mp4', '92.mp4', '226.mp4', '269.mp4', '282.mp4', '137.mp4', '123.mp4', '22.mp4', '453.mp4', '447.mp4', '490.mp4', '484.mp4', '485.mp4', '491.mp4', '320.mp4', '334.mp4', '23.mp4', '122.mp4', '136.mp4', '268.mp4', '295.mp4', '281.mp4', '134.mp4', '21.mp4', '450.mp4', '487.mp4', '493.mp4', '486.mp4', '337.mp4', '135.mp4', '121.mp4', '294.mp4', '257.mp4', '247.mp4', '18.mp4', '24.mp4', '30.mp4', '327.mp4', '333.mp4', '455.mp4', '496.mp4', '468.mp4', '332.mp4', '454.mp4', '326.mp4', '31.mp4', '124.mp4', '508.mp4', '250.mp4', '287.mp4', '293.mp4', '33.mp4', '495.mp4', '494.mp4', '319.mp4', '325.mp4', '331.mp4', '32.mp4', '248.mp4', '260.mp4', '17.mp4', '328.mp4', '472.mp4', '466.mp4', '467.mp4', '473.mp4', '16.mp4', '103.mp4', '117.mp4', '507.mp4', '249.mp4', '288.mp4', '101.mp4', '459.mp4', '303.mp4', '465.mp4', '471.mp4', '470.mp4', '302.mp4', '458.mp4', '15.mp4', '114.mp4', '100.mp4', '289.mp4', '299.mp4', '104.mp4', '11.mp4', '460.mp4', '448.mp4', '449.mp4', '461.mp4', '10.mp4', '139.mp4', '111.mp4', '105.mp4', '298.mp4', '267.mp4', '259.mp4', '113.mp4', '12.mp4', '339.mp4', '338.mp4', '304.mp4', '106.mp4', '112.mp4', '258.mp4', '270.mp4', '161.mp4', '60.mp4', '411.mp4', '405.mp4', '388.mp4', '389.mp4', '362.mp4', '61.mp4', '148.mp4', '162.mp4', '348.mp4', '406.mp4', '360.mp4', '374.mp4', '407.mp4', '361.mp4', '349.mp4', '99.mp4', '167.mp4', '66.mp4', '365.mp4', '371.mp4', '364.mp4', '67.mp4', '172.mp4', '98.mp4', '166.mp4', '238.mp4', '170.mp4', '164.mp4', '158.mp4', '65.mp4', '372.mp4', '400.mp4', '366.mp4', '428.mp4', '399.mp4', '398.mp4', '429.mp4', '401.mp4', '367.mp4', '373.mp4', '58.mp4', '159.mp4', '165.mp4', '171.mp4']
# adding file
# Moviepy - Building video behavior_data/control/509.mp4.
# MoviePy - Writing audio in 509TEMP_MPY_wvf_snd.mp4
# chunk: 100%|██████████| 1/1 [1:28:12<00:00, 5292.89s/it, now=None]
# t:   0%|          | 0/120 [00:00<?, ?it/s, now=None]
# t:  82%|████████▎ | 99/120 [00:00<00:00, 958.04it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video behavior_data/control/509.mp4
# chunk: 100%|██████████| 1/1 [1:28:13<00:00, 5293.27s/it, now=None]
# chunk:   0%|          | 0/133 [00:00<?, ?it/s, now=None]
# Moviepy - Done !
# Moviepy - video ready behavior_data/control/509.mp4
# ['154.mp4', '140.mp4', '55.mp4', '41.mp4', '395.mp4', '68.mp4', '141.mp4', '169.mp4', '237.mp4', '42.mp4', '4.mp4', '427.mp4', '355.mp4', '433.mp4', '396.mp4', '354.mp4', '432.mp4', '340.mp4', '57.mp4', '43.mp4', '142.mp4', '94.mp4', '146.mp4', '152.mp4', '84.mp4', '1.mp4', '344.mp4', '422.mp4', '350.mp4', '387.mp4', '345.mp4', '423.mp4', '91.mp4', '85.mp4', '153.mp4', '147.mp4', '151.mp4', '145.mp4', '93.mp4', '87.mp4', '2.mp4', '44.mp4', '353.mp4', '435.mp4', '421.mp4', '347.mp4', '390.mp4', '408.mp4', '420.mp4', '434.mp4', '3.mp4', '86.mp4', '92.mp4', '226.mp4', '269.mp4', '282.mp4', '137.mp4', '123.mp4', '22.mp4', '453.mp4', '447.mp4', '490.mp4', '484.mp4', '485.mp4', '491.mp4', '320.mp4', '334.mp4', '23.mp4', '122.mp4', '136.mp4', '268.mp4', '295.mp4', '281.mp4', '134.mp4', '21.mp4', '450.mp4', '487.mp4', '493.mp4', '486.mp4', '337.mp4', '135.mp4', '121.mp4', '294.mp4', '257.mp4', '247.mp4', '509.mp4', '18.mp4', '24.mp4', '30.mp4', '327.mp4', '333.mp4', '455.mp4', '496.mp4', '468.mp4', '332.mp4', '454.mp4', '326.mp4', '31.mp4', '124.mp4', '508.mp4', '250.mp4', '287.mp4', '293.mp4', '33.mp4', '495.mp4', '494.mp4', '319.mp4', '325.mp4', '331.mp4', '32.mp4', '248.mp4', '260.mp4', '17.mp4', '328.mp4', '472.mp4', '466.mp4', '467.mp4', '473.mp4', '16.mp4', '103.mp4', '117.mp4', '507.mp4', '249.mp4', '288.mp4', '101.mp4', '459.mp4', '303.mp4', '465.mp4', '471.mp4', '470.mp4', '302.mp4', '458.mp4', '15.mp4', '114.mp4', '100.mp4', '289.mp4', '299.mp4', '104.mp4', '11.mp4', '460.mp4', '448.mp4', '449.mp4', '461.mp4', '10.mp4', '139.mp4', '111.mp4', '105.mp4', '298.mp4', '267.mp4', '259.mp4', '113.mp4', '12.mp4', '339.mp4', '338.mp4', '304.mp4', '106.mp4', '112.mp4', '258.mp4', '270.mp4', '161.mp4', '60.mp4', '411.mp4', '405.mp4', '388.mp4', '389.mp4', '362.mp4', '61.mp4', '148.mp4', '162.mp4', '348.mp4', '406.mp4', '360.mp4', '374.mp4', '407.mp4', '361.mp4', '349.mp4', '99.mp4', '167.mp4', '66.mp4', '365.mp4', '371.mp4', '364.mp4', '67.mp4', '172.mp4', '98.mp4', '166.mp4', '238.mp4', '170.mp4', '164.mp4', '158.mp4', '65.mp4', '372.mp4', '400.mp4', '366.mp4', '428.mp4', '399.mp4', '398.mp4', '429.mp4', '401.mp4', '367.mp4', '373.mp4', '58.mp4', '159.mp4', '165.mp4', '171.mp4']
# adding file
# Moviepy - Building video behavior_data/control/510.mp4.
# MoviePy - Writing audio in 510TEMP_MPY_wvf_snd.mp4
# chunk: 100%|██████████| 1/1 [1:28:13<00:00, 5293.37s/it, now=None]
# t:   0%|          | 0/144 [00:00<?, ?it/s, now=None]
# t:  69%|██████▉   | 100/144 [00:00<00:00, 992.62it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video behavior_data/control/510.mp4
# chunk: 100%|██████████| 1/1 [1:28:13<00:00, 5293.61s/it, now=None]
# Moviepy - Done !
# Moviepy - video ready behavior_data/control/510.mp4
# staring the 73th file
# http://www.youtube.com/watch?v=Pa-pdBF4FFA
# This is url:  http://www.youtube.com/watch?v=Pa-pdBF4FFA
# annoying url: http://www.youtube.com/watch?v=Pa-pdBF4FFA
# Pa-pdBF4FFA is unavailable
# staring the 74th file
# http://www.youtube.com/watch?v=Lex0gIMd73g
# This is url:  http://www.youtube.com/watch?v=Lex0gIMd73g
# chunk: 100%|██████████| 1/1 [1:28:22<00:00, 5302.68s/it, now=None]
# chunk:   0%|          | 0/155 [00:00<?, ?it/s, now=None]
# ['96.mp4', '7.mp4', '418.mp4', '430.mp4', '356.mp4', '424.mp4', '381.mp4', '380.mp4', '394.mp4', '425.mp4', '431.mp4', '357.mp4', '419.mp4', '6.mp4', '54.mp4', '155.mp4', '97.mp4', '95.mp4', '382.mp4', '397.mp4', '426.mp4', '5.mp4', '156.mp4', '47.mp4', '53.mp4', '378.mp4', '393.mp4', '392.mp4', '379.mp4', '351.mp4', '52.mp4', '46.mp4', '50.mp4', '409.mp4', '391.mp4', '45.mp4', '51.mp4', '144.mp4', '452.mp4', '451.mp4', '125.mp4', '469.mp4', '126.mp4', '456.mp4', '457.mp4', '464.mp4', '463.mp4', '462.mp4', '48.mp4', '377.mp4', '404.mp4', '410.mp4', '376.mp4', '49.mp4', '160.mp4', '412.mp4', '375.mp4', '413.mp4', '8.mp4', '403.mp4', '417.mp4', '358.mp4', '416.mp4', '402.mp4', '59.mp4', '414.mp4', '415.mp4']
# adding file
# Moviepy - Building video behavior_data/headbanging/511.mp4.
# MoviePy - Writing audio in 511TEMP_MPY_wvf_snd.mp4
# chunk: 100%|██████████| 1/1 [1:28:22<00:00, 5302.78s/it, now=None]
# t:   0%|          | 0/210 [00:00<?, ?it/s, now=None]
# t:  58%|█████▊    | 122/210 [00:00<00:00, 1205.81it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video behavior_data/headbanging/511.mp4
# chunk: 100%|██████████| 1/1 [1:28:23<00:00, 5303.20s/it, now=None]
# chunk:   0%|          | 0/133 [00:00<?, ?it/s, now=None]
# Moviepy - Done !
# Moviepy - video ready behavior_data/headbanging/511.mp4
# ['96.mp4', '7.mp4', '418.mp4', '430.mp4', '356.mp4', '424.mp4', '381.mp4', '380.mp4', '394.mp4', '425.mp4', '431.mp4', '357.mp4', '419.mp4', '6.mp4', '54.mp4', '155.mp4', '97.mp4', '95.mp4', '382.mp4', '397.mp4', '426.mp4', '5.mp4', '156.mp4', '47.mp4', '53.mp4', '378.mp4', '393.mp4', '392.mp4', '379.mp4', '351.mp4', '52.mp4', '46.mp4', '50.mp4', '409.mp4', '391.mp4', '45.mp4', '51.mp4', '144.mp4', '452.mp4', '451.mp4', '125.mp4', '469.mp4', '126.mp4', '456.mp4', '457.mp4', '511.mp4', '464.mp4', '463.mp4', '462.mp4', '48.mp4', '377.mp4', '404.mp4', '410.mp4', '376.mp4', '49.mp4', '160.mp4', '412.mp4', '375.mp4', '413.mp4', '8.mp4', '403.mp4', '417.mp4', '358.mp4', '416.mp4', '402.mp4', '59.mp4', '414.mp4', '415.mp4']
# adding file
# Moviepy - Building video behavior_data/headbanging/512.mp4.
# MoviePy - Writing audio in 512TEMP_MPY_wvf_snd.mp4
# chunk: 100%|██████████| 1/1 [1:28:23<00:00, 5303.29s/it, now=None]
# t:   0%|          | 0/180 [00:00<?, ?it/s, now=None]
# t:  68%|██████▊   | 122/180 [00:00<00:00, 1214.83it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video behavior_data/headbanging/512.mp4
# chunk: 100%|██████████| 1/1 [1:28:23<00:00, 5303.64s/it, now=None]
# chunk:   0%|          | 0/45 [00:00<?, ?it/s, now=None]
# chunk: 100%|██████████| 1/1 [1:28:23<00:00, 5303.69s/it, now=None]
# t:   0%|          | 0/60 [00:00<?, ?it/s, now=None]
# Moviepy - Done !
# Moviepy - video ready behavior_data/headbanging/512.mp4
# ['154.mp4', '140.mp4', '55.mp4', '41.mp4', '395.mp4', '68.mp4', '141.mp4', '169.mp4', '237.mp4', '42.mp4', '4.mp4', '427.mp4', '355.mp4', '433.mp4', '396.mp4', '354.mp4', '432.mp4', '340.mp4', '57.mp4', '43.mp4', '142.mp4', '94.mp4', '146.mp4', '152.mp4', '84.mp4', '1.mp4', '344.mp4', '422.mp4', '350.mp4', '387.mp4', '345.mp4', '423.mp4', '91.mp4', '85.mp4', '153.mp4', '147.mp4', '151.mp4', '145.mp4', '93.mp4', '87.mp4', '2.mp4', '44.mp4', '353.mp4', '435.mp4', '421.mp4', '347.mp4', '390.mp4', '408.mp4', '420.mp4', '434.mp4', '3.mp4', '86.mp4', '92.mp4', '226.mp4', '269.mp4', '282.mp4', '137.mp4', '123.mp4', '22.mp4', '453.mp4', '447.mp4', '490.mp4', '484.mp4', '485.mp4', '491.mp4', '320.mp4', '334.mp4', '23.mp4', '122.mp4', '136.mp4', '268.mp4', '295.mp4', '281.mp4', '134.mp4', '21.mp4', '450.mp4', '487.mp4', '493.mp4', '486.mp4', '337.mp4', '135.mp4', '121.mp4', '294.mp4', '257.mp4', '247.mp4', '509.mp4', '18.mp4', '24.mp4', '30.mp4', '327.mp4', '333.mp4', '455.mp4', '496.mp4', '468.mp4', '332.mp4', '454.mp4', '326.mp4', '31.mp4', '124.mp4', '508.mp4', '250.mp4', '287.mp4', '293.mp4', '33.mp4', '495.mp4', '494.mp4', '319.mp4', '325.mp4', '331.mp4', '32.mp4', '248.mp4', '260.mp4', '17.mp4', '328.mp4', '472.mp4', '466.mp4', '467.mp4', '473.mp4', '16.mp4', '103.mp4', '117.mp4', '507.mp4', '249.mp4', '288.mp4', '101.mp4', '459.mp4', '303.mp4', '465.mp4', '471.mp4', '470.mp4', '302.mp4', '458.mp4', '15.mp4', '114.mp4', '100.mp4', '289.mp4', '510.mp4', '299.mp4', '104.mp4', '11.mp4', '460.mp4', '448.mp4', '449.mp4', '461.mp4', '10.mp4', '139.mp4', '111.mp4', '105.mp4', '298.mp4', '267.mp4', '259.mp4', '113.mp4', '12.mp4', '339.mp4', '338.mp4', '304.mp4', '106.mp4', '112.mp4', '258.mp4', '270.mp4', '161.mp4', '60.mp4', '411.mp4', '405.mp4', '388.mp4', '389.mp4', '362.mp4', '61.mp4', '148.mp4', '162.mp4', '348.mp4', '406.mp4', '360.mp4', '374.mp4', '407.mp4', '361.mp4', '349.mp4', '99.mp4', '167.mp4', '66.mp4', '365.mp4', '371.mp4', '364.mp4', '67.mp4', '172.mp4', '98.mp4', '166.mp4', '238.mp4', '170.mp4', '164.mp4', '158.mp4', '65.mp4', '372.mp4', '400.mp4', '366.mp4', '428.mp4', '399.mp4', '398.mp4', '429.mp4', '401.mp4', '367.mp4', '373.mp4', '58.mp4', '159.mp4', '165.mp4', '171.mp4']
# adding file
# Moviepy - Building video behavior_data/control/513.mp4.
# MoviePy - Writing audio in 513TEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video behavior_data/control/513.mp4
# chunk: 100%|██████████| 1/1 [1:28:23<00:00, 5303.97s/it, now=None]
# chunk:   0%|          | 0/23 [00:00<?, ?it/s, now=None]
# Moviepy - Done !
# Moviepy - video ready behavior_data/control/513.mp4
# ['154.mp4', '140.mp4', '55.mp4', '41.mp4', '395.mp4', '68.mp4', '141.mp4', '169.mp4', '237.mp4', '42.mp4', '4.mp4', '427.mp4', '355.mp4', '433.mp4', '396.mp4', '354.mp4', '432.mp4', '340.mp4', '57.mp4', '43.mp4', '142.mp4', '94.mp4', '146.mp4', '152.mp4', '84.mp4', '1.mp4', '344.mp4', '422.mp4', '350.mp4', '387.mp4', '345.mp4', '423.mp4', '91.mp4', '85.mp4', '153.mp4', '147.mp4', '151.mp4', '145.mp4', '93.mp4', '87.mp4', '2.mp4', '44.mp4', '353.mp4', '435.mp4', '421.mp4', '347.mp4', '390.mp4', '408.mp4', '420.mp4', '434.mp4', '3.mp4', '86.mp4', '92.mp4', '226.mp4', '269.mp4', '282.mp4', '137.mp4', '123.mp4', '22.mp4', '453.mp4', '447.mp4', '490.mp4', '484.mp4', '485.mp4', '491.mp4', '320.mp4', '334.mp4', '23.mp4', '122.mp4', '136.mp4', '268.mp4', '295.mp4', '281.mp4', '134.mp4', '21.mp4', '450.mp4', '487.mp4', '493.mp4', '486.mp4', '337.mp4', '135.mp4', '121.mp4', '294.mp4', '257.mp4', '247.mp4', '509.mp4', '18.mp4', '24.mp4', '30.mp4', '327.mp4', '333.mp4', '455.mp4', '496.mp4', '468.mp4', '332.mp4', '454.mp4', '326.mp4', '31.mp4', '124.mp4', '508.mp4', '250.mp4', '287.mp4', '293.mp4', '33.mp4', '495.mp4', '494.mp4', '319.mp4', '325.mp4', '331.mp4', '32.mp4', '248.mp4', '260.mp4', '17.mp4', '328.mp4', '472.mp4', '466.mp4', '467.mp4', '473.mp4', '16.mp4', '103.mp4', '117.mp4', '513.mp4', '507.mp4', '249.mp4', '288.mp4', '101.mp4', '459.mp4', '303.mp4', '465.mp4', '471.mp4', '470.mp4', '302.mp4', '458.mp4', '15.mp4', '114.mp4', '100.mp4', '289.mp4', '510.mp4', '299.mp4', '104.mp4', '11.mp4', '460.mp4', '448.mp4', '449.mp4', '461.mp4', '10.mp4', '139.mp4', '111.mp4', '105.mp4', '298.mp4', '267.mp4', '259.mp4', '113.mp4', '12.mp4', '339.mp4', '338.mp4', '304.mp4', '106.mp4', '112.mp4', '258.mp4', '270.mp4', '161.mp4', '60.mp4', '411.mp4', '405.mp4', '388.mp4', '389.mp4', '362.mp4', '61.mp4', '148.mp4', '162.mp4', '348.mp4', '406.mp4', '360.mp4', '374.mp4', '407.mp4', '361.mp4', '349.mp4', '99.mp4', '167.mp4', '66.mp4', '365.mp4', '371.mp4', '364.mp4', '67.mp4', '172.mp4', '98.mp4', '166.mp4', '238.mp4', '170.mp4', '164.mp4', '158.mp4', '65.mp4', '372.mp4', '400.mp4', '366.mp4', '428.mp4', '399.mp4', '398.mp4', '429.mp4', '401.mp4', '367.mp4', '373.mp4', '58.mp4', '159.mp4', '165.mp4', '171.mp4']
# adding file
# Moviepy - Building video behavior_data/control/514.mp4.
# MoviePy - Writing audio in 514TEMP_MPY_wvf_snd.mp4
# chunk: 100%|██████████| 1/1 [1:28:24<00:00, 5304.02s/it, now=None]
# t:   0%|          | 0/30 [00:00<?, ?it/s, now=None]
# chunk: 100%|██████████| 1/1 [1:28:24<00:00, 5304.09s/it, now=None]
# MoviePy - Done.
# Moviepy - Writing video behavior_data/control/514.mp4
#
# Moviepy - Done !
# Moviepy - video ready behavior_data/control/514.mp4

# %% [markdown]
# # Directory Structure
#
# ## We have one folder inside of this AnishMachineLearning folder called "behavior_data" that has the "armflapping" and "spinning" folders. There all of the sliced .mp4 files with the behavior of interest are located.
#
# ### We will process headbanging videos even if we are not going to use it because we still want it as a negative case for training the arm flapping & spinning.

# %%
# for spinning it is just the hand positions that matter right?

import cv2
import mediapipe as mp 
import numpy as np
mp_hands = mp.solutions.hands


cap = cv2.VideoCapture("/Users/anish/Documents/Machine Learning Env/AnishMachineLearning/behavior_data/spinning/37.mp4")
#cap = cv2.VideoCapture(0)
# Initiate holistic model

#capcv2.VideoCapture(0)

hands = mp_hands.Hands(min_detection_confidence = 0.5, min_tracking_confidence = 0.5)

while cap.isOpened():
    ret, image = cap.read() 
    if not ret:break 

    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image.flags.writeable = False 
    results = hands.process(image)

    image.flags.writeable = True
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
    
    height, width, _ = image.shape

    white_image = np.zeros_like(image)
    white_image.fill(255.0)
    
    #check for hand results 
    if results.multi_hand_landmarks:
        for hand_landmark in results.multi_hand_landmarks:
            for i in range(0, 21):
                landmark = hand_landmark.landmark[i]
                x = int(landmark.x * width)
                y = int(landmark.y * height)
                cv2.circle(white_image, (x, y), 5, (100, 100, 0), -1)

    cv2.imshow("", white_image)

    if cv2.waitKey(1) == ord("q"):
        break 

cap.release() 
cv2.destroyAllWindows()

# %%
list(range(21))

# %% [markdown]
# # We can try using the y values for each of the hand flapping videos and graph them to see if there is a noticeable difference of the y-values (we'll use the mean of all y-values for all 21 hand landmarks and then graph them).

# %%
import matplotlib.pyplot as plt
import os 

# first all hand flapping videos 
for hand_flap_video in os.listdir("behavior_data/armflapping"):
    video = "behavior_data/armflapping/" + hand_flap_video
    cap = cv2.VideoCapture(video)
    
    hands = mp_hands.Hands(min_detection_confidence = 0.5, min_tracking_confidence = 0.5)
    
    all_YS = [] 
    
    while cap.isOpened():
        ret, image = cap.read() 
        if not ret:break 

        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False 
        results = hands.process(image)

        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

        height, width, _ = image.shape

        #check for hand results 
        y_s = []
        
        if results.multi_hand_landmarks:
            for hand_landmark in results.multi_hand_landmarks:
                for i in range(0, 21):
                    landmark = hand_landmark.landmark[i]
                    x = int(landmark.x * width)
                    y = int(landmark.y * height)
                    y_s.append(y)
        
        all_YS.append(np.mean(y_s))

    plt.plot(range(len(all_YS)), all_YS, color = "green")
    plt.show()

# %%
# now for spinning 

import matplotlib.pyplot as plt
import os 

# first all hand flapping videos 
for hand_flap_video in os.listdir("behavior_data/spinning"):
    video = "behavior_data/spinning/" + hand_flap_video
    cap = cv2.VideoCapture(video)
    
    hands = mp_hands.Hands(min_detection_confidence = 0.5, min_tracking_confidence = 0.5)
    
    all_YS = [] 
    
    while cap.isOpened():
        ret, image = cap.read() 
        if not ret:break 

        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False 
        results = hands.process(image)

        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

        height, width, _ = image.shape

        #check for hand results 
        y_s = []
        
        if results.multi_hand_landmarks:
            for hand_landmark in results.multi_hand_landmarks:
                for i in range(0, 21):
                    landmark = hand_landmark.landmark[i]
                    x = int(landmark.x * width)
                    y = int(landmark.y * height)
                    y_s.append(y)
        
        all_YS.append(np.mean(y_s))

    plt.plot(range(len(all_YS)), all_YS, color = "green")
    plt.show()

# %%
# next for headbanging 

# now for spinning 

import matplotlib.pyplot as plt
import os 

# first all hand flapping videos 
for hand_flap_video in os.listdir("behavior_data/headbanging"):
    video = "behavior_data/headbanging/" + hand_flap_video
    cap = cv2.VideoCapture(video)
    
    hands = mp_hands.Hands(min_detection_confidence = 0.5, min_tracking_confidence = 0.5)
    
    all_YS = [] 
    
    while cap.isOpened():
        ret, image = cap.read() 
        if not ret:break 

        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False 
        results = hands.process(image)

        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

        height, width, _ = image.shape

        #check for hand results 
        y_s = []
        
        if results.multi_hand_landmarks:
            for hand_landmark in results.multi_hand_landmarks:
                for i in range(0, 21):
                    landmark = hand_landmark.landmark[i]
                    x = int(landmark.x * width)
                    y = int(landmark.y * height)
                    y_s.append(y)
        
        all_YS.append(np.mean(y_s))

    plt.plot(range(len(all_YS)), all_YS, color = "green")
    plt.show()

# %% [markdown]
# # First let's get the frames for every arm flapping and control video. If the number of frames is less than ___ we will not take it.

# %%
ARMFLAPPING_VIDEOS = []
CONTROL_VIDEOS = []

for video_name in os.listdir('behavior_data/armflapping'): 
    cap = cv2.VideoCapture('behavior_data/armflapping/' + video_name)  
    FRAMES = [] # frames for this video 
    while True: 
        _, image = cap.read() 
        if not _ : break 
        
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        FRAMES.append(image)
    if len(FRAMES): 
        # ignore any .DS_Store files
        ARMFLAPPING_VIDEOS.append(FRAMES)

ARMFLAPPING_LABELS = np.ones(len(ARMFLAPPING_VIDEOS))

for video_name in os.listdir('behavior_data/control'): 
    cap = cv2.VideoCapture('behavior_data/control/' + video_name)  
    FRAMES = [] # frames for this video 
    while True: 
        _, image = cap.read() 
        if not _ : break 
        
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        
        FRAMES.append(image)
        
    if len(FRAMES): 
        CONTROL_VIDEOS.append(FRAMES)

CONTROL_LABELS = np.zeros(len(CONTROL_VIDEOS))

# %%
# shuffle and then balance the amount of videos
amount_of_videos = min([len(CONTROL_VIDEOS), len(ARMFLAPPING_VIDEOS)])

ARMFLAPPING_VIDEOS = np.array(ARMFLAPPING_VIDEOS)
CONTROL_VIDEOS = np.array(CONTROL_VIDEOS)
import numpy as np
control_permutation = np.random.permutation(CONTROL_LABELS.shape[0])
CONTROL_VIDEOS, CONTROL_LABELS = CONTROL_VIDEOS[control_permutation], CONTROL_LABELS[control_permutation]

armflapping_permutation = np.random.permutation(ARMFLAPPING_LABELS.shape[0])
ARMFLAPPING_VIDEOS, ARMFLAPPING_LABELS = ARMFLAPPING_VIDEOS[control_permutation], ARMFLAPPING_LABELS[control_permutation]

ARMFLAPPING_VIDEOS, ARMFLAPPING_LABELS = ARMFLAPPING_VIDEOS[:amount_of_videos], ARMFLAPPING_LABELS[:amount_of_videos]
CONTROL_VIDEOS, CONTROL_LABELS = CONTROL_VIDEOS[:amount_of_videos], CONTROL_LABELS[:amount_of_videos]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-75-a681eae49813> in <module>
#       9
#      10 armflapping_permutation = np.random.permutation(ARMFLAPPING_LABELS.shape[0])
# ---> 11 ARMFLAPPING_VIDEOS, ARMFLAPPING_LABELS = ARMFLAPPING_VIDEOS[control_permutation], ARMFLAPPING_LABELS[control_permutation]
#      12
#      13 ARMFLAPPING_VIDEOS, ARMFLAPPING_LABELS = ARMFLAPPING_VIDEOS[:amount_of_videos], ARMFLAPPING_LABELS[:amount_of_videos]
#
# IndexError: index 107 is out of bounds for axis 0 with size 99

# %%
armflapping_videos_lengths = np.array([len(armflapping_video) for armflapping_video in ARMFLAPPING_VIDEOS])
control_videos_lengths = np.array([len(control_video) for control_video in CONTROL_VIDEOS])
