# %% [markdown]
# # The first step is preprocessing. We use the [SSBD Dataset](https://rolandgoecke.net/research/datasets/ssbd/) in order to get the data for hand flapping and spinning.
#
# ## The dataset does contain 75 URLs (although we'll ignore all headbanging videos) to youtube videos. All the data is nicely stored in XML files that I will read to get the youtube videos and also the time stamps of when the behavior (hand flapping or spinning) occurs. Then I will use pytube to download the youtube videos to .mp4 and moviepy to cut the .mp4 videos into the areas of interest. Finally, because some of those areas of interest clips are more than a few seconds long (which is all you need to detect spinning or headbanging) I will take those areas that are > 8 seconds and split them into many clips (that way we have more data.) Also in sections of the video where no behavior is used I will take them as videos as control data.

# %%
# first change the directory over to ssbd release
import os 
import xml.etree.ElementTree as ET

# %%
# next step would be to get the hand flapping and spinning data 

tree = ET.parse("ssbd-release/Annotations/v_ArmFlapping_07.xml")
root = tree.getroot()
for child in root:
    # for each child in the root 
    if child.tag == "url":
        print(child.text)
    if child.tag == "behaviours":
        for behavior in child: # go through each reported behavior 
            for tag in behavior: # tag is just the attribute of the behavior 
                if tag.tag == "time":
                    print(tag.text)
                if tag.tag == "intensity":
                    print(tag.text)
                if tag.tag == "category":
                    print(tag.text)

# %%
def convert_to_second(time : str) -> int:
    # this will take in a time like "0125" or 1:25 and make it 85 (60 + 25)
    overall_seconds = 0 
    for i, time_char in enumerate(reversed(time)):
        if i == 0:
            overall_seconds += int(time_char)
        if i == 1:
            overall_seconds += int(time_char) * 10
        if i == 2:
            overall_seconds += int(time_char) * 60 
        if i == 3:
            overall_seconds += int(time_char) * 600 
    return overall_seconds 

assert convert_to_second('2345') == 23 * 60 + 45  

def consecutive(data, stepsize=1):
    '''groups up elements in an array that are continous with each other (useful to create sections where none 
    of the behaviors are shown.)'''
    return np.split(data, np.where(np.diff(data) != stepsize)[0]+1)

# %%
from collections import defaultdict
import math 
import numpy as np

NUM_SECONDS_TO_RECOGNIZE = 8 # hypothesis: takes this many seconds seconds to recognize handflapping + spinning 

URLS_TO_DOWNLOAD = set() # contains all youtube videos to download 
links_to_times = {} # data will be stored here like {link : {'category' : [(start, end)], 'another cat' : [(start, end)]}


for i, file_name in enumerate(os.listdir('ssbd-release/Annotations/')):
    # parse this file 
    tree = ET.parse('ssbd-release/Annotations/' + file_name)
    root = tree.getroot() 
    
    # everything we need to store
    URL = ""
    
    for child in root:
        
        if child.tag == "url":
            URL = child.text # store URL
            URLS_TO_DOWNLOAD.add(URL)
            links_to_times[URL] = defaultdict(list) 
        
        if child.tag == "duration":
            duration = int(child.text[:-1])
            all_times = list(range(duration))
        
        if child.tag == "behaviours": # this child has the list of behaviors 
            for reported_behavior in child: 
                for info in reported_behavior:
                    # gather the start time, end time, and category for this youtube link 
                    if info.tag == "time":
                        # the time will be start:end 
                        times = str(info.text) # contains the string 
                        if times.count(":"): 
                            divider_index = times.index(":")
                        elif times.count("-"):
                            divider_index = times.index("-")
                        else:
                            break # invalid then 
                        actual_start_time, actual_end_time = convert_to_second(times[:divider_index]), convert_to_second(times[divider_index + 1:])
                        START_TIMES, END_TIMES = [], []
                        times = np.array(range(actual_start_time, actual_end_time +1))
                        for time in times:
                            try:
                                all_times.remove(time)
                            except Exception as e:
                                pass 
                        split_times = np.array_split(times, math.ceil(times.shape[0] / NUM_SECONDS_TO_RECOGNIZE))
                        for time in split_times:
                            START_TIMES.append(time[0])
                            END_TIMES.append(time[-1])
                    if info.tag == "category":
                        # this is the label 
                        LABEL = info.text 
                
                # create an entry for this reported behavior 
                for START_TIME, END_TIME in zip(START_TIMES, END_TIMES):
                    links_to_times[URL][LABEL].append((START_TIME, END_TIME))
                    
            idle_times = consecutive(np.array(all_times))
            num_contributed = 0 # each video can only give 4 control clips (because otherwise it takes WAY too long)
            for control_times in idle_times:
                if num_contributed >= 4: 
                    break 
                # times maybe > NUM_SECONDS_TO_RECOGNIZE so split if that is the case 
                if len(control_times) <= NUM_SECONDS_TO_RECOGNIZE:
                    START_TIME, END_TIME = control_times[0], control_times[-1]
                    links_to_times[URL]['control'].append((START_TIME, END_TIME))
                    num_contributed += 1
                else:
                    # needs to be split 
                    control_times_split = np.array_split(control_times, math.ceil(len(control_times) / NUM_SECONDS_TO_RECOGNIZE))
                    for control_time in control_times_split:  
                        START_TIME, END_TIME = control_time[0], control_time[-1]
                        links_to_times[URL]['control'].append((START_TIME, END_TIME))
                        num_contributed += 1
                        if num_contributed >= 4: 
                            break

# %%
links_to_times
# Out:
# {'http://www.youtube.com/watch?v=Pqd9Vu-juPI': defaultdict(list,
#              {'spinning': [(10, 15)],
#               'control': [(0, 4), (5, 9), (16, 23), (24, 31)]}),
#  'http://www.youtube.com/watch?v=yMgx2lVjf5I': defaultdict(list,
#              {'headbanging': [(1, 7), (18, 25), (36, 43), (44, 50)],
#               'control': [(0, 0), (8, 12), (13, 17), (26, 30)]}),
#  'http://www.youtube.com/watch?v=WRGUUOZ5_wA': defaultdict(list,
#              {'armflapping': [(60, 67), (60, 67)],
#               'control': [(0, 7), (8, 15), (16, 23), (24, 31)]}),
#  'http://www.youtube.com/watch?v=8vFUIFEfRpA': defaultdict(list,
#              {'armflapping': [(2, 8), (9, 14)],
#               'control': [(0, 1), (15, 21), (22, 28), (29, 34)]}),
#  'http://www.youtube.com/watch?v=SOc13pnf-Dc': defaultdict(list,
#              {'armflapping': [(65, 71),
#                (72, 78),
#                (79, 85),
#                (132, 136),
#                (137, 140)],
#               'control': [(0, 7), (8, 15), (16, 22), (23, 29)]}),
#  'http://www.youtube.com/watch?v=iDuAugAykcc': defaultdict(list,
#              {'armflapping': [(18, 22),
#                (23, 27),
#                (33, 37),
#                (50, 57),
#                (68, 73),
#                (74, 79),
#                (80, 85)],
#               'control': [(0, 5), (6, 11), (12, 17), (28, 32)]}),
#  'http://www.youtube.com/watch?v=BUAFdqrw4fA': defaultdict(list,
#              {'headbanging': [(8, 13),
#                (14, 18),
#                (20, 26),
#                (27, 32),
#                (33, 38),
#                (39, 44),
#                (54, 61),
#                (62, 69),
#                (70, 76),
#                (77, 83)],
#               'control': [(0, 7), (19, 19), (45, 49), (50, 53)]}),
#  'http://www.youtube.com/watch?v=WcsZ9eMQ5Zs': defaultdict(list,
#              {'headbanging': [(2, 6), (7, 10)],
#               'control': [(0, 1), (11, 13)]}),
#  'http://www.youtube.com/watch?v=w96PxUcoo58': defaultdict(list,
#              {'headbanging': [(5, 10)], 'control': [(0, 4), (11, 13)]}),
#  'http://www.youtube.com/watch?v=ehlLfMossUY': defaultdict(list,
#              {'armflapping': [(27, 30), (40, 43), (100, 102)],
#               'control': [(0, 6), (7, 13), (14, 20), (21, 26)]}),
#  'http://www.youtube.com/watch?v=mnBWOI4LuKw': defaultdict(list,
#              {'armflapping': [(3, 9),
#                (10, 16),
#                (17, 23),
#                (24, 30),
#                (74, 81),
#                (82, 88),
#                (89, 95),
#                (96, 102),
#                (103, 109),
#                (110, 116),
#                (117, 123),
#                (124, 130),
#                (134, 141),
#                (142, 148),
#                (149, 155)],
#               'control': [(0, 2), (31, 38), (39, 45), (46, 52)]}),
#  'http://www.youtube.com/watch?v=3Oh_Lmehb6c': defaultdict(list,
#              {'armflapping': [(19, 22), (40, 45), (46, 51)],
#               'control': [(0, 6), (7, 12), (13, 18), (23, 28)]}),
#  'http://www.youtube.com/watch?v=T9rbit_oiJA': defaultdict(list,
#              {'armflapping': [(4, 10), (15, 20)],
#               'control': [(0, 3), (11, 14), (21, 27), (28, 33)]}),
#  'http://www.youtube.com/watch?v=6sR-8llWl_s': defaultdict(list,
#              {'headbanging': [(9, 14), (15, 20), (21, 26)],
#               'control': [(0, 4), (5, 8), (27, 33), (34, 40)]}),
#  'http://www.youtube.com/watch?v=Z2kfvB4lv7A': defaultdict(list,
#              {'armflapping': [(22, 27)],
#               'control': [(0, 7), (8, 14), (15, 21), (28, 34)]}),
#  'http://www.youtube.com/watch?v=vtVnrV_jog0': defaultdict(list,
#              {'armflapping': [(2, 8), (9, 14), (19, 23), (36, 39)],
#               'control': [(0, 1), (15, 18), (24, 29), (30, 35)]}),
#  'http://www.youtube.com/watch?v=5sgfS0SSh8o': defaultdict(list,
#              {'armflapping': [(32, 39), (40, 46)], 'control': [(0, 4)]}),
#  'http://www.youtube.com/watch?v=hKf-IwHM6TI': defaultdict(list,
#              {'armflapping': [(11, 16), (19, 23), (29, 33)],
#               'control': [(0, 5), (6, 10), (17, 18), (24, 28)]}),
#  'http://www.youtube.com/watch?v=zuoD4tEtYyk': defaultdict(list,
#              {'headbanging': [(1, 7), (8, 14), (15, 20)],
#               'control': [(0, 0), (21, 21)]}),
#  'http://www.youtube.com/watch?v=I38WtUMuQwM': defaultdict(list,
#              {'headbanging': [(30, 35), (36, 40)],
#               'armflapping': [(124, 130),
#                (131, 137),
#                (138, 144),
#                (145, 150),
#                (176, 181),
#                (182, 187),
#                (206, 211)],
#               'control': [(0, 7), (8, 15), (16, 22), (23, 29)]}),
#  'http://www.youtube.com/watch?v=pz1nIbRWb2M': defaultdict(list,
#              {'armflapping': [(3, 7)],
#               'control': [(0, 2), (8, 14), (15, 21), (22, 28)]}),
#  'http://www.youtube.com/watch?v=I7fdv1q9-m8': defaultdict(list,
#              {'armflapping': [(18, 24)],
#               'headbanging': [(27, 32)],
#               'control': [(0, 5), (6, 11), (12, 17), (25, 26)]}),
#  'http://www.youtube.com/watch?v=nGoMpqcYcOg': defaultdict(list,
#              {'armflapping': [(17, 23), (32, 37)],
#               'control': [(0, 5), (6, 11), (12, 16), (24, 31)]}),
#  'http://www.youtube.com/watch?v=TVMWW9SejgI': defaultdict(list,
#              {'headbanging': [(1, 8), (9, 15)],
#               'control': [(0, 0), (16, 20), (21, 25)]}),
#  'http://www.youtube.com/watch?v=hX3sIO2wc1s': defaultdict(list,
#              {'headbanging': [(3, 10)], 'control': [(0, 2), (11, 15)]}),
#  'http://www.youtube.com/watch?v=VxK45NHvHTg': defaultdict(list,
#              {'spinning': [(25, 28)],
#               'control': [(0, 6), (7, 12), (13, 18), (19, 24)]}),
#  'http://www.youtube.com/watch?v=AXghcX_Bjac': defaultdict(list,
#              {'spinning': [(56, 63)],
#               'control': [(0, 7), (8, 15), (16, 23), (24, 31)]}),
#  'http://www.youtube.com/watch?v=scM9g0LExJA': defaultdict(list,
#              {'spinning': [(1, 8),
#                (9, 16),
#                (17, 24),
#                (25, 32),
#                (33, 40),
#                (41, 47),
#                (60, 67),
#                (68, 74),
#                (75, 81),
#                (82, 88),
#                (105, 112),
#                (113, 120),
#                (121, 128),
#                (140, 147),
#                (163, 170),
#                (171, 178),
#                (179, 186),
#                (187, 194),
#                (195, 202),
#                (203, 210),
#                (211, 218),
#                (219, 226),
#                (227, 234),
#                (235, 242),
#                (243, 250),
#                (251, 258),
#                (259, 266),
#                (267, 274),
#                (275, 281),
#                (282, 288),
#                (289, 295)],
#               'control': [(0, 0)]}),
#  'http://www.youtube.com/watch?v=-rC-ab0nzxY': defaultdict(list,
#              {'spinning': [(26, 31), (32, 37), (38, 43)],
#               'control': [(0, 6), (7, 13), (14, 19), (20, 25)]}),
#  'http://www.youtube.com/watch?v=yiEo7Kg1ngY': defaultdict(list,
#              {'spinning': [(1, 8),
#                (9, 16),
#                (17, 24),
#                (25, 32),
#                (33, 40),
#                (41, 48),
#                (49, 56),
#                (57, 64),
#                (65, 72),
#                (73, 80),
#                (81, 88),
#                (89, 96),
#                (97, 104),
#                (105, 112),
#                (113, 120),
#                (121, 127),
#                (128, 134),
#                (135, 141),
#                (142, 148),
#                (149, 155)],
#               'control': [(0, 0), (156, 157)]}),
#  'http://www.youtube.com/watch?v=8R1MfXoI3mo': defaultdict(list,
#              {'spinning': [(2, 7),
#                (15, 22),
#                (23, 30),
#                (31, 38),
#                (39, 45),
#                (46, 52),
#                (53, 59),
#                (60, 66),
#                (67, 73),
#                (74, 80)],
#               'control': [(0, 1), (8, 14)]}),
#  'http://www.youtube.com/watch?v=5MS6VZwZDi0': defaultdict(list,
#              {'spinning': [(2, 9),
#                (10, 17),
#                (18, 24),
#                (25, 31),
#                (32, 38),
#                (39, 45),
#                (46, 52),
#                (53, 59)],
#               'control': [(0, 1), (60, 66), (67, 73), (74, 80)]}),
#  'http://www.youtube.com/watch?v=TH5mlAhdw00': defaultdict(list,
#              {'spinning': [(2, 9)],
#               'control': [(0, 1), (10, 17), (18, 25), (26, 33)]}),
#  'http://www.youtube.com/watch?v=kFuxwAufWvQ': defaultdict(list,
#              {'spinning': [(2, 9),
#                (10, 17),
#                (18, 25),
#                (26, 33),
#                (34, 40),
#                (41, 47)],
#               'control': [(0, 1), (48, 55), (56, 63), (64, 71)]}),
#  'http://www.youtube.com/watch?v=oukupxRUA84': defaultdict(list,
#              {'spinning': [(4, 8),
#                (9, 12),
#                (28, 34),
#                (35, 41),
#                (42, 47),
#                (58, 64)],
#               'control': [(0, 3), (13, 20), (21, 27), (48, 52)]}),
#  'http://www.youtube.com/watch?v=Gt-WMpTP7IE': defaultdict(list,
#              {'spinning': [(1, 8),
#                (9, 16),
#                (17, 24),
#                (25, 32),
#                (33, 40),
#                (41, 48),
#                (49, 56),
#                (57, 63),
#                (64, 70)],
#               'control': [(0, 0), (71, 78), (79, 85)]}),
#  'http://www.youtube.com/watch?v=uWgI1w2fQhs': defaultdict(list,
#              {'spinning': [(3, 9), (10, 16), (17, 22), (23, 28)],
#               'control': [(0, 2), (29, 35), (36, 42)]}),
#  'http://www.youtube.com/watch?v=VAMZwnfAHyY': defaultdict(list,
#              {'spinning': [(3, 8), (9, 14), (15, 20)],
#               'control': [(0, 2), (21, 27), (28, 33)]}),
#  'http://www.youtube.com/watch?v=arn5UCMLlBo': defaultdict(list,
#              {'spinning': [(2, 8), (9, 15)], 'control': [(0, 1), (16, 18)]}),
#  'http://www.youtube.com/watch?v=5BVFjqo0FUY': defaultdict(list,
#              {'spinning': [(1, 8),
#                (9, 16),
#                (17, 24),
#                (36, 43),
#                (44, 51),
#                (52, 59),
#                (60, 67),
#                (68, 75),
#                (76, 82),
#                (83, 89),
#                (90, 96),
#                (97, 103),
#                (104, 110),
#                (111, 117),
#                (125, 131),
#                (132, 138),
#                (139, 145),
#                (146, 152),
#                (153, 159),
#                (160, 165),
#                (180, 186),
#                (187, 193),
#                (194, 199)],
#               'control': [(0, 0), (25, 30), (31, 35), (118, 124)]}),
#  'http://www.youtube.com/watch?v=2AS14wxMB-A': defaultdict(list,
#              {'spinning': [(6, 12), (13, 18)],
#               'control': [(0, 5), (19, 24), (25, 29)]}),
#  'http://www.youtube.com/watch?v=cxqsde-6V-c': defaultdict(list,
#              {'spinning': [(1, 7), (8, 14), (15, 20)],
#               'control': [(0, 0), (21, 27), (28, 33), (34, 39)]}),
#  'http://www.youtube.com/watch?v=ZHJr17Q4384': defaultdict(list,
#              {'spinning': [(2, 9),
#                (10, 17),
#                (18, 25),
#                (26, 33),
#                (34, 41),
#                (42, 49),
#                (50, 57),
#                (58, 65),
#                (66, 73),
#                (74, 81),
#                (82, 89),
#                (90, 96),
#                (97, 103),
#                (104, 110)],
#               'control': [(0, 1), (111, 114)]}),
#  'http://www.youtube.com/watch?v=NDcUGYlTy_4': defaultdict(list,
#              {'spinning': [(6, 12), (75, 81), (82, 88), (89, 95)],
#               'control': [(0, 5), (13, 20), (21, 28), (29, 36)]}),
#  'http://www.youtube.com/watch?v=sAgAvYT3D8s': defaultdict(list,
#              {'spinning': [(10, 15), (16, 20)],
#               'control': [(0, 4), (5, 9), (21, 28), (29, 36)]}),
#  'http://www.youtube.com/watch?v=wu5fgT-LkHs': defaultdict(list,
#              {'spinning': [(2, 8),
#                (9, 14),
#                (15, 20),
#                (30, 36),
#                (37, 43),
#                (44, 50),
#                (51, 57),
#                (58, 63)],
#               'control': [(0, 1), (21, 25), (26, 29), (64, 71)]}),
#  'http://www.youtube.com/watch?v=uNpUNkjNreg': defaultdict(list,
#              {'spinning': [(68, 75), (76, 83)],
#               'control': [(0, 7), (8, 15), (16, 23), (24, 31)]}),
#  'http://www.youtube.com/watch?v=gKED6S0eGYA': defaultdict(list,
#              {'spinning': [(1, 5), (6, 10)],
#               'control': [(0, 0), (11, 18), (19, 25)]}),
#  'http://www.youtube.com/watch?v=pgj_LKf6jL4': defaultdict(list,
#              {'spinning': [(51, 58)],
#               'control': [(0, 7), (8, 15), (16, 22), (23, 29)]}),
#  'http://www.youtube.com/watch?v=yCaymsrcNwA': defaultdict(list,
#              {'headbanging': [(1, 4)],
#               'control': [(0, 0), (5, 11), (12, 18), (19, 24)]}),
#  'http://www.youtube.com/watch?v=9zOrUA7Kn4o': defaultdict(list,
#              {'headbanging': [(1, 8), (9, 16), (17, 23)],
#               'control': [(0, 0), (24, 31), (32, 38), (39, 45)]}),
#  'http://www.youtube.com/watch?v=AGmXuSY4gx0': defaultdict(list,
#              {'armflapping': [(8, 15)],
#               'control': [(0, 7), (16, 22), (23, 28), (29, 34)]}),
#  'http://www.youtube.com/watch?v=JM8BHjJTSFM': defaultdict(list,
#              {'armflapping': [(3, 7), (40, 45), (46, 50)],
#               'control': [(0, 2), (8, 15), (16, 23), (24, 31)]}),
#  'http://www.youtube.com/watch?v=1vRklwIBC28': defaultdict(list,
#              {'headbanging': [(60, 66),
#                (67, 73),
#                (74, 80),
#                (81, 87),
#                (88, 94),
#                (100, 106),
#                (107, 113),
#                (114, 120)],
#               'armflapping': [(175, 182), (183, 190), (205, 212), (213, 219)],
#               'control': [(0, 7), (8, 15), (16, 23), (24, 31)]}),
#  'http://www.youtube.com/watch?v=I2rfPPinMHk': defaultdict(list,
#              {'armflapping': [(4, 8)],
#               'control': [(0, 3), (9, 15), (16, 22)]}),
#  'http://www.youtube.com/watch?v=0Vk9itex_ds': defaultdict(list,
#              {'headbanging': [(4, 10), (11, 17), (18, 24), (25, 30)],
#               'control': [(0, 3), (31, 32)]}),
#  'http://www.youtube.com/watch?v=Lw-MsQ2k6ZQ': defaultdict(list,
#              {'headbanging': [(10, 17)],
#               'control': [(0, 4), (5, 9), (18, 25), (26, 32)]}),
#  'http://www.youtube.com/watch?v=a5BuwkqtIa0': defaultdict(list,
#              {'headbanging': [(4, 9), (36, 40), (41, 44)],
#               'control': [(0, 3), (10, 16), (17, 23), (24, 29)]}),
#  'http://www.youtube.com/watch?v=k9MJ4pDQQ74': defaultdict(list,
#              {'headbanging': [(6, 10), (11, 14)], 'control': [(0, 5)]}),
#  'http://www.youtube.com/watch?v=8SrUO-NdSZU': defaultdict(list,
#              {'headbanging': [(2, 9),
#                (10, 16),
#                (17, 23),
#                (24, 30),
#                (31, 37),
#                (38, 44),
#                (45, 51),
#                (52, 58)],
#               'control': [(0, 1), (59, 66), (67, 73), (74, 80)]}),
#  'http://www.youtube.com/watch?v=B9hYEIjsHDA': defaultdict(list,
#              {'headbanging': [(2, 8), (9, 14), (15, 20)],
#               'control': [(0, 1), (21, 25), (26, 29)]}),
#  'http://www.youtube.com/watch?v=nwLp0k1xa0o': defaultdict(list,
#              {'headbanging': [(55, 59), (60, 64)],
#               'control': [(0, 7), (8, 15), (16, 23), (24, 31)]}),
#  'http://www.youtube.com/watch?v=UxpQpWzhOx0': defaultdict(list,
#              {'armflapping': [(2, 6),
#                (41, 48),
#                (49, 55),
#                (60, 67),
#                (68, 75),
#                (76, 82),
#                (83, 89),
#                (94, 98),
#                (99, 102),
#                (110, 114),
#                (115, 118)],
#               'control': [(0, 1), (7, 13), (14, 20), (21, 27)]}),
#  'http://www.youtube.com/watch?v=xeKKMkVgNPU': defaultdict(list,
#              {'armflapping': [(3, 9), (60, 65), (66, 70)],
#               'spinning': [(49, 53), (54, 57)],
#               'control': [(0, 2), (10, 17), (18, 25), (26, 33)]}),
#  'http://www.youtube.com/watch?v=WLtorzPESbc': defaultdict(list,
#              {'headbanging': [(10, 14), (15, 19)],
#               'control': [(0, 4), (5, 9), (20, 22)]}),
#  'http://www.youtube.com/watch?v=5WTHMIJ_61I': defaultdict(list,
#              {'headbanging': [(2, 7), (8, 12)],
#               'control': [(0, 1), (13, 20), (21, 28), (29, 36)]}),
#  'http://www.youtube.com/watch?v=pzPhXbGEpSo': defaultdict(list,
#              {'headbanging': [(16, 23), (24, 30), (34, 39)],
#               'control': [(0, 7), (8, 15), (31, 33), (40, 46)]}),
#  'http://www.youtube.com/watch?v=aNaC46cUOJo': defaultdict(list,
#              {'headbanging': [(16, 22)],
#               'control': [(0, 7), (8, 15), (23, 30), (31, 38)]}),
#  'http://www.youtube.com/watch?v=C_O8vyrSt0Q': defaultdict(list,
#              {'armflapping': [(5, 10),
#                (11, 15),
#                (30, 37),
#                (38, 44),
#                (55, 62),
#                (63, 70),
#                (85, 92),
#                (93, 100),
#                (125, 132),
#                (133, 139)],
#               'control': [(0, 4), (16, 22), (23, 29), (45, 49)]}),
#  'http://www.youtube.com/watch?v=AQ-jO6O5gow': defaultdict(list,
#              {'armflapping': [(7, 11), (12, 16)],
#               'control': [(0, 6), (17, 22)]}),
#  'http://www.youtube.com/watch?v=MOt-6FAEP_g': defaultdict(list,
#              {'armflapping': [(94, 98)],
#               'control': [(0, 7), (8, 15), (16, 23), (24, 31)]}),
#  'http://www.youtube.com/watch?v=5Ps9iE8mPqY': defaultdict(list,
#              {'armflapping': [(18, 21),
#                (47, 51),
#                (70, 77),
#                (90, 96),
#                (97, 102),
#                (103, 108),
#                (122, 128),
#                (129, 134),
#                (195, 200),
#                (218, 223)],
#               'control': [(0, 5), (6, 11), (12, 17), (22, 28)]}),
#  'http://www.youtube.com/watch?v=Pa-pdBF4FFA': defaultdict(list,
#              {'headbanging': [(36, 39)],
#               'control': [(0, 7), (8, 14), (15, 21), (22, 28)]}),
#  'http://www.youtube.com/watch?v=Lex0gIMd73g': defaultdict(list,
#              {'headbanging': [(3, 10), (11, 17)],
#               'control': [(0, 2), (18, 19)]})}

# %%
# pickle this just incase 
import pickle 
with open("links_to_times.pkl", 'wb') as f:
    pickle.dump(links_to_times, f)

# %%
import cv2
import numpy as np
from moviepy.video.io.VideoFileClip import VideoFileClip
import pytube
FPS = 30 
i = 0 
for vid, (url, category_times) in enumerate((links_to_times.items())): 
    print(f"staring the {vid+1}th file")
    # download the video 
    print(url)
    try: 
        print("This is url: ", url)
        y = pytube.YouTube(url)
        video = y.streams.get_highest_resolution()
        video.download()
    except Exception as e:
        print(f"annoying url: {url}")
        print(e)
        continue 
        
    for category, times in category_times.items(): 
        folder_path = "behavior_data/" + category + "/"
        
        for start_time, end_time in times:
            try:
                input_file = y.streams.get_highest_resolution().default_filename
                output_file = folder_path + f"{i}.mp4"
                print(os.listdir(folder_path))
                if f"{i}.mp4" not in os.listdir(folder_path):
                    print("adding file")
                    with VideoFileClip(input_file) as video:
                        new = video.subclip(start_time, end_time)
                        new.write_videofile(output_file, audio_codec='aac')
                        i += 1 
            except Exception as e:
                print(f"failed on {i}")
                i += 1 
    os.remove(y.streams.get_highest_resolution().default_filename)
# Out:
# staring the 1th file
# http://www.youtube.com/watch?v=Pqd9Vu-juPI
# This is url:  http://www.youtube.com/watch?v=Pqd9Vu-juPI
# annoying url: http://www.youtube.com/watch?v=Pqd9Vu-juPI
# Pqd9Vu-juPI is a private video
# staring the 2th file
# http://www.youtube.com/watch?v=yMgx2lVjf5I
# This is url:  http://www.youtube.com/watch?v=yMgx2lVjf5I
# ['41.mp4', '418.mp4', '430.mp4', '424.mp4', '425.mp4', '40.mp4', '54.mp4', '155.mp4', '42.mp4', '56.mp4', '396.mp4', '43.mp4', '90.mp4', '47.mp4', '1.mp4', '.DS_Store', '393.mp4', '392.mp4', '351.mp4', '423.mp4', '0.mp4', '46.mp4', '91.mp4', '151.mp4', '2.mp4', '44.mp4', '353.mp4', '409.mp4', '390.mp4', '391.mp4', '408.mp4', '346.mp4', '352.mp4', '45.mp4', '3.mp4', '92.mp4', '150.mp4', '120.mp4', '450.mp4', '451.mp4', '121.mp4', '455.mp4', '468.mp4', '456.mp4', '511.mp4', '510.mp4', '461.mp4', '139.mp4', '463.mp4', '462.mp4', '48.mp4', '411.mp4', '377.mp4', '376.mp4', '49.mp4', '374.mp4', '412.mp4', '375.mp4', '413.mp4', '403.mp4', '417.mp4', '371.mp4', '416.mp4', '370.mp4', '402.mp4', '372.mp4', '414.mp4', '429.mp4', '401.mp4', '373.mp4', '415.mp4']
# ['41.mp4', '418.mp4', '430.mp4', '424.mp4', '425.mp4', '40.mp4', '54.mp4', '155.mp4', '42.mp4', '56.mp4', '396.mp4', '43.mp4', '90.mp4', '47.mp4', '1.mp4', '.DS_Store', '393.mp4', '392.mp4', '351.mp4', '423.mp4', '0.mp4', '46.mp4', '91.mp4', '151.mp4', '2.mp4', '44.mp4', '353.mp4', '409.mp4', '390.mp4', '391.mp4', '408.mp4', '346.mp4', '352.mp4', '45.mp4', '3.mp4', '92.mp4', '150.mp4', '120.mp4', '450.mp4', '451.mp4', '121.mp4', '455.mp4', '468.mp4', '456.mp4', '511.mp4', '510.mp4', '461.mp4', '139.mp4', '463.mp4', '462.mp4', '48.mp4', '411.mp4', '377.mp4', '376.mp4', '49.mp4', '374.mp4', '412.mp4', '375.mp4', '413.mp4', '403.mp4', '417.mp4', '371.mp4', '416.mp4', '370.mp4', '402.mp4', '372.mp4', '414.mp4', '429.mp4', '401.mp4', '373.mp4', '415.mp4']
# ['41.mp4', '418.mp4', '430.mp4', '424.mp4', '425.mp4', '40.mp4', '54.mp4', '155.mp4', '42.mp4', '56.mp4', '396.mp4', '43.mp4', '90.mp4', '47.mp4', '1.mp4', '.DS_Store', '393.mp4', '392.mp4', '351.mp4', '423.mp4', '0.mp4', '46.mp4', '91.mp4', '151.mp4', '2.mp4', '44.mp4', '353.mp4', '409.mp4', '390.mp4', '391.mp4', '408.mp4', '346.mp4', '352.mp4', '45.mp4', '3.mp4', '92.mp4', '150.mp4', '120.mp4', '450.mp4', '451.mp4', '121.mp4', '455.mp4', '468.mp4', '456.mp4', '511.mp4', '510.mp4', '461.mp4', '139.mp4', '463.mp4', '462.mp4', '48.mp4', '411.mp4', '377.mp4', '376.mp4', '49.mp4', '374.mp4', '412.mp4', '375.mp4', '413.mp4', '403.mp4', '417.mp4', '371.mp4', '416.mp4', '370.mp4', '402.mp4', '372.mp4', '414.mp4', '429.mp4', '401.mp4', '373.mp4', '415.mp4']
# ['41.mp4', '418.mp4', '430.mp4', '424.mp4', '425.mp4', '40.mp4', '54.mp4', '155.mp4', '42.mp4', '56.mp4', '396.mp4', '43.mp4', '90.mp4', '47.mp4', '1.mp4', '.DS_Store', '393.mp4', '392.mp4', '351.mp4', '423.mp4', '0.mp4', '46.mp4', '91.mp4', '151.mp4', '2.mp4', '44.mp4', '353.mp4', '409.mp4', '390.mp4', '391.mp4', '408.mp4', '346.mp4', '352.mp4', '45.mp4', '3.mp4', '92.mp4', '150.mp4', '120.mp4', '450.mp4', '451.mp4', '121.mp4', '455.mp4', '468.mp4', '456.mp4', '511.mp4', '510.mp4', '461.mp4', '139.mp4', '463.mp4', '462.mp4', '48.mp4', '411.mp4', '377.mp4', '376.mp4', '49.mp4', '374.mp4', '412.mp4', '375.mp4', '413.mp4', '403.mp4', '417.mp4', '371.mp4', '416.mp4', '370.mp4', '402.mp4', '372.mp4', '414.mp4', '429.mp4', '401.mp4', '373.mp4', '415.mp4']
# ['154.mp4', '140.mp4', '7.mp4', '55.mp4', '6.mp4', '141.mp4', '81.mp4', '143.mp4', '368.mp4', '5.mp4', '146.mp4', '53.mp4', '.DS_Store', '350.mp4', '52.mp4', '153.mp4', '147.mp4', '87.mp4', '50.mp4', '79.mp4', '86.mp4', '255.mp4', '137.mp4', '446.mp4', '334.mp4', '136.mp4', '297.mp4', '283.mp4', '254.mp4', '134.mp4', '493.mp4', '492.mp4', '486.mp4', '135.mp4', '109.mp4', '294.mp4', '253.mp4', '509.mp4', '284.mp4', '119.mp4', '18.mp4', '19.mp4', '118.mp4', '293.mp4', '495.mp4', '494.mp4', '457.mp4', '506.mp4', '512.mp4', '17.mp4', '472.mp4', '16.mp4', '117.mp4', '513.mp4', '507.mp4', '471.mp4', '262.mp4', '276.mp4', '299.mp4', '39.mp4', '38.mp4', '298.mp4', '107.mp4', '112.mp4', '149.mp4', '148.mp4', '88.mp4', '406.mp4', '349.mp4', '366.mp4', '367.mp4']
# adding file
# chunk:   0%|          | 0/1 [00:00<?, ?it/s, now=None]
# Moviepy - Building video behavior_data/control/0.mp4.
# MoviePy - Writing audio in 0TEMP_MPY_wvf_snd.mp4
# failed on 0
# ['154.mp4', '140.mp4', '7.mp4', '55.mp4', '6.mp4', '141.mp4', '81.mp4', '143.mp4', '368.mp4', '5.mp4', '146.mp4', '53.mp4', '.DS_Store', '350.mp4', '52.mp4', '153.mp4', '147.mp4', '87.mp4', '50.mp4', '79.mp4', '86.mp4', '255.mp4', '137.mp4', '446.mp4', '334.mp4', '136.mp4', '297.mp4', '283.mp4', '254.mp4', '134.mp4', '493.mp4', '492.mp4', '486.mp4', '135.mp4', '109.mp4', '294.mp4', '253.mp4', '509.mp4', '284.mp4', '119.mp4', '18.mp4', '19.mp4', '118.mp4', '293.mp4', '495.mp4', '494.mp4', '457.mp4', '506.mp4', '512.mp4', '17.mp4', '472.mp4', '16.mp4', '117.mp4', '513.mp4', '507.mp4', '471.mp4', '262.mp4', '276.mp4', '299.mp4', '39.mp4', '38.mp4', '298.mp4', '107.mp4', '112.mp4', '149.mp4', '148.mp4', '88.mp4', '406.mp4', '349.mp4', '366.mp4', '367.mp4']
# adding file
# chunk: 100%|██████████| 1/1 [00:00<00:00,  4.22it/s, now=None]
# chunk:   0%|          | 0/89 [00:00<?, ?it/s, now=None]
# chunk: 100%|██████████| 1/1 [00:00<00:00,  3.23it/s, now=None]
# t:   0%|          | 0/120 [00:00<?, ?it/s, now=None]
# t:  50%|█████     | 60/120 [00:00<00:00, 598.30it/s, now=None]
# Moviepy - Building video behavior_data/control/1.mp4.
# MoviePy - Writing audio in 1TEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video behavior_data/control/1.mp4
# chunk: 100%|██████████| 1/1 [00:00<00:00,  1.62it/s, now=None]
# Moviepy - Done !
# Moviepy - video ready behavior_data/control/1.mp4
# ['154.mp4', '140.mp4', '7.mp4', '55.mp4', '6.mp4', '141.mp4', '81.mp4', '143.mp4', '368.mp4', '5.mp4', '146.mp4', '1.mp4', '53.mp4', '.DS_Store', '350.mp4', '52.mp4', '153.mp4', '147.mp4', '87.mp4', '50.mp4', '79.mp4', '86.mp4', '255.mp4', '137.mp4', '446.mp4', '334.mp4', '136.mp4', '297.mp4', '283.mp4', '254.mp4', '134.mp4', '493.mp4', '492.mp4', '486.mp4', '135.mp4', '109.mp4', '294.mp4', '253.mp4', '509.mp4', '284.mp4', '119.mp4', '18.mp4', '19.mp4', '118.mp4', '293.mp4', '495.mp4', '494.mp4', '457.mp4', '506.mp4', '512.mp4', '17.mp4', '472.mp4', '16.mp4', '117.mp4', '513.mp4', '507.mp4', '471.mp4', '262.mp4', '276.mp4', '299.mp4', '39.mp4', '38.mp4', '298.mp4', '107.mp4', '112.mp4', '149.mp4', '148.mp4', '88.mp4', '406.mp4', '349.mp4', '366.mp4', '367.mp4']
# adding file
# chunk: 100%|██████████| 1/1 [00:00<00:00,  1.21it/s, now=None]
# chunk:   0%|          | 0/89 [00:00<?, ?it/s, now=None]
# chunk: 100%|██████████| 1/1 [00:00<00:00,  1.12it/s, now=None]
# t:   0%|          | 0/120 [00:00<?, ?it/s, now=None]
# t:  53%|█████▎    | 64/120 [00:00<00:00, 639.14it/s, now=None]
# Moviepy - Building video behavior_data/control/2.mp4.
# MoviePy - Writing audio in 2TEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video behavior_data/control/2.mp4
# chunk: 100%|██████████| 1/1 [00:01<00:00,  1.19s/it, now=None]
# Moviepy - Done !
# Moviepy - video ready behavior_data/control/2.mp4
# ['154.mp4', '140.mp4', '7.mp4', '55.mp4', '6.mp4', '141.mp4', '81.mp4', '143.mp4', '368.mp4', '5.mp4', '146.mp4', '1.mp4', '53.mp4', '.DS_Store', '350.mp4', '52.mp4', '153.mp4', '147.mp4', '87.mp4', '50.mp4', '2.mp4', '79.mp4', '86.mp4', '255.mp4', '137.mp4', '446.mp4', '334.mp4', '136.mp4', '297.mp4', '283.mp4', '254.mp4', '134.mp4', '493.mp4', '492.mp4', '486.mp4', '135.mp4', '109.mp4', '294.mp4', '253.mp4', '509.mp4', '284.mp4', '119.mp4', '18.mp4', '19.mp4', '118.mp4', '293.mp4', '495.mp4', '494.mp4', '457.mp4', '506.mp4', '512.mp4', '17.mp4', '472.mp4', '16.mp4', '117.mp4', '513.mp4', '507.mp4', '471.mp4', '262.mp4', '276.mp4', '299.mp4', '39.mp4', '38.mp4', '298.mp4', '107.mp4', '112.mp4', '149.mp4', '148.mp4', '88.mp4', '406.mp4', '349.mp4', '366.mp4', '367.mp4']
# adding file
# chunk: 100%|██████████| 1/1 [00:01<00:00,  1.39s/it, now=None]
# chunk:   0%|          | 0/89 [00:00<?, ?it/s, now=None]
# chunk: 100%|██████████| 1/1 [00:01<00:00,  1.48s/it, now=None]
# t:   0%|          | 0/120 [00:00<?, ?it/s, now=None]
# t:  52%|█████▏    | 62/120 [00:00<00:00, 610.36it/s, now=None]
# Moviepy - Building video behavior_data/control/3.mp4.
# MoviePy - Writing audio in 3TEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video behavior_data/control/3.mp4
# chunk: 100%|██████████| 1/1 [00:01<00:00,  1.80s/it, now=None]
# Moviepy - Done !
# Moviepy - video ready behavior_data/control/3.mp4
# staring the 3th file
# http://www.youtube.com/watch?v=WRGUUOZ5_wA
# This is url:  http://www.youtube.com/watch?v=WRGUUOZ5_wA
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-cbc6e75b459a> in <module>
#      13         y = pytube.YouTube(url)
#      14         video = y.streams.get_highest_resolution()
# ---> 15         video.download()
#      16     except Exception as e:
#      17         print(f"annoying url: {url}")
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pytube/streams.py in download(self, output_path, filename, filename_prefix, skip_existing, timeout, max_retries)
#     256         with open(file_path, "wb") as fh:
#     257             try:
# --> 258                 for chunk in request.stream(
#     259                     self.url,
#     260                     timeout=timeout,
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pytube/request.py in stream(url, timeout, max_retries)
#     179                 logger.error(e)
#     180         while True:
# --> 181             chunk = response.read()
#     182             if not chunk:
#     183                 break
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/http/client.py in read(self, amt)
#     465             else:
#     466                 try:
# --> 467                     s = self._safe_read(self.length)
#     468                 except IncompleteRead:
#     469                     self._close_conn()
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/http/client.py in _safe_read(self, amt)
#     606         IncompleteRead exception can be used to detect the problem.
#     607         """
# --> 608         data = self.fp.read(amt)
#     609         if len(data) < amt:
#     610             raise IncompleteRead(data, amt-len(data))
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# # Directory Structure
#
# ## We have one folder inside of this AnishMachineLearning folder called "behavior_data" that has the "armflapping" and "spinning" folders. There all of the sliced .mp4 files with the behavior of interest are located.
#
# ### We will process headbanging videos even if we are not going to use it because we still want it as a negative case for training the arm flapping & spinning.

# %%
# for spinning it is just the hand positions that matter right?

import cv2
import mediapipe as mp 
import numpy as np
mp_hands = mp.solutions.hands


cap = cv2.VideoCapture("/Users/anish/Documents/Machine Learning Env/AnishMachineLearning/behavior_data/spinning/37.mp4")
#cap = cv2.VideoCapture(0)
# Initiate holistic model

#capcv2.VideoCapture(0)

hands = mp_hands.Hands(min_detection_confidence = 0.5, min_tracking_confidence = 0.5)

while cap.isOpened():
    ret, image = cap.read() 
    if not ret:break 

    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image.flags.writeable = False 
    results = hands.process(image)

    image.flags.writeable = True
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
    
    height, width, _ = image.shape

    white_image = np.zeros_like(image)
    white_image.fill(255.0)
    
    #check for hand results 
    if results.multi_hand_landmarks:
        for hand_landmark in results.multi_hand_landmarks:
            for i in range(0, 21):
                landmark = hand_landmark.landmark[i]
                x = int(landmark.x * width)
                y = int(landmark.y * height)
                cv2.circle(white_image, (x, y), 5, (100, 100, 0), -1)

    cv2.imshow("", white_image)

    if cv2.waitKey(1) == ord("q"):
        break 

cap.release() 
cv2.destroyAllWindows()

# %%
list(range(21))

# %% [markdown]
# # We can try using the y values for each of the hand flapping videos and graph them to see if there is a noticeable difference of the y-values (we'll use the mean of all y-values for all 21 hand landmarks and then graph them).

# %%
import matplotlib.pyplot as plt
import os 

# first all hand flapping videos 
for hand_flap_video in os.listdir("behavior_data/armflapping"):
    video = "behavior_data/armflapping/" + hand_flap_video
    cap = cv2.VideoCapture(video)
    
    hands = mp_hands.Hands(min_detection_confidence = 0.5, min_tracking_confidence = 0.5)
    
    all_YS = [] 
    
    while cap.isOpened():
        ret, image = cap.read() 
        if not ret:break 

        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False 
        results = hands.process(image)

        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

        height, width, _ = image.shape

        #check for hand results 
        y_s = []
        
        if results.multi_hand_landmarks:
            for hand_landmark in results.multi_hand_landmarks:
                for i in range(0, 21):
                    landmark = hand_landmark.landmark[i]
                    x = int(landmark.x * width)
                    y = int(landmark.y * height)
                    y_s.append(y)
        
        all_YS.append(np.mean(y_s))

    plt.plot(range(len(all_YS)), all_YS, color = "green")
    plt.show()

# %%
# now for spinning 

import matplotlib.pyplot as plt
import os 

# first all hand flapping videos 
for hand_flap_video in os.listdir("behavior_data/spinning"):
    video = "behavior_data/spinning/" + hand_flap_video
    cap = cv2.VideoCapture(video)
    
    hands = mp_hands.Hands(min_detection_confidence = 0.5, min_tracking_confidence = 0.5)
    
    all_YS = [] 
    
    while cap.isOpened():
        ret, image = cap.read() 
        if not ret:break 

        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False 
        results = hands.process(image)

        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

        height, width, _ = image.shape

        #check for hand results 
        y_s = []
        
        if results.multi_hand_landmarks:
            for hand_landmark in results.multi_hand_landmarks:
                for i in range(0, 21):
                    landmark = hand_landmark.landmark[i]
                    x = int(landmark.x * width)
                    y = int(landmark.y * height)
                    y_s.append(y)
        
        all_YS.append(np.mean(y_s))

    plt.plot(range(len(all_YS)), all_YS, color = "green")
    plt.show()

# %%
# next for headbanging 

# now for spinning 

import matplotlib.pyplot as plt
import os 

# first all hand flapping videos 
for hand_flap_video in os.listdir("behavior_data/headbanging"):
    video = "behavior_data/headbanging/" + hand_flap_video
    cap = cv2.VideoCapture(video)
    
    hands = mp_hands.Hands(min_detection_confidence = 0.5, min_tracking_confidence = 0.5)
    
    all_YS = [] 
    
    while cap.isOpened():
        ret, image = cap.read() 
        if not ret:break 

        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False 
        results = hands.process(image)

        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

        height, width, _ = image.shape

        #check for hand results 
        y_s = []
        
        if results.multi_hand_landmarks:
            for hand_landmark in results.multi_hand_landmarks:
                for i in range(0, 21):
                    landmark = hand_landmark.landmark[i]
                    x = int(landmark.x * width)
                    y = int(landmark.y * height)
                    y_s.append(y)
        
        all_YS.append(np.mean(y_s))

    plt.plot(range(len(all_YS)), all_YS, color = "green")
    plt.show()

# %% [markdown]
# # First let's get the frames for every arm flapping and control video. If the number of frames is less than 100 frames we will not take it.

# %%
from PIL import Image as im 
import mediapipe as mp
def hand_locations(frame, min_detection_confidence = 0.2, min_tracking_confidence = 0.2): 
    hands = mp.solutions.hands.Hands(min_detection_confidence=min_detection_confidence, min_tracking_confidence=min_tracking_confidence) # MAKE SURE THIS IS ALL GOOD 
    results = hands.process(frame.astype('uint8'))
    X_locations = [0] * 42
    Y_locations = [0] * 42
    if results.multi_hand_landmarks:
        for hand, hand_landmark in enumerate(results.multi_hand_landmarks):
            for i in range(0, 21):
                landmark = hand_landmark.landmark[i]
                X_locations[i * (hand + 1)] = landmark.x
                Y_locations[i * (hand + 1)] = landmark.y
    
    locations = np.concatenate([X_locations, Y_locations])
    hands.close()
    return locations

# %%
import os, cv2
import numpy as np

ARMFLAPPING_VIDEOS = []
CONTROL_VIDEOS = []

NUM_KEEP = 100

for video_name in os.listdir('behavior_data/armflapping'): 
    cap = cv2.VideoCapture('behavior_data/armflapping/' + video_name)  
    FRAMES = [] # frames for this video 
    while True: 
        _, image = cap.read() 
        if not _ : break 
        
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        locs = hand_locations(image)

        FRAMES.append(locs)
    if len(FRAMES) >= NUM_KEEP: 
        # ignore any .DS_Store files
        ARMFLAPPING_VIDEOS.append(np.array(FRAMES))
    
    print("on a new video!")

ARMFLAPPING_LABELS = np.ones(len(ARMFLAPPING_VIDEOS))

for video_name in os.listdir('behavior_data/control'): 
    cap = cv2.VideoCapture('behavior_data/control/' + video_name)  
    FRAMES = [] # frames for this video 
    while True: 
        _, image = cap.read() 
        if not _ : break 
        
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        locs = hand_locations(image)

        FRAMES.append(locs)
        
    if len(FRAMES) >= NUM_KEEP: 
        CONTROL_VIDEOS.append(np.array(FRAMES))
    
    print("continuing on")

CONTROL_LABELS = np.zeros(len(CONTROL_VIDEOS))
# Out:
# on a new video!
# on a new video!
# on a new video!
# on a new video!
# on a new video!
# on a new video!
# on a new video!
# on a new video!
# on a new video!
# on a new video!
# on a new video!
# on a new video!
# on a new video!
# on a new video!
# on a new video!
# on a new video!
# on a new video!
# on a new video!
# on a new video!
# on a new video!
# on a new video!
# on a new video!
# on a new video!
# on a new video!
# on a new video!
# on a new video!
# on a new video!
# on a new video!
# on a new video!
# on a new video!
# on a new video!
# on a new video!
# on a new video!
# on a new video!
# on a new video!
# on a new video!
# on a new video!
# on a new video!
# on a new video!
# on a new video!
# on a new video!
# on a new video!
# on a new video!
# on a new video!
# on a new video!
# on a new video!
# on a new video!
# on a new video!
# on a new video!
# on a new video!
# on a new video!
# on a new video!
# on a new video!
# on a new video!
# on a new video!
# on a new video!
# on a new video!
# on a new video!
# on a new video!
# on a new video!
# on a new video!
# on a new video!
# on a new video!
# on a new video!
# on a new video!
# on a new video!
# on a new video!
# on a new video!
# on a new video!
# on a new video!
# on a new video!
# on a new video!
# on a new video!
# on a new video!
# on a new video!
# on a new video!
# on a new video!
# continuing on
# continuing on
# continuing on
# continuing on
# continuing on
# continuing on
# continuing on
# continuing on
# continuing on
# continuing on
# continuing on
# continuing on
# continuing on
# continuing on
# continuing on
# continuing on
# continuing on
# continuing on
# continuing on
# continuing on
# continuing on
# continuing on
# continuing on
# continuing on
# continuing on
# continuing on
# continuing on
# continuing on
# continuing on
# continuing on
# continuing on
# continuing on
# continuing on
# continuing on
# continuing on
# continuing on
# continuing on
# continuing on
# continuing on
# continuing on
# continuing on
# continuing on
# continuing on
# continuing on
# continuing on
# continuing on
# continuing on
# continuing on
# continuing on
# continuing on
# continuing on
# continuing on
# continuing on
# continuing on
# continuing on
# continuing on
# continuing on
# continuing on
# continuing on
# continuing on
# continuing on
# continuing on
# continuing on
# continuing on
# continuing on
# continuing on
# continuing on
# continuing on
# continuing on
# continuing on
# continuing on
# continuing on
# continuing on
# continuing on

# %%
#### shuffle and then balance the amount of videos
print(len(CONTROL_VIDEOS), len(ARMFLAPPING_VIDEOS))
amount_of_videos = min([len(CONTROL_VIDEOS), len(ARMFLAPPING_VIDEOS)])

ARMFLAPPING_VIDEOS = np.array(ARMFLAPPING_VIDEOS, dtype = "object")
CONTROL_VIDEOS = np.array(CONTROL_VIDEOS, dtype = "object")
import numpy as np
control_permutation = np.random.permutation(CONTROL_LABELS.shape[0])
CONTROL_VIDEOS, CONTROL_LABELS = CONTROL_VIDEOS[control_permutation], CONTROL_LABELS[control_permutation]

armflapping_permutation = np.random.permutation(ARMFLAPPING_LABELS.shape[0])
ARMFLAPPING_VIDEOS, ARMFLAPPING_LABELS = ARMFLAPPING_VIDEOS[armflapping_permutation], ARMFLAPPING_LABELS[armflapping_permutation]

ARMFLAPPING_VIDEOS, ARMFLAPPING_LABELS = ARMFLAPPING_VIDEOS[:amount_of_videos], ARMFLAPPING_LABELS[:amount_of_videos]
CONTROL_VIDEOS, CONTROL_LABELS = CONTROL_VIDEOS[:amount_of_videos], CONTROL_LABELS[:amount_of_videos]
# Out:
# 46 60

# %%
assert len(ARMFLAPPING_VIDEOS) == len(CONTROL_VIDEOS)

# %%
selected_armflapping_frames = [] # the dimensions of this will be (BS, 100, 84) 
selected_control_frames = [] 

for FRAMES in ARMFLAPPING_VIDEOS: 
    selected_armflapping_frames.append(FRAMES[:NUM_KEEP])

for FRAMES in CONTROL_VIDEOS: 
    selected_control_frames.append(FRAMES[:NUM_KEEP])

# %%
ARMFLAPPING_LOCATIONS = np.array(selected_armflapping_frames)
CONTROL_LOCATIONS = np.array(selected_control_frames)

# %%
# save these in a pickle file

import pickle 
with open("armflapping_locations.pickle", 'wb') as f: 
    pickle.dump(ARMFLAPPING_LOCATIONS, f)

with open('control_locations.pickle', 'wb') as f: 
    pickle.dump(CONTROL_LOCATIONS, f)

# %% [markdown]
# # Now that we have the data for both classes, we'll concatenate it and start training (first with no augmentations.)

# %%
from sklearn.model_selection import train_test_split

def generate_data(ARMFLAPPING_LOCATIONS, CONTROL_LOCATIONS, random_state = 42): 
    ARMFLAPPING_LABELS = np.ones(ARMFLAPPING_LOCATIONS.shape[0])
    CONTROL_LABELS = np.zeros(CONTROL_LOCATIONS.shape[0])
    
    # concatenate 
    data = np.concatenate([ARMFLAPPING_LOCATIONS, CONTROL_LOCATIONS])
    labels = np.concatenate([ARMFLAPPING_LABELS, CONTROL_LABELS])
    
    X_train, X_test, y_train, y_test = train_test_split(data, labels, random_state = random_state)
    
    return X_train, X_test, y_train, y_test 

X_train, X_test, y_train, y_test = generate_data(ARMFLAPPING_LOCATIONS, CONTROL_LOCATIONS)

# %%
# start training with a vanilla LSTM. 
import tensorflow as tf 
import keras 

model = tf.keras.models.Sequential([
    tf.keras.layers.LSTM(64, return_sequences = True), 
    tf.keras.layers.LSTM(128, return_sequences = True), 
    tf.keras.layers.LSTM(256, return_sequences = False), 
    tf.keras.layers.Dense(128, activation = "relu")
    tf.keras.layers.Dense(1, activation = "sigmoid")
])

model.compile(loss = "sparse_categorical_crossentropy", optimizer = "Adam", metrics = ['accuracy'])
# Out:
#   File "<ipython-input-144-165628254afe>", line 10
#     tf.keras.layers.Dense(1, activation = "sigmoid")
#     ^
# SyntaxError: invalid syntax

# %%
model.fit(np.concatenate([X_train, X_test]), np.concatenate([y_train, y_test]), epochs = 1000)
# Out:
# Epoch 1/1000
# 3/3 [==============================] - 0s 54ms/step - loss: 0.2240 - accuracy: 0.5029
# Epoch 2/1000
# 3/3 [==============================] - 0s 55ms/step - loss: 0.2275 - accuracy: 0.5027
# Epoch 3/1000
# 3/3 [==============================] - 0s 55ms/step - loss: 0.2236 - accuracy: 0.5029
# Epoch 4/1000
# 3/3 [==============================] - 0s 54ms/step - loss: 0.2244 - accuracy: 0.5029
# Epoch 5/1000
# 3/3 [==============================] - 0s 54ms/step - loss: 0.2262 - accuracy: 0.5030
# Epoch 6/1000
# 3/3 [==============================] - 0s 54ms/step - loss: 0.2219 - accuracy: 0.5030
# Epoch 7/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.2260 - accuracy: 0.5027
# Epoch 8/1000
# 3/3 [==============================] - 0s 55ms/step - loss: 0.2297 - accuracy: 0.5034
# Epoch 9/1000
# 3/3 [==============================] - 0s 56ms/step - loss: 0.2306 - accuracy: 0.5029
# Epoch 10/1000
# 3/3 [==============================] - 0s 55ms/step - loss: 0.2369 - accuracy: 0.5027
# Epoch 11/1000
# 3/3 [==============================] - 0s 56ms/step - loss: 0.2493 - accuracy: 0.5036
# Epoch 12/1000
# 3/3 [==============================] - 0s 55ms/step - loss: 0.2354 - accuracy: 0.5030
# Epoch 13/1000
# 3/3 [==============================] - 0s 54ms/step - loss: 0.2267 - accuracy: 0.5028
# Epoch 14/1000
# 3/3 [==============================] - 0s 54ms/step - loss: 0.2285 - accuracy: 0.5035
# Epoch 15/1000
# 3/3 [==============================] - 0s 55ms/step - loss: 0.2260 - accuracy: 0.5033
# Epoch 16/1000
# 3/3 [==============================] - 0s 55ms/step - loss: 0.2259 - accuracy: 0.5027
# Epoch 17/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.2209 - accuracy: 0.5032
# Epoch 18/1000
# 3/3 [==============================] - 0s 57ms/step - loss: 0.2255 - accuracy: 0.5033
# Epoch 19/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.2197 - accuracy: 0.5029
# Epoch 20/1000
# 3/3 [==============================] - 0s 56ms/step - loss: 0.2241 - accuracy: 0.5028
# Epoch 21/1000
# 3/3 [==============================] - 0s 57ms/step - loss: 0.2326 - accuracy: 0.5033
# Epoch 22/1000
# 3/3 [==============================] - 0s 57ms/step - loss: 0.2232 - accuracy: 0.5029
# Epoch 23/1000
# 3/3 [==============================] - 0s 57ms/step - loss: 0.2269 - accuracy: 0.5027
# Epoch 24/1000
# 3/3 [==============================] - 0s 57ms/step - loss: 0.2234 - accuracy: 0.5034
# Epoch 25/1000
# 3/3 [==============================] - 0s 54ms/step - loss: 0.2201 - accuracy: 0.5033
# Epoch 26/1000
# 3/3 [==============================] - 0s 53ms/step - loss: 0.2215 - accuracy: 0.5028
# Epoch 27/1000
# 3/3 [==============================] - 0s 53ms/step - loss: 0.2191 - accuracy: 0.5029
# Epoch 28/1000
# 3/3 [==============================] - 0s 53ms/step - loss: 0.2246 - accuracy: 0.5034
# Epoch 29/1000
# 3/3 [==============================] - 0s 55ms/step - loss: 0.2223 - accuracy: 0.5027
# Epoch 30/1000
# 3/3 [==============================] - 0s 54ms/step - loss: 0.2210 - accuracy: 0.5030
# Epoch 31/1000
# 3/3 [==============================] - 0s 54ms/step - loss: 0.2236 - accuracy: 0.5033
# Epoch 32/1000
# 3/3 [==============================] - 0s 55ms/step - loss: 0.2245 - accuracy: 0.5028
# Epoch 33/1000
# 3/3 [==============================] - 0s 55ms/step - loss: 0.2220 - accuracy: 0.5030
# Epoch 34/1000
# 3/3 [==============================] - 0s 53ms/step - loss: 0.2285 - accuracy: 0.5033
# Epoch 35/1000
# 3/3 [==============================] - 0s 55ms/step - loss: 0.2225 - accuracy: 0.5028
# Epoch 36/1000
# 3/3 [==============================] - 0s 55ms/step - loss: 0.2211 - accuracy: 0.5029
# Epoch 37/1000
# 3/3 [==============================] - 0s 56ms/step - loss: 0.2194 - accuracy: 0.5034
# Epoch 38/1000
# 3/3 [==============================] - 0s 57ms/step - loss: 0.2199 - accuracy: 0.5028
# Epoch 39/1000
# 3/3 [==============================] - 0s 54ms/step - loss: 0.2176 - accuracy: 0.5030
# Epoch 40/1000
# 3/3 [==============================] - 0s 55ms/step - loss: 0.2234 - accuracy: 0.5034
# Epoch 41/1000
# 3/3 [==============================] - 0s 55ms/step - loss: 0.2266 - accuracy: 0.5030
# Epoch 42/1000
# 3/3 [==============================] - 0s 56ms/step - loss: 0.2150 - accuracy: 0.5030
# Epoch 43/1000
# 3/3 [==============================] - 0s 56ms/step - loss: 0.2234 - accuracy: 0.5033
# Epoch 44/1000
# 3/3 [==============================] - 0s 56ms/step - loss: 0.2175 - accuracy: 0.5029
# Epoch 45/1000
# 3/3 [==============================] - 0s 57ms/step - loss: 0.2238 - accuracy: 0.5026
# Epoch 46/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.2281 - accuracy: 0.5034
# Epoch 47/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.2231 - accuracy: 0.5032
# Epoch 48/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.2200 - accuracy: 0.5027
# Epoch 49/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.2207 - accuracy: 0.5032
# Epoch 50/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.2163 - accuracy: 0.5030
# Epoch 51/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.2179 - accuracy: 0.5028
# Epoch 52/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.2203 - accuracy: 0.5029
# Epoch 53/1000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.2194 - accuracy: 0.5035
# Epoch 54/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.2201 - accuracy: 0.5028
# Epoch 55/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.2202 - accuracy: 0.5030
# Epoch 56/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.2207 - accuracy: 0.5034
# Epoch 57/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.2154 - accuracy: 0.5029
# Epoch 58/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.2160 - accuracy: 0.5029
# Epoch 59/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.2178 - accuracy: 0.5032
# Epoch 60/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.2157 - accuracy: 0.5030
# Epoch 61/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.2145 - accuracy: 0.5029
# Epoch 62/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.2144 - accuracy: 0.5030
# Epoch 63/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.2174 - accuracy: 0.5032
# Epoch 64/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.2146 - accuracy: 0.5029
# Epoch 65/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.2160 - accuracy: 0.5030
# Epoch 66/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.2182 - accuracy: 0.5033
# Epoch 67/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.2160 - accuracy: 0.5032
# Epoch 68/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.2148 - accuracy: 0.5029
# Epoch 69/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.2157 - accuracy: 0.5033
# Epoch 70/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.2135 - accuracy: 0.5030
# Epoch 71/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.2127 - accuracy: 0.5032
# Epoch 72/1000
# 3/3 [==============================] - 0s 66ms/step - loss: 0.2146 - accuracy: 0.5030
# Epoch 73/1000
# 3/3 [==============================] - 0s 65ms/step - loss: 0.2141 - accuracy: 0.5033
# Epoch 74/1000
# 3/3 [==============================] - 0s 66ms/step - loss: 0.2132 - accuracy: 0.5029
# Epoch 75/1000
# 3/3 [==============================] - 0s 69ms/step - loss: 0.2159 - accuracy: 0.5030
# Epoch 76/1000
# 3/3 [==============================] - 0s 65ms/step - loss: 0.2131 - accuracy: 0.5033
# Epoch 77/1000
# 3/3 [==============================] - 0s 65ms/step - loss: 0.2141 - accuracy: 0.5030
# Epoch 78/1000
# 3/3 [==============================] - 0s 65ms/step - loss: 0.2134 - accuracy: 0.5032
# Epoch 79/1000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.2126 - accuracy: 0.5032
# Epoch 80/1000
# 3/3 [==============================] - 0s 65ms/step - loss: 0.2140 - accuracy: 0.5030
# Epoch 81/1000
# 3/3 [==============================] - 0s 65ms/step - loss: 0.2127 - accuracy: 0.5033
# Epoch 82/1000
# 3/3 [==============================] - 0s 65ms/step - loss: 0.2133 - accuracy: 0.5033
# Epoch 83/1000
# 3/3 [==============================] - 0s 65ms/step - loss: 0.2130 - accuracy: 0.5030
# Epoch 84/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.2131 - accuracy: 0.5030
# Epoch 85/1000
# 3/3 [==============================] - 0s 65ms/step - loss: 0.2120 - accuracy: 0.5033
# Epoch 86/1000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.2120 - accuracy: 0.5033
# Epoch 87/1000
# 3/3 [==============================] - 0s 66ms/step - loss: 0.2133 - accuracy: 0.5030
# Epoch 88/1000
# 3/3 [==============================] - 0s 67ms/step - loss: 0.2103 - accuracy: 0.5030
# Epoch 89/1000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.2147 - accuracy: 0.5033
# Epoch 90/1000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.2197 - accuracy: 0.5028
# Epoch 91/1000
# 3/3 [==============================] - 0s 65ms/step - loss: 0.2272 - accuracy: 0.5032
# Epoch 92/1000
# 3/3 [==============================] - 0s 72ms/step - loss: 0.2293 - accuracy: 0.5029
# Epoch 93/1000
# 3/3 [==============================] - 0s 68ms/step - loss: 0.2181 - accuracy: 0.5033
# Epoch 94/1000
# 3/3 [==============================] - 0s 66ms/step - loss: 0.2218 - accuracy: 0.5033
# Epoch 95/1000
# 3/3 [==============================] - 0s 67ms/step - loss: 0.2255 - accuracy: 0.5030
# Epoch 96/1000
# 3/3 [==============================] - 0s 67ms/step - loss: 0.2255 - accuracy: 0.5035
# Epoch 97/1000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.2149 - accuracy: 0.5029
# Epoch 98/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.2139 - accuracy: 0.5033
# Epoch 99/1000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.2126 - accuracy: 0.5035
# Epoch 100/1000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.2104 - accuracy: 0.5033
# Epoch 101/1000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.2120 - accuracy: 0.5033
# Epoch 102/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.2122 - accuracy: 0.5032
# Epoch 103/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.2159 - accuracy: 0.5029
# Epoch 104/1000
# 3/3 [==============================] - 0s 68ms/step - loss: 0.2084 - accuracy: 0.5033
# Epoch 105/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.2153 - accuracy: 0.5035
# Epoch 106/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.2190 - accuracy: 0.5027
# Epoch 107/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.2160 - accuracy: 0.5032
# Epoch 108/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.2077 - accuracy: 0.5034
# Epoch 109/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.2137 - accuracy: 0.5030
# Epoch 110/1000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.2105 - accuracy: 0.5034
# Epoch 111/1000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.2135 - accuracy: 0.5034
# Epoch 112/1000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.2228 - accuracy: 0.5029
# Epoch 113/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.2413 - accuracy: 0.5037
# Epoch 114/1000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.2267 - accuracy: 0.5033
# Epoch 115/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.2276 - accuracy: 0.5032
# Epoch 116/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.2208 - accuracy: 0.5035
# Epoch 117/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.2178 - accuracy: 0.5032
# Epoch 118/1000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.2098 - accuracy: 0.5033
# Epoch 119/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.2146 - accuracy: 0.5033
# Epoch 120/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.2279 - accuracy: 0.5027
# Epoch 121/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.2343 - accuracy: 0.5035
# Epoch 122/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.2400 - accuracy: 0.5030
# Epoch 123/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.2348 - accuracy: 0.5030
# Epoch 124/1000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.5144 - accuracy: 0.5035
# Epoch 125/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.4356 - accuracy: 0.5028
# Epoch 126/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.3710 - accuracy: 0.5032
# Epoch 127/1000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.5839 - accuracy: 0.5033
# Epoch 128/1000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.3769 - accuracy: 0.5038
# Epoch 129/1000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.3948 - accuracy: 0.5040
# Epoch 130/1000
# 3/3 [==============================] - 0s 65ms/step - loss: 0.3897 - accuracy: 0.5040
# Epoch 131/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.3382 - accuracy: 0.5042
# Epoch 132/1000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.3161 - accuracy: 0.5040
# Epoch 133/1000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.2897 - accuracy: 0.5036
# Epoch 134/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.4045 - accuracy: 0.5027
# Epoch 135/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.2936 - accuracy: 0.5029
# Epoch 136/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.4932 - accuracy: 0.5033
# Epoch 137/1000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.2611 - accuracy: 0.5035
# Epoch 138/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.3361 - accuracy: 0.5024
# Epoch 139/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.2897 - accuracy: 0.5032
# Epoch 140/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.3230 - accuracy: 0.5036
# Epoch 141/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.2678 - accuracy: 0.5028
# Epoch 142/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.2561 - accuracy: 0.5025
# Epoch 143/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.2421 - accuracy: 0.5033
# Epoch 144/1000
# 3/3 [==============================] - 0s 65ms/step - loss: 0.2407 - accuracy: 0.5029
# Epoch 145/1000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.2379 - accuracy: 0.5026
# Epoch 146/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.2232 - accuracy: 0.5028
# Epoch 147/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.2283 - accuracy: 0.5027
# Epoch 148/1000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.2200 - accuracy: 0.5029
# Epoch 149/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.2228 - accuracy: 0.5037
# Epoch 150/1000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.2168 - accuracy: 0.5032
# Epoch 151/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.2223 - accuracy: 0.5027
# Epoch 152/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.2146 - accuracy: 0.5033
# Epoch 153/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.2229 - accuracy: 0.5034
# Epoch 154/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.2192 - accuracy: 0.5029
# Epoch 155/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.2155 - accuracy: 0.5029
# Epoch 156/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.2141 - accuracy: 0.5032
# Epoch 157/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.2130 - accuracy: 0.5033
# Epoch 158/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.2117 - accuracy: 0.5032
# Epoch 159/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.2134 - accuracy: 0.5032
# Epoch 160/1000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.2099 - accuracy: 0.5030
# Epoch 161/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.2110 - accuracy: 0.5030
# Epoch 162/1000
# 3/3 [==============================] - 0s 71ms/step - loss: 0.2116 - accuracy: 0.5030
# Epoch 163/1000
# 3/3 [==============================] - 0s 71ms/step - loss: 0.2120 - accuracy: 0.5032
# Epoch 164/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.2113 - accuracy: 0.5032
# Epoch 165/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.2112 - accuracy: 0.5030
# Epoch 166/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.2088 - accuracy: 0.5032
# Epoch 167/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.2106 - accuracy: 0.5033
# Epoch 168/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.2091 - accuracy: 0.5032
# Epoch 169/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.2090 - accuracy: 0.5030
# Epoch 170/1000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.2072 - accuracy: 0.5032
# Epoch 171/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.2125 - accuracy: 0.5034
# Epoch 172/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.2067 - accuracy: 0.5030
# Epoch 173/1000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.2088 - accuracy: 0.5029
# Epoch 174/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.2082 - accuracy: 0.5030
# Epoch 175/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.2085 - accuracy: 0.5033
# Epoch 176/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.2071 - accuracy: 0.5033
# Epoch 177/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.2077 - accuracy: 0.5032
# Epoch 178/1000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.2073 - accuracy: 0.5030
# Epoch 179/1000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.2082 - accuracy: 0.5032
# Epoch 180/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.2070 - accuracy: 0.5032
# Epoch 181/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.2063 - accuracy: 0.5032
# Epoch 182/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.2075 - accuracy: 0.5032
# Epoch 183/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.2064 - accuracy: 0.5030
# Epoch 184/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.2075 - accuracy: 0.5030
# Epoch 185/1000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.2060 - accuracy: 0.5033
# Epoch 186/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.2083 - accuracy: 0.5033
# Epoch 187/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.2059 - accuracy: 0.5032
# Epoch 188/1000
# 3/3 [==============================] - 0s 65ms/step - loss: 0.2056 - accuracy: 0.5030
# Epoch 189/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.2054 - accuracy: 0.5033
# Epoch 190/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.2054 - accuracy: 0.5033
# Epoch 191/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.2046 - accuracy: 0.5033
# Epoch 192/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.2054 - accuracy: 0.5033
# Epoch 193/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.2043 - accuracy: 0.5033
# Epoch 194/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.2047 - accuracy: 0.5033
# Epoch 195/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.2061 - accuracy: 0.5033
# Epoch 196/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.2047 - accuracy: 0.5030
# Epoch 197/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.2054 - accuracy: 0.5033
# Epoch 198/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.2047 - accuracy: 0.5033
# Epoch 199/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.2050 - accuracy: 0.5033
# Epoch 200/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.2055 - accuracy: 0.5033
# Epoch 201/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.2052 - accuracy: 0.5033
# Epoch 202/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.2041 - accuracy: 0.5033
# Epoch 203/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.2042 - accuracy: 0.5029
# Epoch 204/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.2045 - accuracy: 0.5033
# Epoch 205/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.2042 - accuracy: 0.5033
# Epoch 206/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.2040 - accuracy: 0.5033
# Epoch 207/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.2043 - accuracy: 0.5030
# Epoch 208/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.2050 - accuracy: 0.5033
# Epoch 209/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.2036 - accuracy: 0.5032
# Epoch 210/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.2034 - accuracy: 0.5032
# Epoch 211/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.2033 - accuracy: 0.5032
# Epoch 212/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.2058 - accuracy: 0.5034
# Epoch 213/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.2027 - accuracy: 0.5033
# Epoch 214/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.2048 - accuracy: 0.5028
# Epoch 215/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.2039 - accuracy: 0.5033
# Epoch 216/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.2034 - accuracy: 0.5034
# Epoch 217/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.2030 - accuracy: 0.5032
# Epoch 218/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.2042 - accuracy: 0.5030
# Epoch 219/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.2066 - accuracy: 0.5034
# Epoch 220/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.2020 - accuracy: 0.5033
# Epoch 221/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.2045 - accuracy: 0.5028
# Epoch 222/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.2048 - accuracy: 0.5034
# Epoch 223/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.2041 - accuracy: 0.5035
# Epoch 224/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.2029 - accuracy: 0.5030
# Epoch 225/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.2019 - accuracy: 0.5033
# Epoch 226/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.2035 - accuracy: 0.5034
# Epoch 227/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.2035 - accuracy: 0.5033
# Epoch 228/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.2013 - accuracy: 0.5032
# Epoch 229/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.2009 - accuracy: 0.5033
# Epoch 230/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.2024 - accuracy: 0.5032
# Epoch 231/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.2039 - accuracy: 0.5033
# Epoch 232/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.2031 - accuracy: 0.5032
# Epoch 233/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.2027 - accuracy: 0.5029
# Epoch 234/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.2033 - accuracy: 0.5034
# Epoch 235/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.2008 - accuracy: 0.5035
# Epoch 236/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.2027 - accuracy: 0.5030
# Epoch 237/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.1998 - accuracy: 0.5032
# Epoch 238/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.2044 - accuracy: 0.5035
# Epoch 239/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.2005 - accuracy: 0.5030
# Epoch 240/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.2004 - accuracy: 0.5030
# Epoch 241/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.2003 - accuracy: 0.5032
# Epoch 242/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.2008 - accuracy: 0.5034
# Epoch 243/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.2048 - accuracy: 0.5029
# Epoch 244/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.2005 - accuracy: 0.5032
# Epoch 245/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.2020 - accuracy: 0.5034
# Epoch 246/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.2004 - accuracy: 0.5033
# Epoch 247/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.2007 - accuracy: 0.5033
# Epoch 248/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.2001 - accuracy: 0.5032
# Epoch 249/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.2027 - accuracy: 0.5033
# Epoch 250/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.2003 - accuracy: 0.5032
# Epoch 251/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.2014 - accuracy: 0.5032
# Epoch 252/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.2005 - accuracy: 0.5034
# Epoch 253/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.1987 - accuracy: 0.5033
# Epoch 254/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.2001 - accuracy: 0.5029
# Epoch 255/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1995 - accuracy: 0.5032
# Epoch 256/1000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.2003 - accuracy: 0.5034
# Epoch 257/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.2000 - accuracy: 0.5032
# Epoch 258/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.1983 - accuracy: 0.5032
# Epoch 259/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.2003 - accuracy: 0.5033
# Epoch 260/1000
# 3/3 [==============================] - 0s 65ms/step - loss: 0.1978 - accuracy: 0.5032
# Epoch 261/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.2007 - accuracy: 0.5029
# Epoch 262/1000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.1995 - accuracy: 0.5033
# Epoch 263/1000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.2001 - accuracy: 0.5035
# Epoch 264/1000
# 3/3 [==============================] - 0s 67ms/step - loss: 0.1989 - accuracy: 0.5032
# Epoch 265/1000
# 3/3 [==============================] - 0s 69ms/step - loss: 0.1988 - accuracy: 0.5029
# Epoch 266/1000
# 3/3 [==============================] - 0s 69ms/step - loss: 0.1987 - accuracy: 0.5034
# Epoch 267/1000
# 3/3 [==============================] - 0s 71ms/step - loss: 0.2000 - accuracy: 0.5033
# Epoch 268/1000
# 3/3 [==============================] - 0s 69ms/step - loss: 0.2003 - accuracy: 0.5032
# Epoch 269/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.1985 - accuracy: 0.5032
# Epoch 270/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.1983 - accuracy: 0.5034
# Epoch 271/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.2011 - accuracy: 0.5030
# Epoch 272/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.1997 - accuracy: 0.5033
# Epoch 273/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.1977 - accuracy: 0.5034
# Epoch 274/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1968 - accuracy: 0.5032
# Epoch 275/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1993 - accuracy: 0.5029
# Epoch 276/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.1971 - accuracy: 0.5033
# Epoch 277/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.1985 - accuracy: 0.5034
# Epoch 278/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1989 - accuracy: 0.5029
# Epoch 279/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.1972 - accuracy: 0.5030
# Epoch 280/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.1984 - accuracy: 0.5033
# Epoch 281/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.1987 - accuracy: 0.5033
# Epoch 282/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.1980 - accuracy: 0.5029
# Epoch 283/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.1985 - accuracy: 0.5032
# Epoch 284/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1996 - accuracy: 0.5034
# Epoch 285/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1967 - accuracy: 0.5034
# Epoch 286/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.1974 - accuracy: 0.5029
# Epoch 287/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1964 - accuracy: 0.5030
# Epoch 288/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1972 - accuracy: 0.5034
# Epoch 289/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1980 - accuracy: 0.5034
# Epoch 290/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1957 - accuracy: 0.5033
# Epoch 291/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1981 - accuracy: 0.5028
# Epoch 292/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1984 - accuracy: 0.5034
# Epoch 293/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1960 - accuracy: 0.5033
# Epoch 294/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1968 - accuracy: 0.5030
# Epoch 295/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1973 - accuracy: 0.5033
# Epoch 296/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1967 - accuracy: 0.5034
# Epoch 297/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1952 - accuracy: 0.5033
# Epoch 298/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1956 - accuracy: 0.5034
# Epoch 299/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1960 - accuracy: 0.5034
# Epoch 300/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1952 - accuracy: 0.5032
# Epoch 301/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1990 - accuracy: 0.5034
# Epoch 302/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1958 - accuracy: 0.5034
# Epoch 303/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1947 - accuracy: 0.5034
# Epoch 304/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1956 - accuracy: 0.5033
# Epoch 305/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1952 - accuracy: 0.5034
# Epoch 306/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1957 - accuracy: 0.5033
# Epoch 307/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.1957 - accuracy: 0.5029
# Epoch 308/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1939 - accuracy: 0.5032
# Epoch 309/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1978 - accuracy: 0.5034
# Epoch 310/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1946 - accuracy: 0.5033
# Epoch 311/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.1961 - accuracy: 0.5028
# Epoch 312/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1948 - accuracy: 0.5033
# Epoch 313/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1969 - accuracy: 0.5033
# Epoch 314/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1952 - accuracy: 0.5029
# Epoch 315/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1950 - accuracy: 0.5034
# Epoch 316/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.1948 - accuracy: 0.5034
# Epoch 317/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1953 - accuracy: 0.5032
# Epoch 318/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1943 - accuracy: 0.5033
# Epoch 319/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1938 - accuracy: 0.5032
# Epoch 320/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1943 - accuracy: 0.5034
# Epoch 321/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1936 - accuracy: 0.5034
# Epoch 322/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1938 - accuracy: 0.5033
# Epoch 323/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1942 - accuracy: 0.5033
# Epoch 324/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1936 - accuracy: 0.5032
# Epoch 325/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1952 - accuracy: 0.5035
# Epoch 326/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1949 - accuracy: 0.5035
# Epoch 327/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1933 - accuracy: 0.5032
# Epoch 328/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1946 - accuracy: 0.5033
# Epoch 329/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1932 - accuracy: 0.5034
# Epoch 330/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1927 - accuracy: 0.5034
# Epoch 331/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1934 - accuracy: 0.5034
# Epoch 332/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1936 - accuracy: 0.5030
# Epoch 333/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1928 - accuracy: 0.5034
# Epoch 334/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1936 - accuracy: 0.5034
# Epoch 335/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1921 - accuracy: 0.5034
# Epoch 336/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1943 - accuracy: 0.5034
# Epoch 337/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1925 - accuracy: 0.5034
# Epoch 338/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1943 - accuracy: 0.5030
# Epoch 339/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1919 - accuracy: 0.5033
# Epoch 340/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1942 - accuracy: 0.5035
# Epoch 341/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.1935 - accuracy: 0.5030
# Epoch 342/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1932 - accuracy: 0.5030
# Epoch 343/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1916 - accuracy: 0.5034
# Epoch 344/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1960 - accuracy: 0.5034
# Epoch 345/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1971 - accuracy: 0.5033
# Epoch 346/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.1944 - accuracy: 0.5032
# Epoch 347/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1919 - accuracy: 0.5034
# Epoch 348/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1938 - accuracy: 0.5035
# Epoch 349/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1931 - accuracy: 0.5033
# Epoch 350/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1931 - accuracy: 0.5028
# Epoch 351/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1930 - accuracy: 0.5035
# Epoch 352/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1930 - accuracy: 0.5036
# Epoch 353/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1925 - accuracy: 0.5032
# Epoch 354/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1944 - accuracy: 0.5029
# Epoch 355/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1952 - accuracy: 0.5036
# Epoch 356/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1915 - accuracy: 0.5034
# Epoch 357/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1999 - accuracy: 0.5029
# Epoch 358/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1966 - accuracy: 0.5036
# Epoch 359/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1930 - accuracy: 0.5035
# Epoch 360/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.1938 - accuracy: 0.5027
# Epoch 361/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1956 - accuracy: 0.5033
# Epoch 362/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1925 - accuracy: 0.5034
# Epoch 363/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1911 - accuracy: 0.5033
# Epoch 364/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1910 - accuracy: 0.5030
# Epoch 365/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1928 - accuracy: 0.5034
# Epoch 366/1000
# 3/3 [==============================] - 0s 57ms/step - loss: 0.1923 - accuracy: 0.5035
# Epoch 367/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.1906 - accuracy: 0.5034
# Epoch 368/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.1918 - accuracy: 0.5029
# Epoch 369/1000
# 3/3 [==============================] - 0s 57ms/step - loss: 0.1918 - accuracy: 0.5034
# Epoch 370/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.1910 - accuracy: 0.5035
# Epoch 371/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.1934 - accuracy: 0.5032
# Epoch 372/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.1920 - accuracy: 0.5029
# Epoch 373/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.1918 - accuracy: 0.5035
# Epoch 374/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.1914 - accuracy: 0.5035
# Epoch 375/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1900 - accuracy: 0.5034
# Epoch 376/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.1906 - accuracy: 0.5030
# Epoch 377/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1905 - accuracy: 0.5034
# Epoch 378/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1901 - accuracy: 0.5034
# Epoch 379/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1916 - accuracy: 0.5034
# Epoch 380/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.1909 - accuracy: 0.5030
# Epoch 381/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1914 - accuracy: 0.5035
# Epoch 382/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.1893 - accuracy: 0.5034
# Epoch 383/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.1899 - accuracy: 0.5034
# Epoch 384/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1905 - accuracy: 0.5035
# Epoch 385/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1895 - accuracy: 0.5035
# Epoch 386/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1898 - accuracy: 0.5035
# Epoch 387/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1900 - accuracy: 0.5035
# Epoch 388/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1904 - accuracy: 0.5034
# Epoch 389/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1900 - accuracy: 0.5034
# Epoch 390/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1894 - accuracy: 0.5035
# Epoch 391/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1895 - accuracy: 0.5034
# Epoch 392/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1917 - accuracy: 0.5035
# Epoch 393/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1899 - accuracy: 0.5035
# Epoch 394/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.1902 - accuracy: 0.5035
# Epoch 395/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1886 - accuracy: 0.5034
# Epoch 396/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1884 - accuracy: 0.5034
# Epoch 397/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.1882 - accuracy: 0.5034
# Epoch 398/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1903 - accuracy: 0.5035
# Epoch 399/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1914 - accuracy: 0.5032
# Epoch 400/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1909 - accuracy: 0.5032
# Epoch 401/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1896 - accuracy: 0.5034
# Epoch 402/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1893 - accuracy: 0.5034
# Epoch 403/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.1872 - accuracy: 0.5034
# Epoch 404/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.1930 - accuracy: 0.5035
# Epoch 405/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.1893 - accuracy: 0.5034
# Epoch 406/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1892 - accuracy: 0.5035
# Epoch 407/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1902 - accuracy: 0.5034
# Epoch 408/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1887 - accuracy: 0.5034
# Epoch 409/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.1872 - accuracy: 0.5034
# Epoch 410/1000
# 3/3 [==============================] - 0s 57ms/step - loss: 0.1886 - accuracy: 0.5030
# Epoch 411/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.1885 - accuracy: 0.5034
# Epoch 412/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1882 - accuracy: 0.5035
# Epoch 413/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1889 - accuracy: 0.5034
# Epoch 414/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1886 - accuracy: 0.5034
# Epoch 415/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1880 - accuracy: 0.5034
# Epoch 416/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.1876 - accuracy: 0.5035
# Epoch 417/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.1874 - accuracy: 0.5035
# Epoch 418/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.1892 - accuracy: 0.5035
# Epoch 419/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1869 - accuracy: 0.5034
# Epoch 420/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1867 - accuracy: 0.5034
# Epoch 421/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1886 - accuracy: 0.5034
# Epoch 422/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1871 - accuracy: 0.5034
# Epoch 423/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1877 - accuracy: 0.5035
# Epoch 424/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.1877 - accuracy: 0.5035
# Epoch 425/1000
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1671 - accuracy: 0.4425
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-145-a1820218c994> in <module>
# ----> 1 model.fit(np.concatenate([X_train, X_test]), np.concatenate([y_train, y_test]), epochs = 1000)
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1181                 _r=1):
#    1182               callbacks.on_train_batch_begin(step)
# -> 1183               tmp_logs = self.train_function(iterator)
#    1184               if data_handler.should_sync:
#    1185                 context.async_wait()
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     887
#     888       with OptionalXlaContext(self._jit_compile):
# --> 889         result = self._call(*args, **kwds)
#     890
#     891       new_tracing_count = self.experimental_get_tracing_count()
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     915       # In this case we have created variables on the first call, so we run the
#     916       # defunned version which is guaranteed to never create variables.
# --> 917       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     918     elif self._stateful_fn is not None:
#     919       # Release the lock early so that multiple threads can perform the call
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    3021       (graph_function,
#    3022        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 3023     return graph_function._call_flat(
#    3024         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    3025
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1958         and executing_eagerly):
#    1959       # No tape is watching; skip to running the function.
# -> 1960       return self._build_call_outputs(self._inference_function.call(
#    1961           ctx, args, cancellation_manager=cancellation_manager))
#    1962     forward_backward = self._select_forward_and_backward_functions(
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     589       with _InterpolateFunctionError(self):
#     590         if cancellation_manager is None:
# --> 591           outputs = execute.execute(
#     592               str(self.signature.name),
#     593               num_outputs=self._num_outputs,
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57   try:
#      58     ctx.ensure_initialized()
# ---> 59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
# I think there's nothing wrong her
# Out:
# (69,)
