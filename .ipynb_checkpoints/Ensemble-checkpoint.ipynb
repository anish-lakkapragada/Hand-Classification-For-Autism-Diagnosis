# %% [markdown]
# # The ensemble approach is to take the data, and train each of the N classifiers on a different random arrangement of 6 landmarks.

# %%
# first get all X and y data from the all_points_folds
import numpy as np 
import pickle, random 
import cv2

X, y = [], []

for file in os.listdir("all_points_folds"): 
    with open(f"all_points_folds/{file}", 'rb') as f: 
        X_y = pickle.load(f)
        X.append(X_y[0])
        y.append(X_y[1])

# %%
import random 
def shuffle(X, y, seed = None):
    if seed == None:  
        seed = random.randrange(0, 100)
        print(f"using seed {seed}")
    np.random.seed(seed) 
    new_X = np.concatenate([X_i for X_i in X])
    new_y = np.concatenate([y_i for y_i in y])
    N = np.random.permutation(new_X.shape[0])
    new_X = new_X[N]
    new_y = new_y[N]
    new_X = new_X.reshape(5, 20, 90, 126)
    new_y = new_y.reshape(5, 20)
    return new_X, new_y
X, y = shuffle(X, y, seed = 68)

# %% [markdown]
# # We will now get the landmarks for each of the NUM_MODELS models.

# %%
import random 
NUM_LANDMARKS = 3 
NUM_MODELS = 50 

model_to_arrangements = {} 
for i in range(NUM_MODELS): 
    model_to_arrangements[i] = random.sample(list(range(21)), NUM_LANDMARKS)

# %% [markdown]
# # After getting all configuration, create a function to take in a generic dataset and get the customized one for a model.

# %%
def specify_data(dataset, landmarks): 
    """
    dataset should contain a 3D matrix of (N, 90, 126). 
    """ 
    cols = []
    for landmark in landmarks:
        cols += (np.array([0, 21, 42, 63, 84, 105]) + landmark).tolist()
    
    return dataset[:, :, tuple(cols)]

# %% [markdown]
# # next we'll want to get X_train, X_test, y_train, y_test all ready for creating the models

# %%
VALIDATION_FOLD_INDEX = 0 # index of the fold to be used for validation
X_test, y_test = X[VALIDATION_FOLD_INDEX], y[VALIDATION_FOLD_INDEX]
X_train = np.delete(X, VALIDATION_FOLD_INDEX, axis=0).reshape(80, 90, 126) 
y_train = np.delete(y, VALIDATION_FOLD_INDEX, axis=0).reshape(80,)

# %%
import tensorflow as tf 
def make_model(): 
    # use this function to create all of the models 
    model = tf.keras.models.Sequential([
        tf.keras.layers.LSTM(64, return_sequences=False), 
        tf.keras.layers.Dropout(0.3), 
        tf.keras.layers.Dense(1, activation = "sigmoid")
    ])

    model.compile(loss = "binary_crossentropy", optimizer=tf.keras.optimizers.Adam(learning_rate=0.0005), metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()])
    
    return model

# %%
import os

checkpoint = tf.keras.callbacks.ModelCheckpoint("best_ensemble.h5", save_best_only=True, monitor = "val_accuracy")
early_stopping = tf.keras.callbacks.EarlyStopping(monitor = "val_accuracy", patience=10)
def train_models(): 
    # train all of the models and get them back 
    models, val_accuracies = [], []
    for _, model_configuration in model_to_arrangements.items(): 
        train_data, test_data = specify_data(X_train, model_configuration), specify_data(X_test, model_configuration)
        model = make_model() 

        try: 
            os.remove("best_ensemble.h5") 
        except Exception as e: 
            pass 

        # train this model 
        model.fit(train_data, y_train, validation_data = (test_data, y_test), epochs = 75, callbacks = [checkpoint, early_stopping]) 

        # revert to best weights, if created 
        try: 
            model.load_weights("best_ensemble.h5")
        except Exception as e:
            pass 
        
        loss, accuracy, precision, recall = model.evaluate(test_data, y_test)
        
        val_accuracies.append(accuracy) # add the accuracy 

        models.append(model) # add the model

    return models, np.array(val_accuracies)

# %%
models, val_accuracies = train_models()
# Out:
# Epoch 1/75
# 3/3 [==============================] - 3s 311ms/step - loss: 0.6896 - accuracy: 0.6125 - precision: 0.6522 - recall: 0.3947 - val_loss: 0.6865 - val_accuracy: 0.5500 - val_precision: 0.8000 - val_recall: 0.3333
# Epoch 2/75
# 3/3 [==============================] - 0s 45ms/step - loss: 0.
# 3/3 [==============================] - 0s 36ms/step - loss: 0.6899 - accuracy: 0.6000 - precision_2: 0.6364 - recall_2: 0.3684 - val_loss: 0.6855 - val_accuracy: 0.7000 - val_precision_2: 1.0000 - val_recall_2: 0.5000
# Epoch 4/75
# 3/3 [==============================] - 0s 43ms/step - loss: 0.6770 - accuracy: 0.6125 - precision_2: 0.6522 - recall_2: 0.3947 - val_loss: 0.6821 - val_accuracy: 0.7000 - val_precision_2: 0.8750 - val_recall_2: 0.5833
# Epoch 5/75
# 3/3 [==============================] - 0s 34ms/step - loss: 0.6790 - accuracy: 0.6250 - precision_2: 0.6818 - recall_2: 0.3947 - val_loss: 0.6784 - val_accuracy: 0.7500 - val_precision_2: 0.8889 - val_recall_2: 0.6667
# Epoch 6/75
# 3/3 [==============================] - 0s 29ms/step - loss: 0.6755 - accuracy: 0.6625 - precision_2: 0.6774 - recall_2: 0.5526 - val_loss: 0.6754 - val_accuracy: 0.8500 - val_precision_2: 1.0000 - val_recall_2: 0.7500
# Epoch 7/75
# 3/3 [==============================] - 0s 31ms/step - loss: 0.6775 - accuracy: 0.6250 - precision_2: 0.6333 - recall_2: 0.5000 - val_loss: 0.6712 - val_accuracy: 0.8500 - val_precision_2: 1.0000 - val_recall_2: 0.7500
# Epoch 8/75
# 3/3 [==============================] - 0s 30ms/step - loss: 0.6681 - accuracy: 0.6375 - precision_2: 0.6667 - recall_2: 0.4737 - val_loss: 0.6668 - val_accuracy: 0.8500 - val_precision_2: 1.0000 - val_recall_2: 0.7500
# Epoch 9/75
# 3/3 [==============================] - 0s 30ms/step - loss: 0.6703 - accuracy: 0.6625 - precision_2: 0.6571 - recall_2: 0.6053 - val_loss: 0.6605 - val_accuracy: 0.8000 - val_precision_2: 0.9000 - val_recall_2: 0.7500
# Epoch 10/75
# 3/3 [==============================] - 0s 33ms/step - loss: 0.6559 - accuracy: 0.7000 - precision_2: 0.6842 - recall_2: 0.6842 - val_loss: 0.6533 - val_accuracy: 0.8500 - val_precision_2: 0.9091 - val_recall_2: 0.8333
# Epoch 11/75
# 3/3 [==============================] - 0s 35ms/step - loss: 0.6515 - accuracy: 0.7000 - precision_2: 0.6591 - recall_2: 0.7632 - val_loss: 0.6444 - val_accuracy: 0.8000 - val_precision_2: 0.8333 - val_recall_2: 0.8333
# Epoch 12/75
# 3/3 [==============================] - 0s 35ms/step - loss: 0.6487 - accuracy: 0.6625 - precision_2: 0.6279 - recall_2: 0.7105 - val_loss: 0.6341 - val_accuracy: 0.7500 - val_precision_2: 0.7692 - val_recall_2: 0.8333
# Epoch 13/75
# 3/3 [==============================] - 0s 33ms/step - loss: 0.6322 - accuracy: 0.7125 - precision_2: 0.6596 - recall_2: 0.8158 - val_loss: 0.6203 - val_accuracy: 0.7000 - val_precision_2: 0.7143 - val_recall_2: 0.8333
# Epoch 14/75
# 3/3 [==============================] - 0s 35ms/step - loss: 0.6338 - accuracy: 0.7000 - precision_2: 0.6400 - recall_2: 0.8421 - val_loss: 0.6078 - val_accuracy: 0.6500 - val_precision_2: 0.6667 - val_recall_2: 0.8333
# Epoch 15/75
# 3/3 [==============================] - 0s 41ms/step - loss: 0.6212 - accuracy: 0.6875 - precision_2: 0.6226 - recall_2: 0.8684 - val_loss: 0.5963 - val_accuracy: 0.6500 - val_precision_2: 0.6667 - val_recall_2: 0.8333
# Epoch 16/75
# 3/3 [==============================] - 0s 36ms/step - loss: 0.6294 - accuracy: 0.6625 - precision_2: 0.6000 - recall_2: 0.8684 - val_loss: 0.5899 - val_accuracy: 0.7000 - val_precision_2: 0.7143 - val_recall_2: 0.8333
# 1/1 [==============================] - 0s 19ms/step - loss: 0.5899 - accuracy: 0.7000 - precision_2: 0.7143 - recall_2: 0.8333
# Epoch 1/75
# 3/3 [==============================] - 3s 346ms/step - loss: 0.7030 - accuracy: 0.4750 - precision_3: 0.4688 - recall_3: 0.7895 - val_loss: 0.6870 - val_accuracy: 0.7500 - val_precision_3: 0.8182 - val_recall_3: 0.7500
# Epoch 2/75
# 3/3 [==============================] - 0s 28ms/step - loss: 0.6953 - accuracy: 0.5625 - precision_3: 0.5385 - recall_3: 0.5526 - val_loss: 0.6864 - val_accuracy: 0.6000 - val_precision_3: 1.0000 - val_recall_3: 0.3333
# Epoch 3/75
# 3/3 [==============================] - 0s 29ms/step - loss: 0.
75
# 3/3 [==============================] - 0s 29ms/step - loss: 0.6584 - accuracy: 0.6875 - precision_9: 0.7407 - recall_9: 0.5263 - val_loss: 0.6570 - val_accuracy: 0.8000 - val_precision_9: 1.0000 - val_recall_9: 0.6667
# Epoch 10/75
# 3/3 [==============================] - 0s 30ms/step - loss: 0.6560 - accuracy: 0.7375 - precision_9: 0.7429 - recall_9: 0.6842 - val_loss: 0.6499 - val_accuracy: 0.8500 - val_precision_9: 1.0000 - val_recall_9: 0.7500
# Epoch 11/75
# 3/3 [==============================] - 0s 29ms/step - loss: 0.6540 - accuracy: 0.7125 - precision_9: 0.7027 - recall_9: 0.6842 - val_loss: 0.6405 - val_accuracy: 0.8500 - val_precision_9: 1.0000 - val_recall_9: 0.7500
# Epoch 12/75
# 3/3 [==============================] - 0s 29ms/step - loss: 0.6465 - accuracy: 0.7125 - precision_9: 0.6923 - recall_9: 0.7105 - val_loss: 0.6285 - val_accuracy: 0.8500 - val_precision_9: 0.9091 - val_recall_9: 0.8333
# 1/1 [==============================] - 0s 20ms/step - loss: 0.6285 - accuracy: 0.8500 - precision_9: 0.9091 - recall_9: 0.8333
# Epoch 1/75
# 3/3 [==============================] - 3s 289ms/step - loss: 0.6988 - accuracy: 0.4875 - precision_10: 0.2857 - recall_10: 0.0526 - val_loss: 0.6983 - val_accuracy: 0.4000 - val_precision_10: 0.0000e+00 - val_recall_10: 0.0000e+00
# Epoch 2/75
# 3/3 [==============================] - 0s 29ms/step - loss: 0.6964 - accuracy: 0.4875 - precision_10: 0.4000 - recall_10: 0.1579 - val_loss: 0.6953 - val_accuracy: 0.4000 - val_precision_10: 0.0000e+00 - val_recall_10: 0.0000e+00
# Epoch 3/75
# 3/3 [==============================] - 0s 30ms/step - loss: 0.6936 - accuracy: 0.5375 - precision_10: 0.5556 - recall_10: 0.1316 - val_loss: 0.6914 - val_accuracy: 0.4000 - val_precision_10: 0.0000e+00 - val_recall_10: 0.0000e+00
# Epoch 4/75
# 3/3 [==============================] - 0s 29ms/step - loss: 0.6888 - accuracy: 0.5875 - precision_10: 0.7273 - recall_10: 0.2105 - val_loss: 0.6888 - val_accuracy: 0.4000 - val_precision_10: 0.0000e+00 - val_recall_10: 0.0000e+00
# Epoch 5/75
# 3/3 [==============================] - 0s 34ms/step - loss: 0.6864 - accuracy: 0.6250 - precision_10: 0.7000 - recall_10: 0.3684 - val_loss: 0.6852 - val_accuracy: 0.5500 - val_precision_10: 1.0000 - val_recall_10: 0.2500
# Epoch 6/75
# 3/3 [==============================] - 0s 32ms/step - loss: 0.6799 - accuracy: 0.5750 - precision_10: 0.5909 - recall_10: 0.3421 - val_loss: 0.6820 - val_accuracy: 0.7000 - val_precision_10: 1.0000 - val_recall_10: 0.5000
# Epoch 7/75
# 3/3 [==============================] - 0s 35ms/step - loss: 0.6827 - accuracy: 0.5625 - precision_10: 0.5714 - recall_10: 0.3158 - val_loss: 0.6791 - val_accuracy: 0.7500 - val_precision_10: 1.0000 - val_recall_10: 0.5833
# Epoch 8/75
# 3/3 [==============================] - 0s 35ms/step - loss: 0.6769 - accuracy: 0.6500 - precision_10: 0.7083 - recall_10: 0.4474 - val_loss: 0.6759 - val_accuracy: 0.7500 - val_precision_10: 1.0000 - val_recall_10: 0.5833
# Epoch 9/75
# 3/3 [==============================] - 0s 35ms/step - loss: 0.6733 - accuracy: 0.6375 - precision_10: 0.6552 - recall_10: 0.5000 - val_loss: 0.6720 - val_accuracy: 0.8000 - val_precision_10: 1.0000 - val_recall_10: 0.6667
# Epoch 10/75
# 3/3 [==============================] - 0s 30ms/step - loss: 0.6775 - accuracy: 0.6500 - precision_10: 0.6923 - recall_10: 0.4737 - val_loss: 0.6681 - val_accuracy: 0.8000 - val_precision_10: 1.0000 - val_recall_10: 0.6667
# Epoch 11/75
# 3/3 [==============================] - 0s 32ms/step - loss: 0.6672 - accuracy: 0.6750 - precision_10: 0.6875 - recall_10: 0.5789 - val_loss: 0.6631 - val_accuracy: 0.8000 - val_precision_10: 1.0000 - val_recall_10: 0.6667
# Epoch 12/75
# 3/3 [==============================] - 0s 34ms/step - loss: 0.6597 - accuracy: 0.7250 - precision_10: 0.7222 - recall_10: 0.6842 - val_loss: 0.6566 - val_accuracy: 0.8500 - val_precision_10: 1.0000 - val_recall_10: 0.7500
# Epoch 13/75
# 3/3 [==============================] - 0s 32ms/step - loss: 0.6513 - accuracy: 0.7500 - precision_10: 0.7250 - recall_10: 0.7632 - val_loss: 0.6482 - val_accuracy: 0.9000 - val_precision_10: 1.0000 - val_recall_10: 0.8333
# Epoch 14/75
# 3/3 [==============================] - 0s 32ms/step - loss: 0.6484 - accuracy: 0.6750 - precision_10: 0.6364 - recall_10: 0.7368 - val_loss: 0.6365 - val_accuracy: 0.8500 - val_precision_10: 0.9091 - val_recall_10: 0.8333
# Epoch 15/75
# 3/3 [==============================] - 0s 30ms/step - loss: 0.6401 - accuracy: 0.7000 - precision_10: 0.6522 - recall_10: 0.7895 - val_loss: 0.6232 - val_accuracy: 0.8000 - val_precision_10: 0.8333 - val_recall_10: 0.8333
# Epoch 16/75
# 3/3 [==============================] - 0s 32ms/step - loss: 0.6237 - accuracy: 0.7125 - precision_10: 0.6596 - recall_10: 0.8158 - val_loss: 0.6089 - val_accuracy: 0.7500 - val_precision_10: 0.7692 - val_recall_10: 0.8333
# Epoch 17/75
# 3/3 [==============================] - 0s 38ms/step - loss: 0.6269 - accuracy: 0.7000 - precision_10: 0.6458 - recall_10: 0.8158 - val_loss: 0.5959 - val_accuracy: 0.7500 - val_precision_10: 0.7692 - val_recall_10: 0.8333
# Epoch 18/75
# 3/3 [==============================] - 0s 39ms/step - loss: 0.6153 - accuracy: 0.7000 - precision_10: 0.6458 - recall_10: 0.8158 - val_loss: 0.5878 - val_accuracy: 0.7500 - val_precision_10: 0.7692 - val_recall_10: 0.8333
# Epoch 19/75
# 3/3 [==============================] - 0s 37ms/step - loss: 0.6312 - accuracy: 0.7000 - precision_10: 0.6400 - recall_10: 0.8421 - val_loss: 0.5848 - val_accuracy: 0.7500 - val_precision_10: 0.7692 - val_recall_10: 0.8333
# Epoch 20/75
# 3/3 [==============================] - 0s 37ms/step - loss: 0.6129 - accuracy: 0.7125 - precision_10: 0.6596 - recall_10: 0.8158 - val_loss: 0.5842 - val_accuracy: 0.7500 - val_precision_10: 0.7692 - val_recall_10: 0.8333
# Epoch 21/75
# 3/3 [==============================] - 0s 43ms/step - loss: 0.6124 - accuracy: 0.7000 - precision_10: 0.6458 - recall_10: 0.8158 - val_loss: 0.5829 - val_accuracy: 0.7500 - val_precision_10: 0.7692 - val_recall_10: 0.8333
# Epoch 22/75
# 3/3 [==============================] - 0s 38ms/step - loss: 0.6054 - accuracy: 0.7125 - precision_10: 0.6596 - recall_10: 0.8158 - val_loss: 0.5783 - val_accuracy: 0.7500 - val_precision_10: 0.7692 - val_recall_10: 0.8333
# Epoch 23/75
# 3/3 [==============================] - 0s 29ms/step - loss: 0.5988 - accuracy: 0.7000 - precision_10: 0.6458 - recall_10: 0.8158 - val_loss: 0.5723 - val_accuracy: 0.7500 - val_precision_10: 0.7692 - val_recall_10: 0.8333
# 1/1 [==============================] - 0s 19ms/step - loss: 0.5723 - accuracy: 0.7500 - precision_10: 0.7692 - recall_10: 0.8333
# Epoch 1/75
# 3/3 [==============================] - 3s 301ms/step - loss: 0.6956 - accuracy: 0.4375 - precision_11: 0.3600 - recall_11: 0.2368 - val_loss: 0.6913 - val_accuracy: 0.6500 - val_precision_11: 1.0000 - val_recall_11: 0.4167
# Epoch 2/75
# 3/3 [==============================] - 0s 26ms/step - loss: 0.6968 - accuracy: 0.5625 - precision_11: 0.5600 - recall_11: 0.3684 - val_loss: 0.6880 - val_accuracy: 0.7000 - val_precision_11: 1.0000 - val_recall_11: 0.5000
# Epoch 3/75
# 3/3 [==============================] - 0s 28ms/step - loss: 0.6864 - accuracy: 0.7000 - precision_11: 0.7059 - recall_11: 0.6316 - val_loss: 0.6846 - val_accuracy: 0.7500 - val_precision_11: 1.0000 - val_recall_11: 0.5833
# Epoch 4/75
# 3/3 [==============================] - 0s 27ms/step - loss: 0.6873 - accuracy: 0.5500 - precision_11: 0.5357 - recall_11: 0.3947 - val_loss: 0.6824 - val_accuracy: 0.7000 - val_precision_11: 1.0000 - val_recall_11: 0.5000
# Epoch 5/75
# 3/3 [==============================] - 0s 27ms/step - loss: 0.6807 - accuracy: 0.6750 - precision_11: 0.7000 - recall_11: 0.5526 - val_loss: 0.6791 - val_accuracy: 0.7000 - val_precision_11: 1.0000 - val_recall_11: 0.5000
# Epoch 6/75
# 3/3 [==============================] - 0s 27ms/step - loss: 0.6771 - accuracy: 0.6375 - precision_11: 0.6667 - recall_11: 0.4737 - val_loss: 0.6760 - val_accuracy: 0.7000 - val_precision_11: 1.0000 - val_recall_11: 0.5000
# Epoch 7/75
# 3/3 [==============================] - 0s 27ms/step - loss: 0.6733 - accuracy: 0.7000 - precision_11: 0.7692 - recall_11: 0.5263 - val_loss: 0.6727 - val_accuracy: 0.7000 - val_precision_11: 1.0000 - val_recall_11: 0.5000
# Epoch 8/75
# 3/3 [==============================] - 0s 28ms/step - loss: 0.6667 - accuracy: 0.7000 - precision_11: 0.7692 - recall_11: 0.5263 - val_loss: 0.6689 - val_accuracy: 0.7500 - val_precision_11: 1.0000 - val_recall_11: 0.5833
# Epoch 9/75
# 3/3 [==============================] - 0s 28ms/step - loss: 0.6738 - accuracy: 0.6625 - precision_11: 0.6897 - recall_11: 0.5263 - val_loss: 0.6644 - val_accuracy: 0.7500 - val_precision_11: 1.0000 - val_recall_11: 0.5833
# Epoch 10/75
# 3/3 [==============================] - 0s 27ms/step - loss: 0.6675 - accuracy: 0.7000 - precision_11: 0.7500 - recall_11: 0.5526 - val_loss: 0.6592 - val_accuracy: 0.7500 - val_precision_11: 1.0000 - val_recall_11: 0.5833
# Epoch 11/75
# 3/3 [==============================] - 0s 26ms/step - loss: 0.6641 - accuracy: 0.7000 - precision_11: 0.6842 - recall_11: 0.6842 - val_loss: 0.6526 - val_accuracy: 0.8000 - val_precision_11: 1.0000 - val_recall_11: 0.6667
# Epoch 12/75
# 3/3 [==============================] - 0s 27ms/step - loss: 0.6509 - accuracy: 0.6875 - precision_11: 0.6857 - recall_11: 0.6316 - val_loss: 0.6461 - val_accuracy: 0.8000 - val_precision_11: 1.0000 - val_recall_11: 0.6667
# Epoch 13/75
# 3/3 [==============================] - 0s 28ms/step - loss: 0.6419 - accuracy: 0.7375 - precision_11: 0.7297 - recall_11: 0.7105 - val_loss: 0.6386 - val_accuracy: 0.8000 - val_precision_11: 1.0000 - val_recall_11: 0.6667
# Epoch 14/75
# 3/3 [==============================] - 0s 28ms/step - loss: 0.6315 - accuracy: 0.7625 - precision_11: 0.7436 - recall_11: 0.7632 - val_loss: 0.6287 - val_accuracy: 0.8500 - val_precision_11: 1.0000 - val_recall_11: 0.7500
# Epoch 15/75
# 3/3 [==============================] - 0s 28ms/step - loss: 0.6337 - accuracy: 0.7250 - precision_11: 0.7000 - recall_11: 0.7368 - val_loss: 0.6178 - val_accuracy: 0.8500 - val_precision_11: 0.9091 - val_recall_11: 0.8333
# Epoch 16/75
# 3/3 [==============================] - 0s 27ms/step - loss: 0.6278 - accuracy: 0.7125 - precision_11: 0.6667 - recall_11: 0.7895 - val_loss: 0.6062 - val_accuracy: 0.8500 - val_precision_11: 0.9091 - val_recall_11: 0.8333
# Epoch 17/75
# ...
# 1/1 [==============================] - 0s 23ms/step - loss: 0.5888 - accuracy: 0.7500 - precision_45: 0.8182 - recall_45: 0.7500
# Epoch 1/75
# 3/3 [==============================] - 3s 332ms/step - loss: 0.6923 - accuracy: 0.4875 - precision_46: 0.0000e+00 - recall_46: 0.0000e+00 - val_loss: 0.7024 - val_accuracy: 0.4000 - val_precision_46: 0.0000e+00 - val_recall_46: 0.0000e+00
# Epoch 2/75
# 3/3 [==============================] - 0s 40ms/step - loss: 0.6937 - accuracy: 0.5125 - precision_46: 0.4286 - recall_46: 0.0789 - val_loss: 0.6958 - val_accuracy: 0.5500 - val_precision_46: 1.0000 - val_recall_46: 0.2500
# Epoch 3/75
# 3/3 [==============================] - 0s 36ms/step - loss: 0.6841 - accuracy: 0.5375 - precision_46: 0.5185 - recall_46: 0.3684 - val_loss: 0.6897 - val_accuracy: 0.5500 - val_precision_46: 0.6667 - val_recall_46: 0.5000
# Epoch 4/75
# 3/3 [==============================] - 0s 43ms/step - loss: 0.
 0.8333
# Epoch 16/75
# 3/3 [==============================] - 0s 28ms/step - loss: 0.6253 - accuracy: 0.7000 - precision_49: 0.6458 - recall_49: 0.8158 - val_loss: 0.6019 - val_accuracy: 0.7500 - val_precision_49: 0.8182 - val_recall_49: 0.7500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.6019 - accuracy: 0.7500 - precision_49: 0.8182 - recall_49: 0.7500

# %% [markdown]
# # We will then need a function to test the model's accuracy on the test set.
# # We will also want to see whether this approach does well on our six videos.

# %%
def aggregate_validation_accuracy(models, X_test, y_test):
    preds = np.zeros((X_test.shape[0], 1))
    for model, landmarks in zip(models, model_to_arrangements.values()):
        test_data = specify_data(X_test, landmarks)
        preds += model.predict(test_data)
    preds = preds / len(models)
    preds = np.round_(preds).flatten()
    return (preds == y_test).mean()

# %%
aggregate_validation_accuracy(models, X_test, y_test)
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fb173530280> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fb2136bb280> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 0.75

# %%
import mediapipe as mp 
from tqdm import tqdm 
def hand_locations_general(frame, min_detection_confidence = 0.5, min_tracking_confidence = 0.5): 
    """give all landmarks"""

    hands = mp.solutions.hands.Hands(min_detection_confidence=min_detection_confidence, min_tracking_confidence=min_tracking_confidence) # MAKE SURE THIS IS ALL GOOD 
    results = hands.process(frame.astype('uint8'))
    X_locations = [0] * 42
    Y_locations = [0] * 42
    Z_locations = [0] * 42

    if results.multi_hand_landmarks:
        x = y = z = 0 
        for hand, hand_landmark in enumerate(results.multi_hand_landmarks):
            for i in range(0, 21):
                landmark = hand_landmark.landmark[i]
                X_locations[x] = landmark.x
                Y_locations[y] = landmark.y 
                Z_locations[z] = landmark.z
                x += 1; y += 1; z +=1; 
            
    hands.close()
    return np.concatenate([X_locations, Y_locations, Z_locations]) 


# create a function to pad your videos 
def pad(locations, maxlen = 90, padding = "post", truncating = "post"): 
    new_locations = locations.tolist() 
    empty_row = np.zeros((1, 126))
    for i, video in tqdm(enumerate(new_locations)): 
        if len(video) < maxlen:  
            for new_row in range(maxlen - len(video)): 
                if padding == "post": 
                    new_locations[i] = np.array(new_locations[i])
                    new_locations[i] = np.concatenate([new_locations[i], empty_row])
                if padding == "pre": 
                    new_locations[i] = np.array(new_locations[i])
                    new_locations[i] = np.concatenate([empty_row, new_locations[i]])

        if len(video) > maxlen: 
            if truncating == "post": 
                new_locations[i] = new_locations[i][:maxlen]
            elif truncating == "pre": 
                new_locations[i] = new_locations[i][len(video) - maxlen : ]
    return np.array(new_locations)

# %%
# function to ensemble predict on frames. 
def ensemble_predict(models, X_test):
    preds = np.zeros((X_test.shape[0], 1))
    for model, landmarks in tqdm(zip(models, model_to_arrangements.values())):
        test_data = specify_data(X_test, landmarks)
        preds += model.predict(test_data)
    preds = preds / len(models)
    return preds.flatten()

# %%
# create a function to then predict on videos 
def predict_on_video(models, path): 
    LOCATIONS = []
    cap = cv2.VideoCapture(path)
    while cap.isOpened():
        _, frame = cap.read()
        if not _: break 

        frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

        LOCATIONS.append(hand_locations_general(frame))
        print("read frame") 
        
    print("read all frames")
    LOCATIONS = np.array([LOCATIONS])
    LOCATIONS = pad(LOCATIONS)
    return ensemble_predict(models, LOCATIONS)

# %%
LOCATIONS = []
cap = cv2.VideoCapture("control_1.mov")
while cap.isOpened():
    _, frame = cap.read()
    if not _: break 

    frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

    LOCATIONS.append(hand_locations_general(frame))
    print("read frame")
