# %% [markdown]
# # The ensemble approach is to take the data, and train each of the N classifiers on a different random arrangement of 6 landmarks.

# %%
# first get all X and y data from the all_points_folds
import numpy as np 
import pickle, random 
import cv2
import os 

X, y = [], []

for file in os.listdir("all_points_folds"): 
    with open(f"all_points_folds/{file}", 'rb') as f: 
        X_y = pickle.load(f)
        X.append(X_y[0])
        y.append(X_y[1])

# %%
import random 
def shuffle(X, y, seed = None):
    if seed == None:  
        seed = random.randrange(0, 100)
        print(f"using seed {seed}")
    np.random.seed(seed) 
    new_X = np.concatenate([X_i for X_i in X])
    new_y = np.concatenate([y_i for y_i in y])
    N = np.random.permutation(new_X.shape[0])
    new_X = new_X[N]
    new_y = new_y[N]
    new_X = new_X.reshape(5, 20, 90, 126)
    new_y = new_y.reshape(5, 20)
    return new_X, new_y
X, y = shuffle(X, y, seed = 68)

# %% [markdown]
# # We will now get the landmarks for each of the NUM_MODELS models.

# %%
import random 
NUM_LANDMARKS = 3 
NUM_MODELS = 50 

model_to_arrangements = {} 
for i in range(NUM_MODELS): 
    model_to_arrangements[i] = random.sample(list(range(21)), NUM_LANDMARKS)

# %% [markdown]
# # After getting all configuration, create a function to take in a generic dataset and get the customized one for a model.

# %%
def specify_data(dataset, landmarks): 
    """
    dataset should contain a 3D matrix of (N, 90, 126). 
    """ 
    cols = []
    for landmark in landmarks:
        cols += (np.array([0, 21, 42, 63, 84, 105]) + landmark).tolist()
    
    return dataset[:, :, tuple(cols)]

# %% [markdown]
# # next we'll want to get X_train, X_test, y_train, y_test all ready for creating the models

# %%
VALIDATION_FOLD_INDEX = 0 # index of the fold to be used for validation
X_test, y_test = X[VALIDATION_FOLD_INDEX], y[VALIDATION_FOLD_INDEX]
X_train = np.delete(X, VALIDATION_FOLD_INDEX, axis=0).reshape(80, 90, 126) 
y_train = np.delete(y, VALIDATION_FOLD_INDEX, axis=0).reshape(80,)

# %%
import tensorflow as tf 
def make_model(): 
    # use this function to create all of the models 
    model = tf.keras.models.Sequential([
        tf.keras.layers.LSTM(64, return_sequences=False), 
        tf.keras.layers.Dropout(0.3), 
        tf.keras.layers.Dense(1, activation = "sigmoid")
    ])

    model.compile(loss = "binary_crossentropy", optimizer=tf.keras.optimizers.Adam(learning_rate=0.0005), metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()])
    
    return model

# %%
import os

checkpoint = tf.keras.callbacks.ModelCheckpoint("best_ensemble.h5", save_best_only=True, monitor = "val_accuracy")
early_stopping = tf.keras.callbacks.EarlyStopping(monitor = "val_accuracy", patience=10)
def train_models(): 
    # train all of the models and get them back 
    models, val_accuracies = [], []
    for _, model_configuration in model_to_arrangements.items(): 
        train_data, test_data = specify_data(X_train, model_configuration), specify_data(X_test, model_configuration)
        model = make_model() 

        try: 
            os.remove("best_ensemble.h5") 
        except Exception as e: 
            pass 

        # train this model 
        model.fit(train_data, y_train, validation_data = (test_data, y_test), epochs = 75, callbacks = [checkpoint, early_stopping]) 

        # revert to best weights, if created 
        try: 
            model.load_weights("best_ensemble.h5")
        except Exception as e:
            pass 
        
        loss, accuracy, precision, recall = model.evaluate(test_data, y_test)
        
75
# 3/3 [==============================] - 0s 28ms/step - loss: 0.6920 - accuracy: 0.5250 - precision_2: 0.5000 - recall_2: 0.1579 - val_loss: 0.6908 - val_accuracy: 0.4500 - val_precision_2: 1.0000 - val_recall_2: 0.0833
# Epoch 5/75
# 3/3 [==============================] - 0s 29ms/step - loss: 0.6929 - accuracy: 0.5125 - precision_2: 0.4545 - recall_2: 0.1316 - val_loss: 0.6870 - val_accuracy: 0.4500 - val_precision_2: 1.0000 - val_recall_2: 0.0833
# Epoch 6/75
# 3/3 [==============================] - 0s 27ms/step - loss: 0.6838 - accuracy: 0.5625 - precision_2: 0.6667 - recall_2: 0.1579 - val_loss: 0.6831 - val_accuracy: 0.4500 - val_precision_2: 1.0000 - val_recall_2: 0.0833
# Epoch 7/75
# 3/3 [==============================] - 0s 27ms/step - loss: 0.6830 - accuracy: 0.5500 - precision_2: 0.5500 - recall_2: 0.2895 - val_loss: 0.6780 - val_accuracy: 0.7500 - val_precision_2: 1.0000 - val_recall_2: 0.5833
# Epoch 8/75
# 3/3 [==============================] - 0s 28ms/step - loss: 0.6796 - accuracy: 0.6250 - precision_2: 0.6818 - recall_2: 0.3947 - val_loss: 0.6733 - val_accuracy: 0.8000 - val_precision_2: 1.0000 - val_recall_2: 0.6667
# Epoch 9/75
# 3/3 [==============================] - 0s 27ms/step - loss: 0.6756 - accuracy: 0.5750 - precision_2: 0.5714 - recall_2: 0.4211 - val_loss: 0.6677 - val_accuracy: 0.8000 - val_precision_2: 1.0000 - val_recall_2: 0.6667
# Epoch 10/75
# 3/3 [==============================] - 0s 27ms/step - loss: 0.6636 - accuracy: 0.6375 - precision_2: 0.6364 - recall_2: 0.5526 - val_loss: 0.6608 - val_accuracy: 0.8500 - val_precision_2: 1.0000 - val_recall_2: 0.7500
# Epoch 11/75
# 3/3 [==============================] - 0s 28ms/step - loss: 0.6670 - accuracy: 0.6625 - precision_2: 0.6667 - recall_2: 0.5789 - val_loss: 0.6531 - val_accuracy: 0.8500 - val_precision_2: 1.0000 - val_recall_2: 0.7500
# Epoch 12/75
# 3/3 [==============================] - 0s 27ms/step - loss: 0.6534 - accuracy: 0.6500 - precision_2: 0.6250 - recall_2: 0.6579 - val_loss: 0.6430 - val_accuracy: 0.9000 - val_precision_2: 1.0000 - val_recall_2: 0.8333
# Epoch 13/75
# 3/3 [==============================] - 0s 29ms/step - loss: 0.6443 - accuracy: 0.7000 - precision_2: 0.6667 - recall_2: 0.7368 - val_loss: 0.6315 - val_accuracy: 0.8000 - val_precision_2: 0.8333 - val_recall_2: 0.8333
# Epoch 14/75
# 3/3 [==============================] - 0s 29ms/step - loss: 0.6350 - accuracy: 0.7000 - precision_2: 0.6522 - recall_2: 0.7895 - val_loss: 0.6198 - val_accuracy: 0.8000 - val_precision_2: 0.8333 - val_recall_2: 0.8333
# Epoch 15/75
# 3/3 [==============================] - 0s 28ms/step - loss: 0.6296 - accuracy: 0.7125 - precision_2: 0.6596 - recall_2: 0.8158 - val_loss: 0.6081 - val_accuracy: 0.7500 - val_precision_2: 0.7692 - val_recall_2: 0.8333
# Epoch 16/75
# 3/3 [==============================] - 0s 28ms/step - loss: 0.6251 - accuracy: 0.7000 - precision_2: 0.6458 - recall_2: 0.8158 - val_loss: 0.5979 - val_accuracy: 0.7500 - val_precision_2: 0.7692 - val_recall_2: 0.8333
# Epoch 17/75
# 3/3 [==============================] - 0s 28ms/step - loss: 0.6208 - accuracy: 0.6750 - precision_2: 0.6200 - recall_2: 0.8158 - val_loss: 0.5883 - val_accuracy: 0.7500 - val_precision_2: 0.7692 - val_recall_2: 0.8333
# Epoch 18/75
# 3/3 [==============================] - 0s 28ms/step - loss: 0.6033 - accuracy: 0.6750 - precision_2: 0.6200 - recall_2: 0.8158 - val_loss: 0.5795 - val_accuracy: 0.7500 - val_precision_2: 0.7692 - val_recall_2: 0.8333
# Epoch 19/75
# 3/3 [==============================] - 0s 28ms/step - loss: 0.6216 - accuracy: 0.6500 - precision_2: 0.5962 - recall_2: 0.8158 - val_loss: 0.5752 - val_accuracy: 0.7500 - val_precision_2: 0.7692 - val_recall_2: 0.8333
# Epoch 20/75
# 3/3 [==============================] - 0s 28ms/step - loss: 0.6099 - accuracy: 0.6625 - precision_2: 0.6078 - recall_2: 0.8158 - val_loss: 0.5750 - val_accuracy: 0.7500 - val_precision_2: 0.7692 - val_recall_2: 0.8333
# Epoch 21/75
# 3/3 [==============================] - 0s 27ms/step - loss: 0.6085 - accuracy: 0.6750 - precision_2: 0.6200 - recall_2: 0.8158 - val_loss: 0.5777 - val_accuracy: 0.8000 - val_precision_2: 0.8333 - val_recall_2: 0.8333
# Epoch 22/75
# 3/3 [==============================] - 0s 29ms/step - loss: 0.5999 - accuracy: 0.7000 - precision_2: 0.6458 - recall_2: 0.8158 - val_loss: 0.5806 - val_accuracy: 0.8000 - val_precision_2: 0.9000 - val_recall_2: 0.7500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.6430 - accuracy: 0.9000 - precision_2: 1.0000 - recall_2: 0.8333
# Epoch 1/75
# 3/3 [==============================] - 2s 282ms/step - loss: 0.6893 - accuracy: 0.4500 - precision_3: 0.4531 - recall_3: 0.7632 - val_loss: 0.6807 - val_accuracy: 0.6500 - val_precision_3: 0.6316 - val_recall_3: 1.0000
# Epoch 2/75
# 3/3 [==============================] - 0s 27ms/step - loss: 0.6768 - accuracy: 0.6000 - precision_3: 0.5536 - recall_3: 0.8158 - val_loss: 0.6793 - val_accuracy: 0.8000 - val_precision_3: 0.9000 - val_recall_3: 0.7500
# Epoch 3/75
# 3/3 [==============================] - 0s 27ms/step - loss: 0.6891 - accuracy: 0.6000 - precision_3: 0.5789 - recall_3: 0.5789 - val_loss: 0.6770 - val_accuracy: 0.8500 - val_precision_3: 1.0000 - val_recall_3: 0.7500
# Epoch 4/75
# 3/3 [==============================] - 0s 28ms/step - loss: 0.6752 - accuracy: 0.6625 - precision_3: 0.6486 - recall_3: 0.6316 - val_loss: 0.6745 - val_accuracy: 0.8000 - val_precision_3: 1.0000 - val_recall_3: 0.6667
# Epoch 5/75
# 3/3 [==============================] - 0s 28ms/step - loss: 0.6730 - accuracy: 0.6875 - precision_3: 0.6970 - recall_3: 0.6053 - val_loss: 0.6712 - val_accuracy: 0.7500 - val_precision_3: 1.0000 - val_recall_3: 0.5833
# Epoch 6/75
# 3/3 [==============================] - 0s 28ms/step - loss: 0.6679 - accuracy: 0.7000 - precision_3: 0.6944 - recall_3: 0.6579 - val_loss: 0.6677 - val_accuracy: 0.7500 - val_precision_3: 1.0000 - val_recall_3: 0.5833
# Epoch 7/75
# 3/3 [==============================] - 0s 28ms/step - loss: 0.6633 - accuracy: 0.7125 - precision_3: 0.7143 - recall_3: 0.6579 - val_loss: 0.6626 - val_accuracy: 0.8000 - val_precision_3: 1.0000 - val_recall_3: 0.6667
# Epoch 8/75
# 3/3 [==============================] - 0s 27ms/step - loss: 0.6592 - accuracy: 0.6500 - precision_3: 0.6471 - recall_3: 0.5789 - val_loss: 0.6562 - val_accuracy: 0.8000 - val_precision_3: 1.0000 - val_recall_3: 0.6667
# Epoch 9/75
# 3/3 [==============================] - 0s 28ms/step - loss: 0.6462 - accuracy: 0.6875 - precision_3: 0.6667 - recall_3: 0.6842 - val_loss: 0.6483 - val_accuracy: 0.8500 - val_precision_3: 1.0000 - val_recall_3: 0.7500
# Epoch 10/75
# 3/3 [==============================] - 0s 29ms/step - loss: 0.6479 - accuracy: 0.6625 - precision_3: 0.6341 - recall_3: 0.6842 - val_loss: 0.6385 - val_accuracy: 0.8500 - val_precision_3: 1.0000 - val_recall_3: 0.7500
# Epoch 11/75
# 3/3 [==============================] - 0s 29ms/step - loss: 0.
75
# 3/3 [==============================] - 0s 27ms/step - loss: 0.6881 - accuracy: 0.6125 - precision_10: 0.5854 - recall_10: 0.6316 - val_loss: 0.6834 - val_accuracy: 0.8500 - val_precision_10: 0.9091 - val_recall_10: 0.8333
# Epoch 3/75
# 3/3 [==============================] - 0s 27ms/step - loss: 0.6833 - accuracy: 0.6625 - precision_10: 0.6279 - recall_10: 0.7105 - val_loss: 0.6810 - val_accuracy: 0.9000 - val_precision_10: 1.0000 - val_recall_10: 0.8333
# Epoch 4/75
# 3/3 [==============================] - 0s 26ms/step - loss: 0.6819 - accuracy: 0.6500 - precision_10: 0.6389 - recall_10: 0.6053 - val_loss: 0.6787 - val_accuracy: 0.9000 - val_precision_10: 1.0000 - val_recall_10: 0.8333
# Epoch 5/75
# 3/3 [==============================] - 0s 26ms/step - loss: 0.6824 - accuracy: 0.6500 - precision_10: 0.6316 - recall_10: 0.6316 - val_loss: 0.6765 - val_accuracy: 0.8000 - val_precision_10: 1.0000 - val_recall_10: 0.6667
# Epoch 6/75
# 3/3 [==============================] - 0s 25ms/step - loss: 0.6792 - accuracy: 0.6500 - precision_10: 0.6250 - recall_10: 0.6579 - val_loss: 0.6739 - val_accuracy: 0.8000 - val_precision_10: 1.0000 - val_recall_10: 0.6667
# Epoch 7/75
# 3/3 [==============================] - 0s 26ms/step - loss: 0.6772 - accuracy: 0.6500 - precision_10: 0.6316 - recall_10: 0.6316 - val_loss: 0.6711 - val_accuracy: 0.8000 - val_precision_10: 1.0000 - val_recall_10: 0.6667
# Epoch 8/75
# 3/3 [==============================] - 0s 27ms/step - loss: 0.6731 - accuracy: 0.6750 - precision_10: 0.6429 - recall_10: 0.7105 - val_loss: 0.6675 - val_accuracy: 0.8000 - val_precision_10: 1.0000 - val_recall_10: 0.6667
# Epoch 9/75
# 3/3 [==============================] - 0s 27ms/step - loss: 0.6723 - accuracy: 0.7000 - precision_10: 0.6750 - recall_10: 0.7105 - val_loss: 0.6644 - val_accuracy: 0.8000 - val_precision_10: 1.0000 - val_recall_10: 0.6667
# Epoch 10/75
# 3/3 [==============================] - 0s 27ms/step - loss: 0.6681 - accuracy: 0.7125 - precision_10: 0.7027 - recall_10: 0.6842 - val_loss: 0.6606 - val_accuracy: 0.8000 - val_precision_10: 1.0000 - val_recall_10: 0.6667
# Epoch 11/75
# 3/3 [==============================] - 0s 26ms/step - loss: 0.6599 - accuracy: 0.7375 - precision_10: 0.7179 - recall_10: 0.7368 - val_loss: 0.6560 - val_accuracy: 0.8000 - val_precision_10: 1.0000 - val_recall_10: 0.6667
# Epoch 12/75
# 3/3 [==============================] - 0s 26ms/step - loss: 0.6586 - accuracy: 0.7250 - precision_10: 0.7000 - recall_10: 0.7368 - val_loss: 0.6499 - val_accuracy: 0.8500 - val_precision_10: 1.0000 - val_recall_10: 0.7500
# Epoch 13/75
# 3/3 [==============================] - 0s 25ms/step - loss: 0.6527 - accuracy: 0.7250 - precision_10: 0.7105 - recall_10: 0.7105 - val_loss: 0.6435 - val_accuracy: 0.8500 - val_precision_10: 1.0000 - val_recall_10: 0.7500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.6435 - accuracy: 0.8500 - precision_10: 1.0000 - recall_10: 0.7500
# Epoch 1/75
# 3/3 [==============================] - 2s 221ms/step - loss: 0.6917 - accuracy: 0.4625 - precision_11: 0.4419 - recall_11: 0.5000 - val_loss: 0.6963 - val_accuracy: 0.5000 - val_precision_11: 0.6667 - val_recall_11: 0.3333
# Epoch 2/75
# 3/3 [==============================] - 0s 27ms/step - loss: 0.6913 - accuracy: 0.5625 - precision_11: 0.5517 - recall_11: 0.4211 - val_loss: 0.6948 - val_accuracy: 0.4500 - val_precision_11: 1.0000 - val_recall_11: 0.0833
# Epoch 3/75
# 3/3 [==============================] - 0s 26ms/step - loss: 0.6858 - accuracy: 0.5875 - precision_11: 0.6667 - recall_11: 0.2632 - val_loss: 0.6929 - val_accuracy: 0.4500 - val_precision_11: 1.0000 - val_recall_11: 0.0833
# Epoch 4/75
# 3/3 [==============================] - 0s 26ms/step - loss: 0.6941 - accuracy: 0.5375 - precision_11: 0.5333 - recall_11: 0.2105 - val_loss: 0.6914 - val_accuracy: 0.4500 - val_precision_11: 1.0000 - val_recall_11: 0.0833
# Epoch 5/75
# 3/3 [==============================] - 0s 26ms/step - loss: 0.6848 - accuracy: 0.6125 - precision_11: 0.6842 - recall_11: 0.3421 - val_loss: 0.6882 - val_accuracy: 0.4500 - val_precision_11: 1.0000 - val_recall_11: 0.0833
# Epoch 6/75
# 3/3 [==============================] - 0s 27ms/step - loss: 0.6820 - accuracy: 0.6375 - precision_11: 0.7368 - recall_11: 0.3684 - val_loss: 0.6852 - val_accuracy: 0.5500 - val_precision_11: 1.0000 - val_recall_11: 0.2500
# Epoch 7/75
# 3/3 [==============================] - 0s 26ms/step - loss: 0.6751 - accuracy: 0.7000 - precision_11: 0.7692 - recall_11: 0.5263 - val_loss: 0.6821 - val_accuracy: 0.6500 - val_precision_11: 1.0000 - val_recall_11: 0.4167
# Epoch 8/75
# 3/3 [==============================] - 0s 26ms/step - loss: 0.6701 - accuracy: 0.6500 - precision_11: 0.7083 - recall_11: 0.4474 - val_loss: 0.6792 - val_accuracy: 0.6500 - val_precision_11: 1.0000 - val_recall_11: 0.4167
# Epoch 9/75
# 3/3 [==============================] - 0s 26ms/step - loss: 0.6709 - accuracy: 0.7250 - precision_11: 0.8333 - recall_11: 0.5263 - val_loss: 0.6751 - val_accuracy: 0.6500 - val_precision_11: 1.0000 - val_recall_11: 0.4167
# Epoch 10/75
# 3/3 [==============================] - 0s 27ms/step - loss: 0.6655 - accuracy: 0.6875 - precision_11: 0.7826 - recall_11: 0.4737 - val_loss: 0.6701 - val_accuracy: 0.8000 - val_precision_11: 1.0000 - val_recall_11: 0.6667
# Epoch 11/75
# 3/3 [==============================] - 0s 27ms/step - loss: 0.6559 - accuracy: 0.6625 - precision_11: 0.6897 - recall_11: 0.5263 - val_loss: 0.6640 - val_accuracy: 0.8000 - val_precision_11: 1.0000 - val_recall_11: 0.6667
# Epoch 12/75
# 3/3 [==============================] - 0s 26ms/step - loss: 0.6466 - accuracy: 0.7250 - precision_11: 0.7222 - recall_11: 0.6842 - val_loss: 0.6547 - val_accuracy: 0.8500 - val_precision_11: 1.0000 - val_recall_11: 0.7500
# Epoch 13/75
# 3/3 [==============================] - 0s 26ms/step - loss: 0.6410 - accuracy: 0.7125 - precision_11: 0.6744 - recall_11: 0.7632 - val_loss: 0.6451 - val_accuracy: 0.8500 - val_precision_11: 1.0000 - val_recall_11: 0.7500
# Epoch 14/75
# 3/3 [==============================] - 0s 26ms/step - loss: 0.6368 - accuracy: 0.6875 - precision_11: 0.6444 - recall_11: 0.7632 - val_loss: 0.6326 - val_accuracy: 0.8500 - val_precision_11: 0.9091 - val_recall_11: 0.8333
# Epoch 15/75
# 3/3 [==============================] - 0s 27ms/step - loss: 0.6258 - accuracy: 0.7000 - precision_11: 0.6458 - recall_11: 0.8158 - val_loss: 0.6193 - val_accuracy: 0.7500 - val_precision_11: 0.7692 - val_recall_11: 0.8333
# Epoch 16/75
# 3/3 [==============================] - 0s 26ms/step - loss: 0.6318 - accuracy: 0.7125 - precision_11: 0.6667 - recall_11: 0.7895 - val_loss: 0.6046 - val_accuracy: 0.7500 - val_precision_11: 0.7692 - val_recall_11: 0.8333
# Epoch 17/75
# 3/3 [==============================] - 0s 27ms/step - loss: 0.6266 - accuracy: 0.7250 - precision_11: 0.6739 - recall_11: 0.8158 - val_loss: 0.5921 - val_accuracy: 0.7500 - val_precision_11: 0.7692 - val_recall_11: 0.8333
# Epoch 18/75
# 3/3 [==============================] - 0s 26ms/step - loss: 0.
# 1/1 [==============================] - 0s 17ms/step - loss: 0.5843 - accuracy: 0.7500 - precision_27: 0.7692 - recall_27: 0.8333
# Epoch 1/75

# %% [markdown]
# # We will then need a function to test the model's accuracy on the test set.
# # We will also want to see whether this approach does well on our six videos.

# %%
def aggregate_validation_accuracy(models, X_test, y_test):
    preds = np.zeros((X_test.shape[0], 1))
    for model, landmarks in zip(models, model_to_arrangements.values()):
        test_data = specify_data(X_test, landmarks)
        preds += model.predict(test_data)
    preds = preds / len(models)
    preds = np.round_(preds).flatten()
    return (preds == y_test).mean()

# %%
aggregate_validation_accuracy(models, X_test, y_test)

# %%
import mediapipe as mp 
from tqdm import tqdm 
def hand_locations_general(frame, min_detection_confidence = 0.5, min_tracking_confidence = 0.5): 
    """give all landmarks"""

    hands = mp.solutions.hands.Hands(min_detection_confidence=min_detection_confidence, min_tracking_confidence=min_tracking_confidence) # MAKE SURE THIS IS ALL GOOD 
    results = hands.process(frame.astype('uint8'))
    X_locations = [0] * 42
    Y_locations = [0] * 42
    Z_locations = [0] * 42

    if results.multi_hand_landmarks:
        x = y = z = 0 
        for hand, hand_landmark in enumerate(results.multi_hand_landmarks):
            for i in range(0, 21):
                landmark = hand_landmark.landmark[i]
                X_locations[x] = landmark.x
                Y_locations[y] = landmark.y 
                Z_locations[z] = landmark.z
                x += 1; y += 1; z +=1; 
            
    hands.close()
    return np.concatenate([X_locations, Y_locations, Z_locations]) 


# create a function to pad your videos 
def pad(locations, maxlen = 90, padding = "post", truncating = "post"): 
    new_locations = locations.tolist() 
    empty_row = np.zeros((1, 126))
    for i, video in tqdm(enumerate(new_locations)): 
        if len(video) < maxlen:  
            for new_row in range(maxlen - len(video)): 
                if padding == "post": 
                    new_locations[i] = np.array(new_locations[i])
                    new_locations[i] = np.concatenate([new_locations[i], empty_row])
                if padding == "pre": 
                    new_locations[i] = np.array(new_locations[i])
                    new_locations[i] = np.concatenate([empty_row, new_locations[i]])

        if len(video) > maxlen: 
            if truncating == "post": 
                new_locations[i] = new_locations[i][:maxlen]
            elif truncating == "pre": 
                new_locations[i] = new_locations[i][len(video) - maxlen : ]
    return np.array(new_locations)

# %%
# function to ensemble predict on frames. 
def ensemble_predict(models, X_test):
    preds = np.zeros((X_test.shape[0], 1))
    for model, landmarks in tqdm(zip(models, model_to_arrangements.values())):
        test_data = specify_data(X_test, landmarks)
        preds += model.predict(test_data)
    preds = preds / len(models)
    return preds.flatten()

# %%
# create a function to then predict on videos 
def predict_on_video(models, path): 
    LOCATIONS = []
    cap = cv2.VideoCapture(path)
    while cap.isOpened():
        _, frame = cap.read()
        if not _: break 

        frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

        LOCATIONS.append(hand_locations_general(frame))
        print("read frame") 
        
    print("read all frames")
    LOCATIONS = np.array([LOCATIONS])
    LOCATIONS = pad(LOCATIONS)
    return ensemble_predict(models, LOCATIONS)

# %%
LOCATIONS = []
cap = cv2.VideoCapture("control_1.mov")
while cap.isOpened():
    _, frame = cap.read()
    if not _: break 

    frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

    LOCATIONS.append(hand_locations_general(frame))
    print("read frame")
