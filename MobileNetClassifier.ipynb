# %%
import tensorflow as tf
import pickle
import os 
import cv2
import numpy as np
from sklearn.metrics import recall_score, precision_score, accuracy_score, f1_score
print(tf.__version__)
# Out:
# 2.3.3

# %%
os.environ["TF_FORCE_GPU_ALLOW_GROWTH"]="true"

# %%
! export TF_FORCE_GPU_ALLOW_GROWTH=true

# %%
IMAGE_SIZE = (224,224,3)

# %%
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    tf.config.experimental.set_memory_growth(device, True)

# %%
###
### Use all GPUs.
###
strategy = tf.distribute.MirroredStrategy()
print()
print()
print()
print('Number of devices: {}'.format(strategy.num_replicas_in_sync))
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1', '/job:localhost/replica:0/task:0/device:GPU:2', '/job:localhost/replica:0/task:0/device:GPU:3', '/job:localhost/replica:0/task:0/device:GPU:4', '/job:localhost/replica:0/task:0/device:GPU:5', '/job:localhost/replica:0/task:0/device:GPU:6', '/job:localhost/replica:0/task:0/device:GPU:7')
#
#
#
# Number of devices: 8

# %%
def make_model_2():
    def build_convnet(shape=None):
        momentum = 0.9
        model = tf.keras.Sequential()
        model.add(tf.keras.layers.Conv2D(64, (3,3), input_shape=shape[1:], padding='same', activation='linear'))
        model.add(tf.keras.layers.BatchNormalization(momentum=momentum))
        model.add(tf.keras.layers.Activation('relu'))

        model.add(tf.keras.layers.MaxPool2D())

        model.add(tf.keras.layers.Conv2D(128, (3,3), padding='same', activation='linear'))
        model.add(tf.keras.layers.BatchNormalization(momentum=momentum))
        model.add(tf.keras.layers.Activation('relu'))

        model.add(tf.keras.layers.MaxPool2D())

        model.add(tf.keras.layers.Conv2D(256, (3,3), padding='same', activation='linear'))
        model.add(tf.keras.layers.BatchNormalization(momentum=momentum))
        model.add(tf.keras.layers.Activation('relu'))

        # flatten
        model.add(tf.keras.layers.GlobalMaxPool2D())
        return model
    shape = (90, IMAGE_SIZE[0], IMAGE_SIZE[1], IMAGE_SIZE[2])
    print('Train data shape: ', shape)

    convnet = build_convnet(shape)

    model = tf.keras.Sequential()
    model.add(tf.keras.layers.TimeDistributed(convnet, input_shape=shape))
    model.add(tf.keras.layers.LSTM(64))

    model.add(tf.keras.layers.Dense(256, activation='relu'))
    model.add(tf.keras.layers.Dropout(.5))
    model.add(tf.keras.layers.Dense(128, activation='relu'))
    model.add(tf.keras.layers.Dropout(.5))
    model.add(tf.keras.layers.Dense(64, activation='relu'))
    model.add(tf.keras.layers.Dropout(.5))
    model.add(tf.keras.layers.Dense(16, activation='relu'))

    model.add(tf.keras.layers.Dense(1, activation='sigmoid'))
    
    return model

# %%
def make_model(): 
    inp =  tf.keras.layers.Input((None, IMAGE_SIZE[0], IMAGE_SIZE[1], IMAGE_SIZE[2])) # , ragged=True
    
    mobilenet_model = tf.keras.applications.mobilenet_v2.MobileNetV2(
        include_top=False, weights='imagenet', pooling='max', classes=2, input_shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)
    )
    
    for k,v in mobilenet_model._get_trainable_state().items():
        k.trainable = False
    
#     mobilenet_model = tf.keras.models.Sequential()
#     mobilenet_model.add(tf.keras.layers.Conv2D(16, (3, 3), activation='relu', input_shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)))
#     mobilenet_model.add(tf.keras.layers.MaxPooling2D((2, 2)))
#     mobilenet_model.add(tf.keras.layers.Conv2D(16, (3, 3), activation='relu'))
# #     mobilenet_model.add(tf.keras.layers.MaxPooling2D((2, 2)))
# #     mobilenet_model.add(tf.keras.layers.Conv2D(64, (3, 3), activation='relu'))
#     mobilenet_model.add(tf.keras.layers.Flatten())
    
    x = tf.keras.layers.TimeDistributed(mobilenet_model)(inp)
    x = tf.keras.layers.LSTM(64, return_sequences=False)(x)
    x = tf.keras.layers.Dropout(0.3)(x)
    out = tf.keras.layers.Dense(1, activation = 'sigmoid')(x)

    model = tf.keras.Model(inp, out)

    model.compile(loss = tf.keras.losses.BinaryCrossentropy(), optimizer = tf.keras.optimizers.Adam(learning_rate=0.01), metrics = ['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()])

    return model

# %%
# model = make_model()

# model.build(input_shape=IMAGE_SIZE)
# model.summary()

# %%
all_accs = []
all_pres = []
all_recs = []
all_f1s = []

# %%
###
### CHANGE THIS TO THE CORRECT STARTING PLACE BEFORE RUNNING THE EXPERIMENT AGAIN!!!
### This applies if the notebook connection was interrupted during the middle of
### the training process..
###
STARTING_FOLD_INDEX = 319

# %%
with strategy.scope():

    with open("file_names_folds.pkl", 'rb') as f: 
        SEEDS, FOLD_FILES = pickle.load(f)
        
        index_to_start_at = STARTING_FOLD_INDEX

        for fold in FOLD_FILES[index_to_start_at:]:
            
            print('FOLD::: ', fold)
            
            train_files = [a.strip('_') for a in fold['train']]
            test_files = [a.strip('_') for a in fold['test']]

            X_train = []
            X_test = []

            y_train = []
            y_test = []

            for filename in train_files:
                filename_int = int(filename.split('.mp4')[0])

                if filename_int <= 115:
                    curr_y = 1
                    subdir_name = 'armflapping'
                else:
                    curr_y = 0
                    subdir_name = 'control'

                curr_x = []
                for frame in os.listdir('behavior_data/' + subdir_name + '/' + filename):

                    frame_num = int(frame.split('.')[0])
                    if frame_num > 90:
                        continue

                    image = cv2.imread('behavior_data/' + subdir_name + '/' + filename + '/' + frame)
                    try:
                        image = image.reshape((image.shape[0], image.shape[1], image.shape[2]))
                    except:
                        continue

                    image = cv2.resize(image, (224, 224))
                    curr_x.append(image)

                len_data = len(os.listdir('behavior_data/' + subdir_name + '/' + filename))
                if len_data < 90:
                    for abc in range(len_data, 90):
                        curr_x.append(np.zeros((224, 224, 3)))

                curr_x = np.array(curr_x)

                X_train.append(curr_x)
                y_train.append(curr_y)

            for filename in test_files:
                filename_int = int(filename.split('.mp4')[0])

                if filename_int <= 115:
                    curr_y = 1
                    subdir_name = 'armflapping'
                else:
                    curr_y = 0
                    subdir_name = 'control'

                curr_x = []
                for frame in os.listdir('behavior_data/' + subdir_name + '/' + filename):

                    frame_num = int(frame.split('.')[0])
                    if frame_num > 90:
                        continue

                    image = cv2.imread('behavior_data/' + subdir_name + '/' + filename + '/' + frame)
                    try:
                        image = image.reshape((image.shape[0], image.shape[1], image.shape[2]))
                    except:
                        continue

                    image = cv2.resize(image, (224, 224))
                    curr_x.append(image)

                len_data = len(os.listdir('behavior_data/' + subdir_name + '/' + filename))
                if len_data < 90:
                    for abc in range(len_data, 90):
                        curr_x.append(np.zeros((224, 224, 3)))

                curr_x = np.array(curr_x)

                X_test.append(curr_x)
                y_test.append(curr_y)

            X_train = np.array(X_train)
            X_test = np.array(X_test)
            y_train = np.array(y_train)
            y_test = np.array(y_test)

            print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)

            model = make_model()

            model.compile(loss = tf.keras.losses.BinaryCrossentropy(), 
                          optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001), 
                          metrics = ['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()])

            history = model.fit(X_train, 
                                y_train, 
                                #validation_data = (X_test, y_test), 
                                batch_size = 16,
                                epochs = 60)


            ###
            ### EVALUATE HERE!!!!!
            ###
            
            predictions = []
            trues = []
            for i in range(X_test.shape[0]):
                X_to_predict = np.array([X_test[i]])
                pred = model(X_to_predict)
                print(pred)
                true = y_test[i]
                if pred < 0.5:
                    predictions.append(0)
                else:
                    predictions.append(1)
                trues.append(true)

            acc = accuracy_score(trues, predictions)
            pre = precision_score(trues, predictions)
            rec = recall_score(trues, predictions)
            f1 = f1_score(trues, predictions)
            
            print('\n\n\n\n\n\n\n  ', acc, pre, rec, f1, ' \n\n\n\n\n\n\n')
            
            all_accs.append(acc)
            all_pres.append(pre)
            all_recs.append(rec)
            all_f1s.append(f1)
            
            with open('performances/' + str(STARTING_FOLD_INDEX) + '_results.txt', 'w') as f:
                f.write('Accuracy: ' + str(acc) + '\n')
                f.write('Precision: ' + str(pre) + '\n')
                f.write('Recall: ' + str(rec) + '\n')
                f.write('F1: ' + str(f1) + '\n')
                f.close()
                
            STARTING_FOLD_INDEX += 1
# Out:
# FOLD:::  {'train': ['_113.mp4', '_75.mp4', '_88.mp4', '_61.mp4', '_76.mp4', '_49.mp4', '_17.mp4', '_101.mp4', '_14.mp4', '_65.mp4', '_100.mp4', '_89.mp4', '_99.mp4', '_29.mp4', '_98.mp4', '_2.mp4', '_102.mp4', '_105.mp4', '_114.mp4', '_110.mp4', '_0.mp4', '_72.mp4', '_107.mp4', '_60.mp4', '_10.mp4', '_63.mp4', '_48.mp4', '_115.mp4', '_11.mp4', '_38.mp4', '_1.mp4', '_3.mp4', '_77.mp4', '_39.mp4', '_104.mp4', '_106.mp4', '_112.mp4', '_5.mp4', '_28.mp4', '_111.mp4', '_127.mp4', '_167.mp4', '_171.mp4', '_173.mp4', '_164.mp4', '_172.mp4', '_130.mp4', '_140.mp4', '_120.mp4', '_163.mp4', '_181.mp4', '_165.mp4', '_160.mp4', '_122.mp4', '_161.mp4', '_126.mp4', '_186.mp4', '_118.mp4', '_142.mp4', '_128.mp4', '_132.mp4', '_174.mp4', '_137.mp4', '_158.mp4', '_144.mp4', '_175.mp4', '_166.mp4', '_169.mp4', '_178.mp4', '_151.mp4', '_116.mp4', '_153.mp4', '_159.mp4', '_187.mp4', '_129.mp4', '_134.mp4', '_152.mp4', '_156.mp4', '_136.mp4', '_124.mp4'], 'test': ['_7.mp4', '_12.mp4', '_71.mp4', '_74.mp4', '_64.mp4', '_13.mp4', '_66.mp4', '_6.mp4', '_16.mp4', '_4.mp4', '_179.mp4', '_157.mp4', '_138.mp4', '_170.mp4', '_176.mp4', '_143.mp4', '_162.mp4', '_154.mp4', '_119.mp4', '_180.mp4']}
# (80, 90, 224, 224, 3) (20, 90, 224, 224, 3) (80,) (20,)
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# Epoch 1/60
# INFO:tensorflow:batch_all_reduce: 5 all-reduces with algorithm = nccl, num_packs = 1
# INFO:tensorflow:batch_all_reduce:
- accuracy: 0.9500 - precision_1: 1.0000 - recall_1: 0.9000
# Epoch 29/60
# 5/5 [==============================] - 1s 105ms/step - loss: 0.1489 - accuracy: 0.9625 - precision_1: 1.0000 - recall_1: 0.9250
# Epoch 30/60
# 5/5 [==============================] - 1s 108ms/step - loss: 0.1366 - accuracy: 0.9750 - precision_1: 1.0000 - recall_1: 0.9500
# Epoch 31/60
# 5/5 [==============================] - 1s 102ms/step - loss: 0.1757 - accuracy: 0.9375 - precision_1: 1.0000 - recall_1: 0.8750
# Epoch 32/60
# 5/5 [==============================] - 1s 108ms/step - loss: 0.1662 - accuracy: 0.9500 - precision_1: 1.0000 - recall_1: 0.9000
# Epoch 33/60
# 5/5 [==============================] - 1s 104ms/step - loss: 0.1334 - accuracy: 0.9625 - precision_1: 1.0000 - recall_1: 0.9250
# Epoch 34/60
# 5/5 [==============================] - 1s 106ms/step - loss: 0.1322 - accuracy: 0.9500 - precision_1: 1.0000 - recall_1: 0.9000
# Epoch 35/60
# 5/5 [==============================] - 1s 101ms/step - loss: 0.1602 - accuracy: 0.9625 - precision_1: 1.0000 - recall_1: 0.9250
# Epoch 36/60
# 5/5 [==============================] - 1s 102ms/step - loss: 0.1376 - accuracy: 0.9500 - precision_1: 1.0000 - recall_1: 0.9000
# Epoch 37/60
# 5/5 [==============================] - 1s 108ms/step - loss: 0.1110 - accuracy: 0.9500 - precision_1: 1.0000 - recall_1: 0.9000
# Epoch 38/60
# 5/5 [==============================] - 1s 103ms/step - loss: 0.1155 - accuracy: 0.9625 - precision_1: 1.0000 - recall_1: 0.9250
# Epoch 39/60
# 5/5 [==============================] - 1s 106ms/step - loss: 0.1118 - accuracy: 0.9750 - precision_1: 1.0000 - recall_1: 0.9500
# Epoch 40/60
# 5/5 [==============================] - 1s 103ms/step - loss: 0.1119 - accuracy: 0.9625 - precision_1: 1.0000 - recall_1: 0.9250
# Epoch 41/60
# 5/5 [==============================] - 0s 89ms/step - loss: 0.1027 - accuracy: 0.9875 - precision_1: 1.0000 - recall_1: 0.9750
# Epoch 42/60
# 5/5 [==============================] - 0s 86ms/step - loss: 0.1103 - accuracy: 0.9750 - precision_1: 1.0000 - recall_1: 0.9500
# Epoch 43/60
# 5/5 [==============================] - 0s 87ms/step - loss: 0.1101 - accuracy: 0.9750 - precision_1: 1.0000 - recall_1: 0.9500
# Epoch 44/60
# 5/5 [==============================] - 0s 84ms/step - loss: 0.0874 - accuracy: 0.9875 - precision_1: 1.0000 - recall_1: 0.9750
# Epoch 45/60
# 5/5 [==============================] - 0s 94ms/step - loss: 0.0930 - accuracy: 0.9875 - precision_1: 1.0000 - recall_1: 0.9750
# Epoch 46/60
# 5/5 [==============================] - 0s 92ms/step - loss: 0.0826 - accuracy: 0.9875 - precision_1: 1.0000 - recall_1: 0.9750
# Epoch 47/60
# 5/5 [==============================] - 0s 94ms/step - loss: 0.0792 - accuracy: 0.9625 - precision_1: 1.0000 - recall_1: 0.9250
# Epoch 48/60
# 5/5 [==============================] - 1s 101ms/step - loss: 0.0791 - accuracy: 0.9875 - precision_1: 1.0000 - recall_1: 0.9750
# Epoch 49/60
# 5/5 [==============================] - 0s 97ms/step - loss: 0.0705 - accuracy: 0.9875 - precision_1: 1.0000 - recall_1: 0.9750
# Epoch 50/60
# 5/5 [==============================] - 0s 85ms/step - loss: 0.0807 - accuracy: 0.9750 - precision_1: 1.0000 - recall_1: 0.9500
# Epoch 51/60
# 5/5 [==============================] - 0s 86ms/step - loss: 0.0868 - accuracy: 0.9750 - precision_1: 1.0000 - recall_1: 0.9500
# Epoch 52/60
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0726 - accuracy: 0.9750 - precision_1: 1.0000 - recall_1: 0.9500
# Epoch 53/60
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0576 - accuracy: 1.0000 - precision_1: 1.0000 - recall_1: 1.0000
# Epoch 54/60
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0623 - accuracy: 0.9875 - precision_1: 1.0000 - recall_1: 0.9750
# Epoch 55/60
# 5/5 [==============================] - 0s 86ms/step - loss: 0.0653 - accuracy: 0.9875 - precision_1: 1.0000 - recall_1: 0.9750
# Epoch 56/60
# 5/5 [==============================] - 0s 86ms/step - loss: 0.0532 - accuracy: 1.0000 - precision_1: 1.0000 - recall_1: 1.0000
# Epoch 57/60
# 5/5 [==============================] - 0s 88ms/step - loss: 0.0802 - accuracy: 0.9750 - precision_1: 1.0000 - recall_1: 0.9500
# Epoch 58/60
# 5/5 [==============================] - 0s 85ms/step - loss: 0.0586 - accuracy: 0.9875 - precision_1: 1.0000 - recall_1: 0.9750
# Epoch 59/60
# 5/5 [==============================] - 0s 86ms/step - loss: 0.0658 - accuracy: 0.9875 - precision_1: 1.0000 - recall_1: 0.9750
# Epoch 60/60
# 5/5 [==============================] - 0s 83ms/step - loss: 0.
.mp4', '_129.mp4', '_170.mp4', '_159.mp4', '_122.mp4', '_165.mp4', '_178.mp4', '_156.mp4'], 'test': ['_98.mp4', '_39.mp4', '_76.mp4', '_4.mp4', '_12.mp4', '_66.mp4', '_72.mp4', '_6.mp4', '_102.mp4', '_106.mp4', '_161.mp4', '_187.mp4', '_164.mp4', '_180.mp4', '_157.mp4', '_162.mp4', '_174.mp4', '_154.mp4', '_186.mp4', '_134.mp4']}
# (80, 90, 224, 224, 3) (20, 90, 224, 224, 3) (80,) (20,)
# Epoch 1/60
# INFO:tensorflow:batch_all_reduce: 5 all-reduces with algorithm = nccl, num_packs = 1
# INFO:tensorflow:batch_all_reduce: 5 all-reduces with algorithm = nccl, num_packs = 1
# 5/5 [==============================] - 1s 109ms/step - loss: 0.7352 - accuracy: 0.5250 - precision_5: 0.5167 - recall_5: 0.7750
# Epoch 2/60
# 5/5 [==============================] - 1s 101ms/step - loss: 0.5699 - accuracy: 0.6500 - precision_5: 0.6111 - recall_5: 0.8250
# Epoch 3/60
# 5/5 [==============================] - 1s 109ms/step - loss: 0.4888 - accuracy: 0.8500 - precision_5: 0.8333 - recall_5: 0.8750
# Epoch 4/60
# 5/5 [==============================] - 1s 115ms/step - loss: 0.4510 - accuracy: 0.8500 - precision_5: 0.8333 - recall_5: 0.8750
# Epoch 5/60
# 5/5 [==============================] - 1s 104ms/step - loss: 0.4015 - accuracy: 0.9000 - precision_5: 0.9211 - recall_5: 0.8750
# Epoch 6/60
# 5/5 [==============================] - 1s 102ms/step - loss: 0.4066 - accuracy: 0.9000 - precision_5: 0.9444 - recall_5: 0.8500
# Epoch 7/60
# 5/5 [==============================] - 1s 118ms/step - loss: 0.3759 - accuracy: 0.9125 - precision_5: 0.9714 - recall_5: 0.8500
# Epoch 8/60
# 5/5 [==============================] - 1s 104ms/step - loss: 0.3330 - accuracy: 0.9250 - precision_5: 0.9722 - recall_5: 0.8750
# Epoch 9/60
# 5/5 [==============================] - 1s 102ms/step - loss: 0.3262 - accuracy: 0.9125 - precision_5: 0.9714 - recall_5: 0.8500
# Epoch 10/60
# 5/5 [==============================] - 1s 108ms/step - loss: 0.3116 - accuracy: 0.9125 - precision_5: 0.9714 - recall_5: 0.8500
# Epoch 11/60
# 5/5 [==============================] - 0s 99ms/step - loss: 0.3104 - accuracy: 0.9000 - precision_5: 0.9444 - recall_5: 0.8500
# Epoch 12/60
# 5/5 [==============================] - 1s 106ms/step - loss: 0.2869 - accuracy: 0.9250 - precision_5: 1.0000 - recall_5: 0.8500
# Epoch 13/60
# 5/5 [==============================] - 0s 98ms/step - loss: 0.2774 - accuracy: 0.9250 - precision_5: 0.9722 - recall_5: 0.8750
# Epoch 14/60
# 5/5 [==============================] - 1s 102ms/step - loss: 0.2477 - accuracy: 0.9375 - precision_5: 1.0000 - recall_5: 0.8750
# Epoch 15/60
# 5/5 [==============================] - 1s 104ms/step - loss: 0.2401 - accuracy: 0.9250 - precision_5: 0.9722 - recall_5: 0.8750
# Epoch 16/60
# 5/5 [==============================] - 1s 113ms/step - loss: 0.2411 - accuracy: 0.9250 - precision_5: 0.9722 - recall_5: 0.8750
# Epoch 17/60
# 5/5 [==============================] - 1s 102ms/step - loss: 0
60
# 5/5 [==============================] - 1s 108ms/step - loss: 0.1414 - accuracy: 0.9625 - precision_7: 0.9744 - recall_7: 0.9500
# Epoch 30/60
# 5/5 [==============================] - 1s 111ms/step - loss: 0.1449 - accuracy: 0.9500 - precision_7: 0.9500 - recall_7: 0.9500
# Epoch 31/60
# 5/5 [==============================] - 1s 111ms/step - loss: 0.1561 - accuracy: 0.9625 - precision_7: 0.9744 - recall_7: 0.9500
# Epoch 32/60
# 5/5 [==============================] - 1s 110ms/step - loss: 0.1155 - accuracy: 0.9750 - precision_7: 0.9750 - recall_7: 0.9750
# Epoch 33/60
# 5/5 [==============================] - 1s 107ms/step - loss: 0.1220 - accuracy: 0.9750 - precision_7: 0.9750 - recall_7: 0.9750
# Epoch 34/60
# 5/5 [==============================] - 1s 108ms/step - loss: 0.1185 - accuracy: 0.9750 - precision_7: 0.9750 - recall_7: 0.9750
# Epoch 35/60
# 5/5 [==============================] - 1s 115ms/step - loss: 0.1078 - accuracy: 1.0000 - precision_7: 1.0000 - recall_7: 1.0000
# Epoch 36/60
# 5/5 [==============================] - 1s 114ms/step - loss: 0.1174 - accuracy: 0.9625 - precision_7: 0.9744 - recall_7: 0.9500
# Epoch 37/60
# 5/5 [==============================] - 1s 126ms/step - loss: 0.1052 - accuracy: 0.9625 - precision_7: 0.9744 - recall_7: 0.9500
# Epoch 38/60
# 5/5 [==============================] - 1s 117ms/step - loss: 0.1031 - accuracy: 0.9875 - precision_7: 1.0000 - recall_7: 0.9750
# Epoch 39/60
# 5/5 [==============================] - 1s 111ms/step - loss: 0.1091 - accuracy: 0.9875 - precision_7: 1.0000 - recall_7: 0.9750
# Epoch 40/60
# 5/5 [==============================] - 1s 109ms/step - loss: 0.1047 - accuracy: 0.9625 - precision_7: 0.9744 - recall_7: 0.9500
# Epoch 41/60
# 5/5 [==============================] - 0s 91ms/step - loss: 0.1019 - accuracy: 0.9750 - precision_7: 0.9750 - recall_7: 0.9750
# Epoch 42/60
# 5/5 [==============================] - 0s 87ms/step - loss: 0.0970 - accuracy: 1.0000 - precision_7: 1.0000 - recall_7: 1.0000
# Epoch 43/60
# 5/5 [==============================] - 0s 88ms/step - loss: 0.1161 - accuracy: 0.9625 - precision_7: 0.9744 - recall_7: 0.9500
# Epoch 44/60
# 5/5 [==============================] - 0s 94ms/step - loss: 0.0985 - accuracy: 0.9625 - precision_7: 0.9744 - recall_7: 0.9500
# Epoch 45/60
# 5/5 [==============================] - 0s 92ms/step - loss: 0.0895 - accuracy: 1.0000 - precision_7: 1.0000 - recall_7: 1.0000
# Epoch 46/60
# 5/5 [==============================] - 0s 88ms/step - loss: 0.0833 - accuracy: 1.0000 - precision_7: 1.0000 - recall_7: 1.0000
# Epoch 47/60
# 5/5 [==============================] - 0s 93ms/step - loss: 0.0850 - accuracy: 0.9875 - precision_7: 1.0000 - recall_7: 0.9750
# Epoch 48/60
# 5/5 [==============================] - 0s 84ms/step - loss: 0.0991 - accuracy: 0.9625 - precision_7: 1.0000 - recall_7: 0.9250
# Epoch 49/60
# 5/5 [==============================] - 0s 93ms/step - loss: 0.0690 - accuracy: 1.0000 - precision_7: 1.0000 - recall_7: 1.0000
# Epoch 50/60
# 5/5 [==============================] - 0s 85ms/step - loss: 0.0661 - accuracy: 1.0000 - precision_7: 1.0000 - recall_7: 1.0000
# Epoch 51/60
# 5/5 [==============================] - 1s 100ms/step - loss: 0.0725 - accuracy: 0.9875 - precision_7: 1.0000 - recall_7: 0.9750
# Epoch 52/60
# 5/5 [==============================] - 0s 95ms/step - loss: 0.0536 - accuracy: 1.0000 - precision_7: 1.0000 - recall_7: 1.0000
# Epoch 53/60
# 5/5 [==============================] - 0s 92ms/step - loss: 0.0804 - accuracy: 0.9875 - precision_7: 1.0000 - recall_7: 0.9750
# Epoch 54/60
# 5/5 [==============================] - 0s 91ms/step - loss: 0.
# 5/5 [==============================] - 0s 88ms/step - loss: 0.1046 - accuracy: 0.9625 - precision_359: 1.0000 - recall_359: 0.9250
# Epoch 46/60
# 5/5 [==============================] - 0s 87ms/step - loss: 0.1093 - accuracy: 0.9750 - precision_359: 1.0000 - recall_359: 0.9500
# Epoch 47/60
# 5/5 [==============================] - 0s 88ms/step - loss: 0.0839 - accuracy: 1.0000 - precision_359: 1.0000 - recall_359: 1.0000
# Epoch 48/60
# 5/5 [==============================] - 0s 92ms/step - loss: 0.0844 - accuracy: 1.0000 - precision_359: 1.0000 - recall_359: 1.0000
# Epoch 49/60
# 5/5 [==============================] - 0s 85ms/step - loss: 0.0905 - accuracy: 1.0000 - precision_359: 1.0000 - recall_359: 1.0000
# Epoch 50/60
# 5/5 [==============================] - 0s 87ms/step - loss: 0.0909 - accuracy: 0.9875 - precision_359: 1.0000 - recall_359: 0.9750
# Epoch 51/60
# 5/5 [==============================] - 0s 88ms/step - loss: 0.0913 - accuracy: 0.9875 - precision_359: 1.0000 - recall_359: 0.9750
# Epoch 52/60
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0721 - accuracy: 0.9875 - precision_359: 1.0000 - recall_359: 0.9750
# Epoch 53/60
# 5/5 [==============================] - 0s 87ms/step - loss: 0.0867 - accuracy: 0.9750 - precision_359: 1.0000 - recall_359: 0.9500
# Epoch 54/60
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0903 - accuracy: 0.9875 - precision_359: 1.0000 - recall_359: 0.9750
# Epoch 55/60
# 5/5 [==============================] - 0s 86ms/step - loss: 0.0814 - accuracy: 0.9875 - precision_359: 1.0000 - recall_359: 0.9750
# Epoch 56/60
# 5/5 [==============================] - 0s 87ms/step - loss: 0.0701 - accuracy: 1.0000 - precision_359: 1.0000 - recall_359: 1.0000
# Epoch 57/60
# 5/5 [==============================] - 0s 85ms/step - loss: 0.0768 - accuracy: 0.9875 - precision_359: 1.0000 - recall_359: 0.9750
# Epoch 58/60
# 5/5 [==============================] - 0s 88ms/step - loss: 0.0752 - accuracy: 1.0000 - precision_359: 1.0000 - recall_359: 1.0000
# Epoch 59/60
# 5/5 [==============================] - 0s 88ms/step - loss: 0.0801 - accuracy: 1.0000 - precision_359: 1.0000 - recall_359: 1.0000
# Epoch 60/60
# 5/5 [==============================] - 0s 78ms/step - loss: 0.0651 - accuracy: 0.9875 - precision_359: 1.0000 - recall_359: 0.9750
# tf.Tensor([[0.9776813]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.9919807]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.9911255]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.99264354]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.95917654]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.31500822]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.9925115]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.987245]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.9869212]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.9621639]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.8025875]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.68696]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.04421508]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.97590625]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.02210297]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.17782196]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.04180365]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.05477269]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.05363062]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.05821554]], shape=(1, 1), dtype=float32)
#
#
#
#
#
#
#
#    0.8 0.75 0.9 0.8181818181818182
#
#
#
#
#
#
#
# FOLD:::  {'train': ['_64.mp4', '_105.mp4', '_5.mp4', '_88.mp4', '_102.mp4', '_100.mp4', '_71.mp4', '_66.mp4', '_11.mp4', '_4.mp4', '_112.mp4', '_113.mp4', '_98.mp4', '_104.mp4', '_106.mp4', '_13.mp4', '_28.mp4', '_3.mp4', '_10.mp4', '_38.mp4', '_107.mp4', '_7.mp4', '_111.mp4', '_76.mp4', '_48.mp4', '_63.mp4', '_74.mp4', '_61.mp4', '_14.mp4', '_0.mp4', '_49.mp4', '_29.mp4', '_39.mp4', '_6.mp4', '_2.mp4', '_12.mp4', '_75.mp4', '_17.mp4', '_1.mp4', '_114.mp4', '_176.mp4', '_118.mp4', '_156.mp4', '_171.mp4', '_186.mp4', '_181.mp4', '_138.mp4', '_162.mp4', '_178.mp4', '_180.mp4', '_152.mp4', '_127.mp4', '_161.mp4', '_129.mp4', '_134.mp4', '_143.mp4', '_136.mp4', '_153.mp4', '_144.mp4', '_151.mp4', '_137.mp4', '_179.mp4', '_124.mp4', '_164.mp4', '_166.mp4', '_175.mp4', '_170.m
], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.45193005]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.98920923]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.9943962]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.87565804]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.99098116]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.919647]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.98901343]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.98693293]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.58120894]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.10423066]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.3516473]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.26273105]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.02409338]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.22681005]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.20732474]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.18960331]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.02207327]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.14243533]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.22323251]], shape=(1, 1), dtype=float32)
#
#
#
#
#
#
#
#    0.95 1.0 0.9 0.9473684210526316

# %% [markdown]
# ### Describe summary statistics for all 500 runs.

# %%
all_accs = []
all_pres = []
all_recs = []
all_f1s = []

for file in os.listdir('performances/'):
    with open('performances/' + file) as f:
        lines = f.readlines()
        
        acc = float(lines[0].split(': ')[1].strip('\n'))
        pre = float(lines[1].split(': ')[1].strip('\n'))
        rec = float(lines[2].split(': ')[1].strip('\n'))
        f1 = float(lines[3].split(': ')[1].strip('\n'))
        
        all_accs.append(acc)
        all_pres.append(pre)
        all_recs.append(rec)
        all_f1s.append(f1)
    

from scipy import stats
print('Acc: ', stats.describe(all_accs))
print('Pre: ', stats.describe(all_pres))
print('Rec: ', stats.describe(all_recs))
print('F1: ', stats.describe(all_f1s))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-5abdb896dd9b> in <module>
#      20
#      21 from scipy import stats
# ---> 22 print('Acc: ', stats.describe(all_accs))
#      23 print('Pre: ', stats.describe(all_pres))
#      24 print('Rec: ', stats.describe(all_recs))
#
# /opt/conda/lib/python3.7/site-packages/scipy/stats/stats.py in describe(a, axis, ddof, bias, nan_policy)
#    1315         raise ValueError("The input must not be empty.")
#    1316     n = a.shape[axis]
# -> 1317     mm = (np.min(a, axis=axis), np.max(a, axis=axis))
#    1318     m = np.mean(a, axis=axis)
#    1319     v = np.var(a, axis=axis, ddof=ddof)
#
# <__array_function__ internals> in amin(*args, **kwargs)
#
# /opt/conda/lib/python3.7/site-packages/numpy/core/fromnumeric.py in amin(a, axis, out, keepdims, initial, where)
#    2829     """
#    2830     return _wrapreduction(a, np.minimum, 'min', axis, None, out,
# -> 2831                           keepdims=keepdims, initial=initial, where=where)
#    2832
#    2833
#
# /opt/conda/lib/python3.7/site-packages/numpy/core/fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      85                 return reduction(axis=axis, out=out, **passkwargs)
#      86
# ---> 87     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#      88
#      89
#
# TypeError: cannot perform reduce with flexible type

# %%
'''
THIS IS HOW WE WILL HAVE TO EVALUATE PREDICTIONS!!!!!

https://stackoverflow.com/questions/56711354/tensorflow-v2-cancellederror-opstatefulpartitionedcall
'''

from sklearn.metrics import recall_score, precision_score, accuracy_score, f1_score

with strategy.scope():
    predictions = []
    trues = []
    for i in range(X_test.shape[0]):
        X_to_predict = np.array([X_test[i]])
        pred = model(X_to_predict)
        print(pred)
        true = y_test[i]
        if pred < 0.5:
            predictions.append(0)
        else:
            predictions.append(1)
        trues.append(true)
        
    print('Accuracy: ', accuracy_score(trues, predictions))
    print('Precision: ', precision_score(trues, predictions))
    print('Recall: ', recall_score(trues, predictions))
    print('F1 Score: ', f1_score(trues, predictions))
# Out:
# tf.Tensor([[0.8247404]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.9714775]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.9940625]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.99450547]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.9829216]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.9581735]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.9916317]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.9885062]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.81362104]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.9727558]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.05049171]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.4205745]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.1080795]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.04499972]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.0348262]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.04339964]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.03726655]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.01246449]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.6749961]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.2332511]], shape=(1, 1), dtype=float32)
# Accuracy:  0.95
# Precision:  0.9090909090909091
# Recall:  1.0
# F1 Score:  0.9523809523809523
